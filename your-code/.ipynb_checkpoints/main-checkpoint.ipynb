# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Challenge 2
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# Load the Titanic dataset
titanic = pd.read_csv('/Users/gopikagowthaman/Desktop/IRONHACK/week04/lab-matplotlib-seaborn/your-code/titanic.csv')

# Display the first few rows of the Titanic dataset
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# Check the data types of each column in the Titanic dataset
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_vars = titanic.select_dtypes(include=['int64', 'float64']).columns
numerical_vars
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
categorical_vars = titanic.select_dtypes(include=['object']).columns
categorical_vars
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# Set the plot style to classic
plt.style.use('classic')

# Set the figure size to (12, 6)
plt.rcParams['figure.figsize'] = (12, 6)

# Create a simple plot to confirm the settings
sns.countplot(x='Survived', data=titanic)
plt.title('Number of Passengers Who Survived vs. Those Who Did Not')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# Histogram to show the distribution of the Age column
plt.figure(figsize=(12, 6))
sns.histplot(titanic['Age'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Plot distribution with bins=10
sns.histplot(titanic['Age'], bins=10, kde=True, ax=axes[0])
axes[0].set_title('Distribution of Age (bins=10)')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')

# Plot distribution with bins=20
sns.histplot(titanic['Age'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Age (bins=20)')
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Frequency')

# Plot distribution with bins=50
sns.histplot(titanic['Age'], bins=50, kde=True, ax=axes[2])
axes[2].set_title('Distribution of Age (bins=50)')
axes[2].set_xlabel('Age')
axes[2].set_ylabel('Frequency')

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""10 Bins Provides a broader view with less granularity, 20 Bins Offers a moderate level of detail, 50 Bins Give a detailed view with finer granularity."""
# Out:
# '10 Bins Provides a broader view with less granularity, 20 Bins Offers a moderate level of detail, 50 Bins Give a detailed view with finer granularity.'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# Histogram to show the distribution of the Age column using Seaborn
sns.histplot(titanic['Age'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# Count the number of occurrences for each gender
gender_counts = titanic['Gender'].value_counts()

# Create a bar chart using Matplotlib
plt.figure(figsize=(12, 6))
plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Method 2 - seaborn

# Create a count plot using Seaborn
plt.figure(figsize=(12, 6))
sns.countplot(x='Gender', data=titanic, hue='Gender', palette=['blue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend([],[], frameon=False)  # Disable the legend
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`

# %%
# Create a count plot using Seaborn
plt.figure(figsize=(12, 6))
sns.countplot(x='Pclass', data=titanic, hue='Pclass', palette=['green', 'blue', 'red'])
plt.title('Passenger Class Distribution')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.legend([],[], frameon=False)  # Disable the legend
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# Create a violin plot to show the summary statistics and distribution of the Age column
plt.figure(figsize=(12, 6))
sns.violinplot(x='Age', data=titanic)
plt.title('Summary Statistics and Distribution of Age')
plt.xlabel('Age')
plt.show()

# %%
"""A violin plot could be considered a better option in some cases because it combines the benefits of a box plot with a density plot, providing more information about the distribution of the data"""
# Out:
# 'A violin plot could be considered a better option in some cases because it combines the benefits of a box plot with a density plot, providing more information about the distribution of the data'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""The violin plot reveals that the majority of Titanic passengers were young adults aged 20-30, with significant numbers of children aged 5-10 and middle-aged individuals aged 40-50. The distribution is relatively symmetric with a slight right skew, indicating some older passengers. The plot's bimodal nature suggests two main age groups among the passengers"""
# Out:
# "The violin plot reveals that the majority of Titanic passengers were young adults aged 20-30, with significant numbers of children aged 5-10 and middle-aged individuals aged 40-50. The distribution is relatively symmetric with a slight right skew, indicating some older passengers. The plot's bimodal nature suggests two main age groups among the passengers"

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# Create a FacetGrid with both a histogram and KDE plot to show the summary statistics and distribution of the Age column
plt.figure(figsize=(12, 6))
sns.histplot(titanic['Age'], bins=30, kde=True)
plt.title('Summary Statistics and Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""t highlights where the data is most concentrated, the central values, overall age distribution among Titanic passengers."""
# Out:
# 't highlights where the data is most concentrated, the central values, overall age distribution among Titanic passengers.'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# Create a scatter plot using Matplotlib
plt.figure(figsize=(12, 6))
plt.scatter(titanic['Age'], titanic['Fare'], alpha=0.5)
plt.title('Scatter Plot of Fare vs. Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn

# Create a scatter plot with a regression line using Seaborn
plt.figure(figsize=(12, 6))
sns.regplot(x='Age', y='Fare', data=titanic, scatter_kws={'alpha':0.5})
plt.title('Regression Plot of Fare vs. Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# Select only numerical columns
numerical_columns = titanic.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = titanic[numerical_columns].corr()

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""SibSp and Parch have a Correlation Coefficient of 0.41,therefore it is a moderate positive correlation between SibSp (number of siblings/spouses aboard) and Parch (number of parents/children aboard). This suggests that passengers with more siblings/spouses are likely to also have more parents/children with them"""
# Out:
# 'SibSp and Parch have a Correlation Coefficient of 0.41,therefore it is a moderate positive correlation between SibSp (number of siblings/spouses aboard) and Parch (number of parents/children aboard). This suggests that passengers with more siblings/spouses are likely to also have more parents/children with them'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

# %% [markdown]
# ## Challenge 3 - Amazon UK product Dataset

# %% [markdown]
# #### **Objective**: Delve into the dynamics of product pricing on Amazon UK to uncover insights that can inform business strategies and decision-making.
#
# ##### **Dataset**: This lab utilizes the [Amazon UK](https://www.kaggle.com/datasets/asaniczka/uk-optimal-product-price-prediction/) product dataset which provides information on product categories, brands, prices, ratings, and more from from Amazon UK. You'll need to download it to start working with it.

# %% [markdown]
# ### Part 0 - Preliminary Step: Remove outliers in product prices.
#
# For this purpose, we can use the IQR (Interquartile Range) method. Products priced below the first quartile minus 1.5 times the IQR or above the third quartile plus 1.5 times the IQR will be considered outliers and removed from the dataset. The next steps will be done with the dataframe without outliers.
#
# **Hint**: You can check the Descriptive Stats lesson for a reminder on Inter Quartile Range (IQR).

# %%
# Load the dataset
# Replace 'path_to_your_dataset.csv' with the actual path to your dataset file
dataset_url = '/Users/gopikagowthaman/Desktop/IRONHACK/week04/lab-matplotlib-seaborn/your-code/amz_uk_price_prediction_dataset.csv'
amazon_uk_df = pd.read_csv(dataset_url)

# Display the first few rows of the dataset to understand its structure
print(amazon_uk_df.head())

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = amazon_uk_df['price'].quantile(0.25)
Q3 = amazon_uk_df['price'].quantile(0.75)

# Calculate IQR (Interquartile Range)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from the dataset
filtered_df = amazon_uk_df[(amazon_uk_df['price'] >= lower_bound) & (amazon_uk_df['price'] <= upper_bound)]

# Display the shape of the dataset before and after removing outliers
print(f"Original dataset shape: {amazon_uk_df.shape}")
print(f"Filtered dataset shape: {filtered_df.shape}")

# Display the first few rows of the filtered dataset
print(filtered_df.head())
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers
# Original dataset shape: (2443651, 9)
# Filtered dataset shape: (2115963, 9)
# ...

# %% [markdown]
# ### Part 1 - Violin Plots:
#
# Use a violin plot to visualize the distribution of price across different product categories. Filter out the top 20 categories based on count for better visualization.
#
# Which product category tends to have the highest median price? Don't filter here by top categories.

# %%
# Get the top 20 categories based on count
top_20_categories = filtered_df['category'].value_counts().head(20).index

# Filter the dataset for these top 20 categories
filtered_top_20_df = filtered_df[filtered_df['category'].isin(top_20_categories)]

# Create a violin plot
plt.figure(figsize=(14, 8))
sns.violinplot(x='category', y='price', data=filtered_top_20_df)
plt.title('Distribution of Prices Across Top 20 Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Part 2 - Bar Charts:
#
# Create a bar chart comparing the average price of products for the top 10 product categories (based on count).
# Which product category commands the highest average price? Don't filter here by top categories.

# %%
# Get the top 10 categories based on count
top_10_categories = filtered_df['category'].value_counts().head(10).index

# Filter the dataset for these top 10 categories
filtered_top_10_df = filtered_df[filtered_df['category'].isin(top_10_categories)]

# Calculate the average price for each category
average_prices = filtered_top_10_df.groupby('category')['price'].mean().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(14, 8))
sns.barplot(x=average_prices.index, y=average_prices.values, palette='viridis')
plt.title('Average Price of Products for Top 10 Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Average Price')
plt.xticks(rotation=90)
plt.legend([],[], frameon=False)  # Disable the legend
plt.show()

# Identify the category with the highest average price
highest_avg_price_category = average_prices.idxmax()
highest_avg_price = average_prices.max()

print(f"The product category with the highest average price is: {highest_avg_price_category}")
print(f"The highest average price is: {highest_avg_price}")
# Out:
# /var/folders/73/bp0mdjtd56gc_yr975dw29n00000gn/T/ipykernel_1780/769638133.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_prices.index, y=average_prices.values, palette='viridis')
# The product category with the highest average price is: Sports & Outdoors
# The highest average price is: 25.17206487036301

# %% [markdown]
# ### Part 3 - Box Plots:
#
# Visualize the distribution of product ratings based on their category using side-by-side box plots. Filter out the top 10 categories based on count for better visualization.
# Which category tends to receive the highest median rating from customers? Don't filter here by top categories.

# %% [markdown]
# ### Part 4 - Investigating the Interplay Between Product Prices and Ratings:
#
# Objective: Analyze how product ratings (stars) correlate with product prices.

# %% [markdown]
# #### 4.1 - Correlation Coefficients:
#
# Calculate the correlation coefficient between price and stars.
# Is there a significant correlation between product price and its rating?

# %%
# your code here

# %% [markdown]
# #### 4.2 - Visualizations:
#
# Use a scatter plot to visualize the relationship between product rating and price. What patterns can you observe?
# Use a correlation heatmap to visualize correlations between all numerical variables.
# Examine if product prices typically follow a normal distribution using a QQ plot.

# %%
# your code here
