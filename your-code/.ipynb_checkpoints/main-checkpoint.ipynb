# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, label='linear')
plt.plot(x,z, label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
plot_options,(chart1,chart2) = plt.subplots(nrows=1, ncols=2)
chart1.scatter(x, y,color='green',marker='.')
chart2.scatter(x, z,color='red',marker='+')
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
plot_options,(chart1,chart2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 2.5))

chart1.set_title('Hiper green graph')
chart1.scatter(x, y,color='green',marker='.')
chart1.set_ylabel('y axis')
chart1.set_xlabel('x axis')
chart1.set_xticklabels(labels=x, fontsize = 8, rotation=-15)


chart2.set_title('Cool red graph')
chart2.scatter(x, z,color='red',marker='+')
chart2.set_ylabel('y axis')
chart2.set_xlabel('x axis')
chart2.set_yticklabels(labels=y, fontsize = 12, rotation=15)
plt.show()
# Out:
# /var/folders/0z/fnx6532x5wxbqn3d5jdwnh2w0000gn/T/ipykernel_23215/821598297.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart1.set_xticklabels(labels=x, fontsize = 8, rotation=-15)
# /var/folders/0z/fnx6532x5wxbqn3d5jdwnh2w0000gn/T/ipykernel_23215/821598297.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart2.set_yticklabels(labels=y, fontsize = 12, rotation=15)

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

plot_options,(chart1,chart2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 2.5))

y = x**2 #Blue
v = np.exp(x) #Orange

chart1.set_title('Logarithmic')
chart1.plot(x, y,color='blue')
chart1.set_ylabel('y axis')
chart1.set_xlabel('x axis')
chart1.plot(x, v,color='orange')
chart1.set_yscale('log')
chart1.set_xscale('log')


chart2.set_title('Normal')
chart2.plot(x, y,color='blue')
chart2.plot(x, v,color='orange')
chart2.set_ylabel('y axis')
chart2.set_xlabel('x axis')


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plot_options,(chart1,chart2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 2.5))

y = x**2 #Blue
v = np.exp(x) #Orange

chart1.set_title('Logarithmic')
chart1.plot(x, y, color='blue', label='y=x^2')
chart1.set_ylabel('y axis')
chart1.set_xlabel('x axis')
chart1.plot(x, v, color='orange', label='y=e^x')
chart1.set_yscale('log')
chart1.set_xscale('log')
chart1.legend()

chart2.set_title('Normal')
chart2.plot(x, y, color='blue', label='y=x^2')
chart2.plot(x, v, color='orange', label='y=e^x')
chart2.set_ylabel('y axis')
chart2.set_xlabel('x axis')
chart2.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
if not os.path.exists('figures'):
    os.makedirs('figures')

only_months = fitbit.groupby('Months_encoded')['Steps'].agg('median').reset_index()
only_months

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


plt.figure(figsize=(12, 4))
plt.plot(only_months['Months_encoded'],only_months['Steps'])
plt.xticks(only_months['Months_encoded'],months)
plt.title('Plot Graph Median Steps over Month')
plt.savefig('figures/plot_median_graph.png')
plt.show


plt.figure(figsize=(12, 4))
plt.scatter(only_months['Months_encoded'],only_months['Steps'])
plt.xticks(only_months['Months_encoded'],months)
plt.title('Scatter Graph Median Steps over Month')
plt.savefig('figures/sca_median_graph.png')
plt.show


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

work_or_weekend = fitbit.groupby('Work_or_Weekend')['Steps'].agg('sum').reset_index()
work_or_weekend


plt.figure(figsize=(12, 4))
plt.bar(work_or_weekend['Work_or_Weekend'],work_or_weekend['Steps'])
plt.xticks(work_or_weekend['Work_or_Weekend'],['Work','Weekend'])
plt.title('Bar Graph Median Steps Work/Weekend')
plt.savefig('figures/bar_work_weekend_graph.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

list_min = ['Minutes Very Active', 'Minutes Lightly Active', 'Minutes Sedentary']
colors = ['red','orange','c']

for i, j in zip(list_min, colors):
    plt.scatter(fitbit['Steps'], fitbit[i], color=j, label=i)
    plt.title('Minutes over steps')

plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(1.04, 1))
    
plt.ylabel('Minutes')
plt.xlabel('Steps')
plt.show()

#We get that the very active minute are very low, then the lightly minutes, and then the sedentary minutes.
#Because the high level activity is usuarlly short.

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

num_var = titanic.select_dtypes(include=['int64','float64'])
num_var
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

cat_var = titanic.select_dtypes(include=['object'])
cat_var
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

x = num_var['Age']

plt.hist(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

plot_options,(chart1,chart2,chart3) = plt.subplots(nrows=3,ncols=1,figsize=(20,10))

chart1.hist(x,bins=10,color='green')
chart2.hist(x,bins=20,color='orange')
chart3.hist(x,bins=50,color='red')
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
We can see the more generic plot with less bins, because it sums the ages that are close, so it smooths the graphs.
And it is less accurate.

The more bins, the more realistic the graph but it gets to be less smooth.

"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.hist(titanic['Gender'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Method 2 - seaborn
# your code here

sns.displot(titanic['Gender'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.displot(titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(y='Age', data = titanic)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
"""
The best plot to visualize statistics would be the boxplot. At a glance we can see the median, the percentil 25 and 75.
And we can easily see the outliers.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
That the majority of the people aboard the Titanic were between 22 and 38 years old.
And very few people older than 60.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
#sns.violinplot(y='Age', data= titanic)
sns.distplot(titanic['Age'],bins=20)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
There are many kids between new borns and 5 years old.
And the most common age was around 23 years old.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
#We select the filtered data with only the numerical values
plt.matshow(num_var.corr(), cmap='coolwarm') #adds a more understandable color palette
plt.xticks(range(0,7),num_var.columns, rotation=45)
plt.yticks(range(0,7),num_var.columns)
plt.colorbar()
plt.show

#we see that Age and Fare are actually very slightly related.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(x='Age',y='Fare', data=titanic)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.heatmap(num_var.corr(), cmap='coolwarm', annot=True,xticklabels=num_var.corr().columns,yticklabels=num_var.corr().columns)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are Pclass and Fare, but the have a negative correlation, meaning that when one increases, the other decreases.
The most correlated features that have a positive correlation are the Parch and the SibSp
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# Using matplotlib

fig, axs = plt.subplots(ncols=3, figsize=(12, 4))

# create a boxplot of Age by Pclass for each column of the grid
for i, pclass in enumerate(titanic['Pclass'].unique()):
    ax = axs[i]
    subset = titanic[titanic['Pclass'] == pclass]
    ax.boxplot(subset['Age'].dropna())
    ax.set_title(f'Pclass = {pclass}')
    ax.set_xlabel('Pclass')
    ax.set_ylabel('Age')


plt.show()

# %%
#Using seaborn

g = sns.FacetGrid(titanic, col='Pclass', height=4)
g.map(sns.boxplot, 'Pclass', 'Age')
plt.show
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

grid = sns.FacetGrid(titanic, col='Gender', height=4)

grid.map(sns.boxplot, 'Gender', 'Age')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
