# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, ax = plt.subplots(nrows = 2, ncols = 1)

# Plot (x,y) on the left subplot
ax[0].plot(x, y, linewidth=1, linestyle='--')

# Plot (x,z) on the right subplot
ax[1].plot(x, z, linewidth=2, linestyle='-.')

# Display the figure
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(nrows = 1, ncols = 2)

# Plot (x,y) on the left subplot
ax[0].plot(x, y, linewidth=1, linestyle=':')

# Plot (x,z) on the right subplot
ax[1].plot(x, z, linewidth=2, linestyle='-.')

# Display the figure
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(10,5))

# Plot (x,y) on the left subplot
ax[0].plot(x, y)
ax[0].set_title('x vs y', fontsize=14, fontweight='bold')
ax[0].set_xlabel('x', fontsize=12, fontweight='bold')
ax[0].set_ylabel('y', fontsize=12, fontweight='bold')

# Plot (x,z) on the right subplot
ax[1].plot(x, z)
ax[1].set_title('x vs z', fontsize=14, fontweight='bold')
ax[1].set_xlabel('x', fontsize=12, fontweight='bold')
ax[1].set_ylabel('z', fontsize=12, fontweight='bold')

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
#plot using normal scale
y1 = x**2
y2 = np.exp(x)
plt.plot(y1, label='y=x^2')
plt.plot(y2, label='y=e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y=x^2 and y=e^x in normal scale')
plt.legend()
plt.show()

#plot using logarithmic scale
y1 = x**2
y2 = np.exp(x)
plt.plot(y1, label='y=x^2')
plt.plot(y2, label='y=e^x')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y=x^2 and y=e^x in logarithmic scale')
plt.legend()
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# already done in the previous step

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#code to create the folder figures
# !mkdir figures 

# Figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# MEDIAN STEPS BY MONTH_ENCODED
# Boxplot of steps by month
sns.boxplot(x='Months', y='Steps', data=fitbit, ax=ax1)
ax1.set_xlabel('Month')
ax1.set_ylabel('Steps')
ax1.set_xticks(range(12))
month_labels = fitbit['Months'].unique()
ax1.set_xticklabels(month_labels,rotation=45, ha='right', fontsize=10)
ax1.tick_params(axis='x', labelrotation=45, labelsize=10)
ax1.set_title('Median Steps by Month')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# Bar chart of steps on Work_or_Weekend
sns.boxplot(x='Work_or_Weekend', y='Steps', data=fitbit, ax=ax2)
ax2.set_xlabel('Day Type')
ax2.set_ylabel('Steps')
ax2.set_title('Median Steps on Workdays vs. Weekends')

# Save the figures in the 'figures' folder
plt.savefig('figures/fitbit_steps_by_month_and_day_type_seaborn.png', bbox_inches='tight')

# Show the plots
plt.show()
# Out:
# A subdirectory or file figures already exists.

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

features = [('Minutes Lightly Active', 'Steps'), ('Minutes Very Active', 'Steps'), ('Minutes Sedentary', 'Steps')]

# Figure with 3 subplots
#fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# Loop
for x,y in features:
    plt.scatter(fitbit[x], fitbit[y])
    plt.xlabel(x)
    plt.ylabel(y)
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include='number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
plt.xlabel('Age')
plt.ylabel('Age Distribution')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bins = [10, 20, 50]

fig, axes = plt.subplots( 1, len(bins), figsize=(16,4))

for i, bins in enumerate(bins):
    axes[i].hist(titanic['Age'], bins=bins)
    axes[i].set_xlabel('Age')
    axes[i].set_ylabel('Frequency')


plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The smaller bin size provides a more detailed view of the distribution of the data, while a larger bin size gives a more general
overview. Using a smaller bin size (10) provides a more detailed view of the age distribution, allowing for the identification 
of potential outliers or interesting features like the skewdness and relation to indicatores such as the mode, mean and median.
Using a larger bin size (50) may hide such details and provide a more general view of the data.
"""
# Out:
# '\nThe smaller bin size provides a more detailed view of the distribution of the data, while a larger bin size gives a more general\noverview. Using a smaller bin size (10) provides a more detailed view of the age distribution, allowing for the identification \nof potential outliers or interesting features like the skewdness and relation to indicatores such as the mode, mean and median.\nUsing a larger bin size (50) may hide such details and provide a more general view of the data.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic, x="Age")

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

gender_count=titanic['Gender'].value_counts()
print(gender_count)
plt.bar(gender_count.index, gender_count.values)
plt.title('Titanic Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
# Method 2 - seaborn

sns.countplot(x='Gender', data=titanic)
plt.title('Titanic Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x='Pclass', data=titanic)
plt.title('Passenger Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x='Age', data=titanic)
plt.show()

# %%
"""
We can use a box plot, because it displays the median, quartiles, range, and outliers for a given dataset.
There are other types of plots that can be used to display the summary statistics of the colum Age, 
for example the violin plot, which is similar to boxplot, but also shows the distribution of the data.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The median is a little bit shifted to the left (positive skewed).
The interquartile range is between the 20s and the 40s, which means that 50% of ages for the group are between ~20 and ~40. 
The box is small which means that overall ages have a high level of agreement with each other.  
There are some outliers between 60 and 80 (data points that are located outside the whiskers of the box plot).
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# the violin plot, which is similar to boxplot, but also shows the distribution of the data

sns.violinplot(x='Age', data = titanic)
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
On each side of the gray line is the kernel density estimation to show the distribution shape of the data. Wider sections of 
the violin plot represent a higher probability that members of the population will take on the given age; 
the skinnier sections represent a lower probability. Seems that the higher probability is between 20 and 30.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic['Age'], titanic['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
sns.scatterplot(x='Age', y='Fare', data=titanic)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
titanic_only_numbers = titanic.select_dtypes(include='number')
sns.heatmap(titanic_only_numbers.corr())
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are Parch and SibSp, and also Fare and Survived.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.violinplot(x='Pclass', y='Age', data = titanic)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.violinplot(x='Gender', y='Age', data = titanic)
plt.show()
