# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

# Creating a figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

# Plotting x against y on the first axes
axes[0].plot(x, y, color='blue', linewidth=2)
axes[0].set_title('Plot of y = 2x')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

# Plotting x against z on the second axes
axes[1].plot(x, z, color='red', linewidth=2)
axes[1].set_title('Plot of z = x^2')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')

# Adjusting the spacing between the plots
fig.tight_layout()

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

# Creating a larger figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8))

# Plotting x against y on the first axes
axes[0].plot(x, y, color='blue', linewidth=2)
axes[0].set_title('Plot of y = 2x', fontsize=20, fontweight='bold')
axes[0].set_xlabel('x', fontsize=15)
axes[0].set_ylabel('y', fontsize=15)

# Plotting x against z on the second axes
axes[1].plot(x, z, color='red', linewidth=2)
axes[1].set_title('Plot of z = x^2', fontsize=20, fontweight='bold')
axes[1].set_xlabel('x', fontsize=15)
axes[1].set_ylabel('z', fontsize=15)

# Adjusting the spacing between the plots
fig.tight_layout()

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

# Creating a figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8))

# Creating the data
y1 = x**2
y2 = np.exp(x)

# Plotting y1 and y2 on the first axes (normal scale)
axes[0].plot(x, y1, color='blue', label='y = x^2')
axes[0].plot(x, y2, color='red', label='y = e^x')
axes[0].set_title('Normal Scale', fontsize=15, fontweight='bold')
axes[0].set_xlabel('x', fontsize=10)
axes[0].set_ylabel('y', fontsize=10)
axes[0].legend()

# Plotting y1 and y2 on the second axes (logarithmic scale)
axes[1].plot(x, y1, color='blue', label='y = x^2')
axes[1].plot(x, y2, color='red', label='y = e^x')
axes[1].set_title('Logarithmic Scale', fontsize=15, fontweight='bold')
axes[1].set_xlabel('x', fontsize=10)
axes[1].set_ylabel('y', fontsize=10)
axes[1].set_yscale('log')
axes[1].legend()

# Adjusting the spacing between the plots
fig.tight_layout()

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 4\\Day 2\\lab-matplotlib-seaborn\\your-code\\Fitbit2.csv")

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

# Grouping the data by month and calculating the median steps
median_steps_month = fitbit.groupby('Months_encoded')['Steps'].median()

# Grouping the data by weekday/weekend and calculating the median steps
median_steps_work_weekend = fitbit.groupby('Work_or_Weekend')['Steps'].median()

# Creating subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

# Plotting the median steps by month
plt.sca(axes[0])  # Set the current Axes instance to axes[0]
plt.plot(median_steps_month.index, median_steps_month.values, marker='o')
plt.title('Median Steps walked by Month')
plt.xlabel('Month')
plt.ylabel('Median steps')
plt.xticks(list(range(1,13)), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Plotting the median steps by weekday/weekend
plt.sca(axes[1])  # Set the current Axes instance to axes[1]
plt.bar(median_steps_work_weekend.index, median_steps_work_weekend.values, tick_label=['Weekend', 'Workdays'])
plt.title('Median Steps walked by Workdays and Weekend')
plt.xlabel('Type of Day')
plt.ylabel('Median steps')

# Adjusting the layout
plt.tight_layout()

# Displaying the plots
plt.show()

# %%
 fig.savefig("C:\\Users\\carmo\\Desktop\\IronHack\\Week 4\\Day 2\\lab-matplotlib-seaborn\\your-code\\figures\median_steps.png")

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# List of features to plot against steps
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

# Creating 3 scatter plots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,6))

for i, feature in enumerate(features):
    # Scatter plot
    axes[i].scatter(fitbit[feature], fitbit['Steps'])
    axes[i].set_title(f'{feature} vs Steps')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Steps')

# Adjusting the layout
plt.tight_layout()

# Displaying the plots
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 4\\Day 2\\lab-matplotlib-seaborn\\your-code\\titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# Selecting numerical variables
numerical_vars = titanic.select_dtypes(include=['int64', 'float64'])

# %%
# CATEGORICAL VARIABLES
# Selecting categorical variables
categorical_vars = titanic.select_dtypes(include='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# Setting the plot style to 'classic'
plt.style.use('classic')

# Setting the default figure size
plt.rcParams["figure.figsize"] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# Creating a histogram for the 'Age' column
plt.hist(titanic['Age'].dropna(), bins=30, edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# Creating a figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,6))

# List of bin sizes
bins = [10, 20, 50]

# Creating histograms with different bin sizes
for i, bin_size in enumerate(bins):
    axes[i].hist(titanic['Age'].dropna(), bins=bin_size, edgecolor='black')
    axes[i].set_title(f'Distribution of Age (bins={bin_size})')
    axes[i].set_xlabel('Age')
    axes[i].set_ylabel('Frequency')

# Adjusting the layout
plt.tight_layout()

# Displaying the plots
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size in a histogram affects the level of detail that you can see in the distribution of the data.

Smaller bin sizes (more bins): With smaller bin sizes, each bin covers a smaller range of values, so you can see more detail in the distribution of the data. This is helpful for seeing patterns at a more granular level. However, if the bin size is too small, the histogram might become too cluttered and harder to interpret, potentially amplifying noise in the data.

Larger bin sizes (fewer bins): With larger bin sizes, each bin covers a wider range of values, so the histogram provides a more generalized view of the distribution. This is useful for understanding the overall shape of the data, but you may miss some of the finer details. If the bin size is too large, important features and patterns in the data may be obscured.

In the case of the age distribution in the Titanic dataset:

With 50 bins, we can see more detailed age groups and notice small fluctuations within certain age ranges.
With 10 bins, the age groups are broader, and we get a more general picture of the distribution, which highlights the overall shape but obscures some of the finer details.
In general, choosing an appropriate bin size is a balance between capturing enough detail and not overcomplicating the interpretation of the histogram. It often requires some trial and error, as well as domain knowledge."""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# Creating a histogram for the 'Age' column using seaborn
sns.histplot(data=titanic, x='Age', kde=False, bins=30, color='blue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# Counting the number of each gender
gender_counts = titanic['Gender'].value_counts()

# Creating a figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

# Plotting the gender distribution using matplotlib
axes[0].bar(gender_counts.index, gender_counts.values, color=['blue', 'orange'])
axes[0].set_title('Gender Distribution (Matplotlib)')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Method 2 - seaborn
# Plotting the gender distribution using seaborn
sns.countplot(data=titanic, x='Gender', ax=axes[1])
axes[1].set_title('Gender Distribution (Seaborn)')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Count')

# Adjusting the layout
plt.tight_layout()

# Displaying the plots
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# Counting the number of each class
pclass_counts = titanic['Pclass'].value_counts()

# Creating a figure and a set of subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

# Plotting the Pclass distribution using matplotlib
axes[0].bar(pclass_counts.index, pclass_counts.values, color=['blue', 'orange', 'green'])
axes[0].set_title('Pclass Distribution (Matplotlib)')
axes[0].set_xticks([1, 2, 3])
axes[0].set_xlabel('Pclass')
axes[0].set_ylabel('Count')

# Plotting the Pclass distribution using seaborn
sns.countplot(data=titanic, x='Pclass', ax=axes[1])
axes[1].set_title('Pclass Distribution (Seaborn)')
axes[1].set_xlabel('Pclass')
axes[1].set_ylabel('Count')

# Adjusting the layout
plt.tight_layout()

# Displaying the plots
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# Creating a box plot for the 'Age' column
sns.boxplot(data=titanic, y='Age')
plt.title('Box Plot of Age')
plt.ylabel('Age')
plt.show()

# %%
"""
A box plot (also known as a whisker plot) is a great way to visualize summary statistics (such as the median, quartiles, and possible outliers) of a feature.

In a box plot:

The box represents the interquartile range (IQR), which spans the 25th percentile (Q1) to the 75th percentile (Q3). This range contains the middle 50% of the values.
The line inside the box represents the median (50th percentile).
The whiskers represent the values outside the middle 50% (i.e., the values outside the box). The whiskers typically extend to the smallest and largest values within 1.5 times the IQR from the box.
Points outside the whiskers are considered outliers.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The box plot provides a summary of the distribution of the Age feature in the Titanic dataset. Here's what we can infer from the plot:

Median (the line inside the box): The median age of passengers on the Titanic was around 27-28 years. This means that half of the passengers were younger than this age and half were older.

Interquartile Range (the box itself): The box represents the interquartile range (IQR), which spans from the 25th percentile (Q1) to the 75th percentile (Q3). In this case, it indicates that 50% of the passengers were between approximately 21 and 38 years old.

Whiskers (the lines extending from the box): The whiskers of the box plot represent the range for the bulk of the data. The lower whisker extends to the minimum value within 1.5 * IQR of the first quartile, and the upper whisker extends to the maximum value within 1.5 * IQR of the third quartile. For this dataset, this range is approximately from 2 to 60 years.

Outliers (the points beyond the whiskers): The points beyond the whiskers are considered potential outliers. These suggest that there were a few passengers who were significantly older than the rest, with ages above 60 years.

Overall, the plot reveals that while the passenger ages on the Titanic ranged from infants to the elderly, the majority of passengers were young adults, between approximately 20 and 40 years old."""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# Creating a violin plot for the 'Age' column
sns.violinplot(data=titanic, y='Age')
plt.title('Violin Plot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The violin plot provides a combination of the information given by a box plot and a kernel density plot. In addition to the summary statistics provided by the box plot (median, quartiles, and potential outliers), the violin plot also shows the distribution of data.

Here's what we can infer from the violin plot of the Age feature:

Distribution: The shape of the violin plot, particularly the width at different points, shows the density of passengers at different ages. The widest part of the plot is around ages 20-30, indicating that a high number of passengers were in this age range.

Density: The width of the plot at different points shows the density of the data. Where the plot is wider, there is a higher density of passengers, and where it is narrower, there is a lower density of passengers.

Symmetry: The plot is slightly skewed towards the right, indicating that there were more young passengers than old passengers.

Outliers: The plot shows several points above the age of 60, which are considered potential outliers. This suggests that there were a few passengers significantly older than most.

The violin plot provides a more detailed representation of the age distribution compared to a box plot alone, as it shows not only the summary statistics but also the density and distribution of the data."""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# Creating a scatter plot for the 'Fare' and 'Age' columns using matplotlib
plt.scatter(titanic['Age'], titanic['Fare'], alpha=0.5)
plt.title('Relationship between Fare and Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
# Creating a scatter plot for the 'Fare' and 'Age' columns using seaborn
sns.scatterplot(data=titanic, x='Age', y='Fare')
plt.title('Relationship between Fare and Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# Calculate the correlation matrix
corr_matrix = titanic.corr()

# Create a heatmap of the correlation matrix using seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Titanic Dataset')
plt.show()
# Out:
# C:\Users\carmo\AppData\Local\Temp\ipykernel_22128\764735688.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = titanic.corr()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
From the correlation heatmap, we can observe that the most correlated features are:

Pclass and Fare with a correlation of approximately -0.55: This negative correlation suggests that as Pclass decreases (i.e., moving from third class to first class), the Fare generally increases. This makes sense because first-class tickets are typically more expensive than second- or third-class tickets.

SibSp and Parch with a correlation of approximately 0.41: This positive correlation indicates that passengers with more siblings or spouses on board (SibSp) also tend to have more parents or children on board (Parch). This suggests that larger families tend to travel together.

Please note that these correlations are moderate and do not suggest a strong linear relationship between the variables. Also, the interpretation of these correlations is based on the context of the variables and the Titanic dataset. The actual relationships between these variables may be influenced by other factors not included in this dataset."""
# Out:
# '\nFrom the correlation heatmap, we can observe that the most correlated features are:\n\nPclass and Fare with a correlation of approximately -0.55: This negative correlation suggests that as Pclass decreases (i.e., moving from third class to first class), the Fare generally increases. This makes sense because first-class tickets are typically more expensive than second- or third-class tickets.\n\nSibSp and Parch with a correlation of approximately 0.41: This positive correlation indicates that passengers with more siblings or spouses on board (SibSp) also tend to have more parents or children on board (Parch). This suggests that larger families tend to travel together.\n\nPlease note that these correlations are moderate and do not suggest a strong linear relationship between the variables. Also, the interpretation of these correlations is based on the context of the variables and the Titanic dataset. The actual relationships between these variables may be influenced by other factors
# ...

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# Creating a box plot for the 'Age' column for each 'Pclass'
sns.boxplot(data=titanic, x='Pclass', y='Age')
plt.title('Box Plot of Age by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# Creating a FacetGrid to plot the distribution of 'Age' based on 'Gender'
g = sns.FacetGrid(titanic, col='Gender')
g.map_dataframe(sns.histplot, x='Age', bins=30, color='blue')
plt.show()
