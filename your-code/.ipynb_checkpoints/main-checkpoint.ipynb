# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style
import matplotlib as mpl
import pandas as pd
import os
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.figure(figsize = (10,10))
plt.plot(x,y, 'g', linewidth=5, linestyle='-.')
plt.title('Plot(x,y)')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
plt.figure(figsize = (10,10))
plt.plot(x,z, 'ro', linewidth=5)
plt.title('Plot(x,z)')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, [plot1,plot2] =plt.subplots(nrows=1,ncols=2)
plot1.set_title('Plot(x,y)')
plot1.set_xlabel('x axis')
plot1.set_ylabel('y axis')
plot1.plot(x,y, 'g', linewidth=3, linestyle='-.')
plot2.set_title('Plot(x,z)')
plot2.set_xlabel('x axis')
plot2.set_ylabel('y axis')
plot2.plot(x,z, 'r+')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

plt.figure(figsize = (30,20))
fig, [plot1,plot2] = plt.subplots(nrows=1,ncols=2, figsize=(40,10))
plot1.set_title('Plot(x,y)',fontweight="bold", size=32)
plot1.set_xlabel('x axis', fontsize=28)
plot1.set_ylabel('y axis', fontsize=28)
plot1.plot(x,y, 'g', linewidth=5, linestyle='-.')
plot2.set_title('Plot(x,z)',fontweight="bold", size=32)
plot2.set_xlabel('x axis', fontsize=28)
plot2.set_ylabel('y axis', fontsize=28)
plot2.plot(x,z, 'ro', linewidth=5)

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

#normal scale

#Can be like this: plt.plot(x,x**2,x,np.e**x,'g')

plt.title('Normal Scale')
plt.plot(x,x**2)
plt.plot(x,np.e**x,'g')
plt.show()

#logarithmic scale
"""
Can be like this:
plt.plot(x,x**2,x,np.e**x,'g')
"""
plt.title('Logarithmic Scale')
plt.yscale('log')
plt.plot(x,x**2)
plt.plot(x,np.e**x,'g')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

#normal scale
plt.title('Normal Scale')
plt.plot(x,x**2, label="y=x^2")
plt.plot(x,np.e**x,'g', label="y=e^x")
plt.legend(loc="upper left")
plt.show()

#logarithmic scale
plt.title('Logarithmic Scale')
plt.yscale('log')
plt.plot(x,x**2, label="y=x^2")
plt.plot(x,np.e**x,'g', label="y=e^x")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

by_months = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()
by_months


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

by_work = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()
by_work


# Plotting
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
work_weeknd = ['Work','Weekend']

fig, ax = plt.subplots(1,2,figsize=(12,4))

plt.sca(ax[0])
plt.title('Median Steps by Month')
plt.xticks(by_months['Months_encoded'],labels=months,rotation=45)
plt.bar(by_months['Months_encoded'],by_months['Steps'])

plt.sca(ax[1])
plt.title('Median Steps by Work/Weekend')
plt.xticks(by_work['Work_or_Weekend'],labels=work_weeknd,rotation=45)
plt.bar(by_work['Work_or_Weekend'],by_work['Steps'])

plt.show()

if not (os.path.exists('figures')):
    os.makedirs('figures')
    
fig.savefig('figures/average_steps.png', facecolor='white')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

x=[fitbit['Minutes Lightly Active'],fitbit['Minutes Very Active'],fitbit['Minutes Sedentary']]
y=[fitbit['Steps'],fitbit['Steps'],fitbit['Steps']]
titles=['Minutes Lightly Active vs Steps','Minutes Very Active vs Steps','Minutes Sedentary vs Steps']

for i in range(3):
    plt.figure()
    plt.scatter(x[i],y[i])
    plt.title(titles[i])
    plt.xlabel('Minutes')
    plt.ylabel('Steps')
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(include='number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

display(titanic.select_dtypes(include='object'))

# Also can be:

display(titanic.select_dtypes(exclude='number'))
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

mpl.style.use('classic')

plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic['Age'])
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, ax = plt.subplots(1,3, figsize=(20,5))

plt.sca(ax[0])
plt.title('Distribution of Ages [bin=10]')
plt.hist(titanic['Age'], bins=10)

plt.sca(ax[1])
plt.title('Distribution of Ages [bin=20]')
plt.hist(titanic['Age'], bins=20)

plt.sca(ax[2])
plt.title('Distribution of Ages [bin=50]')
plt.hist(titanic['Age'], bins=50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

"""
The number of bins is helping to clarify the shape of the distributions so is more easy to see the distributions
"""
# Out:
# '\nThe number of bins is helping to clarify the shape of the distributions so is more easy to see the distributions\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

group_gender = titanic.groupby('Gender')['PassengerId'].agg('count').reset_index()

plt.bar(group_gender['Gender'],group_gender['PassengerId'])
plt.title('Passengers by gender')
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.barplot(x= group_gender['Gender'], y=group_gender['PassengerId']).set(title='Passengers by gender')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
group_gender = titanic.groupby('Pclass')['PassengerId'].agg('count').reset_index()

plt.bar(group_gender['Pclass'],group_gender['PassengerId'])
plt.xticks(list(set(group_gender['Pclass'])))
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

display(titanic['Age'].describe())

plt.plot(1,titanic['Age'].describe()['std'],'g^',label='std')
plt.plot(1,titanic['Age'].describe()['mean'],'go',label='mean')
#plt.plot(1,titanic['Age'].describe()['count'],'gx',label='count')
plt.boxplot(titanic['Age'])
plt.legend(loc="upper left")
plt.show()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
"""
your comments here
"""

"""
The Boxplot have the Min, Max, 25%, 50% (median) and 75% of the summary statistics, can add std and mean but count should not because then the visualization would not show information to analyze, count would be the highest outlier
"""
# Out:
# '\nThe Boxplot have the Min, Max, 25%, 50% (median) and 75% of the summary statistics, can add std and mean but count should not because then the visualization would not show information to analyze, count would be the highest outlier\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

"""
Seems that the ages are well distributed, with good size of the IQR and also the min (Q1 - 1.5*IQR) and max (Q3 + 1.5*IQR) values seems well balanced.
There are some outliers outside the max value.
The median is lower than the mean so this can indicate that the distribution is right skewed
"""
# Out:
# '\nSeems that the ages are well distributed, with good size of the IQR and also the min (Q1 - 1.5*IQR) and max (Q3 + 1.5*IQR) values seems well balanced.\nThere are some outliers outside the max value.\nThe median is lower than the mean so this can indicate that the distribution is right skewed\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

q25, q50, q75 = titanic['Age'].quantile(0.25), titanic['Age'].quantile(0.50), titanic['Age'].quantile(0.75)
quants = [[q25, 0.8, 0.26], [q50, 1, 0.36],  [q75, 0.8, 0.46]]
min_value = q25 - 1.5*(q75-q25)
max_value = q75 + 1.5*(q75-q25)

plt.hist(titanic['Age'], alpha=0.30, bins=50)

for i in quants:
    plt.axvline(i[0], alpha = i[1], ymax = i[2], linestyle = ":", linewidth = 2, color='black')

plt.axvline(min_value, alpha=1, ymax = 0.5, linestyle = '-')
plt.axvline(max_value, alpha=1, ymax = 0.5, linestyle = '-')

plt.text(q25, q25+10, "Q1", size = 11, alpha = 0.85)
plt.text(q50, q50+17, "Q2", size = 12, alpha = 1)
plt.text(q75, q75+19, "Q3", size = 11, alpha = 0.85)

plt.text(min_value, max_value, "min", size = 11, alpha = 0.85)
plt.text(max_value, max_value, "max", size = 11, alpha = 0.85)

plt.plot(titanic['Age'].describe()['std'],20,'g^',label='std')
plt.plot(titanic['Age'].describe()['mean'],20,'go',label='mean')
plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

"""
Maybe the distribution of the outliers and seems that 95% of the data is within 2 standard deviations
"""
# Out:
# '\nMaybe the distribution of the outliers and seems that 95% of the data is within 2 standard deviations\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Age'],titanic['Fare'])
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(x=titanic['Age'],y=titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
"""
SibSp and Parch
"""
# Out:
# '\nSibSp and Parch\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
 
dict = {}
for i in range(titanic['Pclass'].max()): 
    dict[i+1] =titanic[(titanic['Pclass']==i+1)]['Age'].describe().T.drop('count') #drop count value because is too large to show the boxplots

boxplot_df = pd.DataFrame(dict)
boxplot_df

plt.boxplot(boxplot_df)
plt.title('Statistic of Age depending on Pclass')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

dist = sns.FacetGrid(titanic, col='Gender', height=4)
dist.map(sns.histplot,'Age')
