# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 with plt.plot

plt.plot(x, y, label='y = 2x', linestyle='--', linewidth=2, color='b')
plt.title('y = 2x')
plt.legend()
plt.show()

plt.subplot(2, 1, 1)
plt.plot(x, z, label='z = x^2', linestyle='dotted', linewidth=2, color='g')
plt.title('z = x^2')
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2 using subplots
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(4, 4))

# Plotting y = 2x
ax[0].plot(x, y, color='blue', linestyle='-', linewidth=2, label='y = 2x')

# Plotting z = x^2
ax[1].plot(x, z, color='green', linestyle='--', linewidth=2, label='z = x^2')

# Adjusting layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
#Done above, where I set figsize=(4, 4) and I added title with plt.title and labels with plt.legend()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
#Let's create the functions
x = np.arange(-20, 20)
y_1 = x**2
y_2 = np.exp(x)

# Plot both functions
plt.figure(figsize=(8, 6))
plt.plot(x, y_1, label='y = x^2', color='blue')
plt.plot(x, y_2, label='y = e^x', color='green')

# Setting logarithmic scale
plt.yscale("log")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
#Let's create the functions
x = np.arange(-20, 20)
y_1 = x**2
y_2 = np.exp(x)

# Plot both functions
plt.figure(figsize=(8, 6))
plt.plot(x, y_1, label='y = x^2', color='blue')
plt.plot(x, y_2, label='y = e^x', color='green')

# Setting logarithmic scale
plt.yscale("log")

plt.title('Comparison of y = x^2 and y = e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pandas as pd

# %%
fitbit=pd.read_csv("Fitbit2.csv")

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
import os

# MEDIAN STEPS BY MONTH_ENCODED
median_steps_month=fitbit.groupby('Months_encoded').agg({'Steps':np.median}).reset_index()

median_steps_day = fitbit.groupby('Work_or_Weekend').agg({'Steps': np.median}).reset_index()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

# Plotting Median Steps by Month
plt.sca(axes[0])
plt.bar(median_steps_month['Months_encoded'], median_steps_month['Steps'], color='blue')
plt.title('Median Steps by Month')
plt.xlabel('Month')
plt.ylabel('Median Steps')


# Plotting Median Steps by Work_or_Weekend
plt.sca(axes[1])
plt.bar(median_steps_day['Work_or_Weekend'], median_steps_day['Steps'], color='green')
plt.title('Median Steps by Work or Weekend')
plt.xlabel('Day Type')
plt.ylabel('Median Steps')
plt.xticks([0, 1], ['Workday', 'Weekend'])

# Show the plots
plt.show()

# Create the 'figures' directory if it doesn't exist
if not os.path.exists('your-code/figures'):
    os.makedirs('your-code/figures')

# Save figures
plt.savefig('your-code/figures/median_steps_by_month_and_daytype.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=len(columns), figsize=(12, 6))

# Plot scatter plots for each column
for i, column in enumerate(columns):
    plt.sca(axes[i])
    plt.scatter(fitbit[column], fitbit['Steps'])
    plt.title(f'Scatter Plot: {column} vs Steps')
    plt.xlabel(column)
    plt.ylabel('Steps')

# Adjust layout and show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv("titanic.csv")

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_variables = titanic.select_dtypes(include=['int64', 'float64'])

print(numerical_variables.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
categorical_variables = titanic.select_dtypes(include=['object'])

print(categorical_variables.columns)
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
#We need to use a histogram
plt.hist(titanic['Age'], bins=10, color='blue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

for i, bins in enumerate([10, 20, 50]):
    plt.sca(axes[i])
    plt.hist(titanic['Age'], bins=bins, color='blue', edgecolor='black')
    plt.title(f'Distribution of Age (Bins={bins})')
    plt.xlabel('Age')
    plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
With less bins the data is more generalised and we cannot spot some peaks and valleys that we can see with the 
50 bins"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
import seaborn as sns

sns.histplot(data=titanic, x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

titanic['Gender'].value_counts().plot(kind='bar', color=['blue', 'pink'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Create a figure and axis with a size of (8, 6)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))

sns.countplot(x='Gender', data=titanic, palette=['blue', 'pink'], edgecolor='black')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x='Pclass', data=titanic)
plt.title('Distribution of Classes')
plt.xlabel('Passanger Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
#Let's use a boxplot for summarizing the summary statistics of Age

sns.boxplot(x='Age', data=titanic, color='skyblue', width=0.3)
plt.title('Summary Statistics of Age (Box Plot)')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Above 60 there is some significant "outliers"
The mean age is around 28
50% of the passenger were in the 22-38 age interval"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
#We can use a violin plot to see the distribution in addition with the summary statistics

sns.violinplot(x='Age', data=titanic, color='skyblue', inner='quartile')
plt.title('Distribution of Age with Summary Statistics (Violin Plot)')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
We can see for each interquartile range (IQR) the distribution of values. For example we can see young people
distribution"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# For this we can use a scatter plot to explore the relationship between variables

plt.scatter(titanic["Fare"], titanic["Age"], color='blue', marker='o', label='Scatter Plot')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot Fare<>Age')
# Out:
# Text(0.5, 1.0, 'Scatter Plot Fare<>Age')

# %%
#Let's fit a regression line to see the relationship

fit = np.polyfit(titanic["Fare"], titanic["Age"], 1)

plt.scatter(titanic["Fare"], titanic["Age"], color='blue', marker='o', label='Scatter Plot')
plt.plot(titanic["Fare"], fit[0] * titanic["Fare"] + fit[1], color='red', label='Fitted Line')


plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot Fare<>Age')
# Out:
# Text(0.5, 1.0, 'Scatter Plot Fare<>Age')

# %%
# Method 2 - seaborn
fit = np.polyfit(titanic["Fare"], titanic["Age"], 1)

sns.regplot(x='Fare', y='Age', data=titanic, scatter_kws={'color': 'blue', 'marker': 'o'}, line_kws={'color': 'red'})

plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot Fare vs Age with Fitted Line')
# Out:
# Text(0.5, 1.0, 'Scatter Plot Fare vs Age with Fitted Line')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
correlation_matrix = titanic.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.title('Correlation Matrix')
# Out:
# /var/folders/90/k9fypstn4y12th_l5jjxyxt00000gn/T/ipykernel_29319/3855608369.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = titanic.corr()
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
PClass and Fare have a negative correlation of 0.56, so this suggests that as one variable ('Pclass') increases,
the other variable ('Fare') tends to decrease, which doesn't make a lot of sense, since higher price normally is 
linked to a better passenger class
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic, width=0.5, palette='viridis')

plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Summary Statistics of Age by Pclass')
# Out:
# Text(0.5, 1.0, 'Summary Statistics of Age by Pclass')

# %%
#We see that the 1st class was crowded with older people

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender", height=6, aspect=0.7)

g.map(plt.hist, 'Age', bins=30, color='black', edgecolor='white')

# Add labels and title
g.set_axis_labels('Age', 'Frequency')
g.set_titles('Age Distribution by Gender')
g.add_legend()


plt.show()
