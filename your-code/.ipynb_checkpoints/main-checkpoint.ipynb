# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries

import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

#Graph 1
plt.plot(x, y,'b+')
plt.title("Graph 1")
plt.show()

#Graph 2
plt.plot(x, z, c='pink')
plt.title("Graph 2")
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, [graph_1, graph_2] = plt.subplots(1,2)

graph_1.plot(x,y)
graph_2.plot(x,z)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig, [graph_1, graph_2] = plt.subplots(1,2,figsize = (15,5))

graph_1.plot(x,y)
graph_1.set_title('GRAPH 1', fontsize=20)
graph_1.set_xlabel('x label')
graph_1.set_ylabel('y label')

graph_2.plot(x,z)
graph_2.set_title('GRAPH 2', fontsize=20)
graph_2.set_xlabel('x label')
graph_2.set_ylabel('y label')

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here


y=x^2

plt.plot(y)
plt.title("Plot Multiple lines in Matplotlib",fontsize=15)
plt.show()

y=x^2
plt.plot(y)
plt.yscale('log')
plt.show()


# "𝑒" is nor recognised by my computer..

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

y=x^2

plt.plot(y, label='Legend of the plot')
plt.title("Plot Multiple lines in Matplotlib",fontsize=15)
plt.legend()
plt.show()

plt.savefig("Ejemplo.jpg")

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit=pd.read_csv('Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

plt.figure(figsize=(12,4))
mean_steps=fitbit.groupby('Months_encoded').agg({'Steps':'mean'}).reset_index()

plt.bar(mean_steps['Months_encoded'],mean_steps['Steps'])
plt.savefig("Figure1.jpg")
plt.show()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

plt.figure(figsize=(5,10)) #if I use another size, we can not appreciate the difference between the bars
work_weekend_steps=fitbit.groupby('Work_or_Weekend').agg({'Steps':'mean'}).reset_index()

plt.bar(work_weekend_steps['Work_or_Weekend'],work_weekend_steps['Steps'])
plt.xticks([-0.25,0,0.25,0.5,0.75,1,1.25],[" ",'Work day'," "," "," ",'Weekend'," "])# I am assuming that the data in number 0 in te column Work_or_Weekend is related to work days and 1 to weekend days
plt.savefig("Figure2.jpg")
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

list=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for i in list:
    plt.scatter(fitbit[i],fitbit['Steps'])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic=pd.read_csv('titanic.csv')
titanic.head()

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(include=['int64','float64'])

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(include=['object'])

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

#with Matplotlib:
plt.style.use('classic')

#style with seaborn: sns.set_style('white')

plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic['Age'],50)
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, [plot1, plot2, plot3] = plt.subplots(1,3, figsize=(20,8))

plot1.hist(titanic['Age'],10)
plot2.hist(titanic['Age'],20)
plot3.hist(titanic['Age'],50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# Higher number of bins, more details about our distribution

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here


sns.distplot(titanic['Age'],100)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.barh(titanic['Gender'].unique(),titanic['Gender'].value_counts())

# %%
# Method 2 - seaborn
# your code here

sns.barplot(x=titanic['Gender'].unique(),y=titanic['Gender'].value_counts(),data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.barplot(x=titanic['Pclass'].unique(),y=titanic['Pclass'].value_counts(),data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

titanic.boxplot(column='Age')

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

#The mean is 29.8 so most people of my dataset could be considered as young people. 
#Based on the Histogram that I displayed above, most of them are between 22 (first quartile) and 37 (third quartile) 
#years old.The oldest person is 80 years old and the youngest is a baby. 
#Additionally, there are some outliers above 59 years old


#titanic['Age'].describe()

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

plt.figure(figsize =(40,35))
titanic.boxplot(column='Age')
plt.hist(titanic['Age'],50,orientation='horizontal', color='white')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Age'],titanic['Fare'])

# %%
# Method 2 - seaborn
# your code here

sns.pairplot(titanic)
#forth graph of the last line

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.heatmap(titanic.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

#PClass and Fare, PClass and Age,Age and SibSp, Survived and PClass

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.boxplot(x = 'Gender', y = 'Age', data = titanic)
