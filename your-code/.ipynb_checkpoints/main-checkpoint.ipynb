# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, linewidth=.7, color='blue')
plt.plot(x,z, linewidth=.7, color='orange')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(nrows=2, ncols=1)
ax[0].plot(x, y, linewidth=1, color='blue')
ax[1].plot(x, z, linewidth=1, color='orange')
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(4,4))
ax[0].plot(x, y, linewidth=1, color='blue')
ax[1].plot(x, z, linewidth=1, color='orange')
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y1 = x*2
y2 = np.exp(x)

# Prepare the plot area
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(4,4))

# first plot, in linear scale
ax[0].plot(x, y1, linewidth=1, color='blue')
ax[0].plot(x, y2, linewidth=1, color='orange')
ax[0].set_xscale('linear')
ax[0].set_yscale('linear')

# second plot in logarithmic scale
ax[1].plot(x, y1, linewidth=1, color='blue')
ax[1].plot(x, y2, linewidth=1, color='orange')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

x = np.arange(0,100)
y1 = x*2
y2 = np.exp(x)

# Prepare the plot area
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(4,4))

# first plot, in linear scale
ax[0].plot(x, y1, linewidth=1, color='blue', label=r'$y = x^2$')
ax[0].plot(x, y2, linewidth=1, color='orange', label=r'$y = e^x$')
ax[0].set_xscale('linear')
ax[0].set_yscale('linear')

# second plot in logarithmic scale
ax[1].plot(x, y1, linewidth=1, color='blue', label=r'$y = x^2$')
ax[1].plot(x, y2, linewidth=1, color='orange', label=r'$y = e^x$')
ax[1].set_xscale('log')
ax[1].set_yscale('log')

ax[0].legend()
ax[1].legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('fitbit2.csv')
fitbit.sample(5)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 130  2015-09-15            2821   9019      6.70      13              755.0
# 36   2015-06-13            4083  26444     19.65      22              549.0
# 89   2015-08-05            3326  14502     10.78      34              520.0
# 252  2016-01-15            3361  14837     11.37      11              687.0
# 301  2016-03-03            2864  11478      8.69      17              749.0
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 130                     144                     72                   25
# 36                      429                     56                   56
# 89                      250                     41                   59
# 252                     210                     58                   71
# 301                     167                      5                   45
#
#      Activity Calories  ...  Distance_miles       Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
median_month = fitbit.groupby('Months_encoded')['Steps'].median()

x = median_month.index
y = median_month

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
ax[0].plot(x, y, linewidth=1, color='blue')
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
ax[0].set_ylabel('Median Value')
ax[0].set_title('Median steps per Month')
ax[0].set_xticklabels(month_names)
ax[0].set_xticks(range(1,13))
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
median_weekend = fitbit.groupby('Work_or_Weekend')['Steps'].median()

x2 = median_weekend.index
y2 = median_weekend
ax[1].bar(x2, y2, linewidth=1, color='orange')
label_weekend = ['Weekdays', 'Weekend']
ax[1].set_title('Median steps per weekdays or weekend')
ax[1].set_xticklabels(label_weekend)
ax[1].set_xticks(range(0,2))
plt.show()
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_11536\391948140.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(month_names)
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_11536\391948140.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(label_weekend)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for feature in features:
    plt.scatter(fitbit['Steps'], fitbit[feature])
    plt.xlabel('Steps')
    plt.ylabel(feature)
    plt.title(feature +' '+ 'vs Steps')
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass                                     Name  \
# 830           831       1.0       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 373           374       0.0       1                      Ringhini, Mr. Sante
# 1150         1151       NaN       3                 Midtsjo, Mr. Karl Albert
# 1152         1153       NaN       3            Nilsson, Mr. August Ferdinand
# 421           422       0.0       3                      Charters, Mr. David
#
#       Gender   Age  SibSp  Parch      Ticket      Fare Cabin Embarked
# 830   female  15.0      1      0        2659   14.4542    U0        C
# 373     male  22.0      0      0    PC 17760  135.6333    U0        C
# 1150    male  21.0      0      0      345501    7.7750    U0        S
# 1152    male  21.0      0      0      350410    7.8542    U0        S
# 421     male  21.0      0      0  A/5. 13032    7.7333    U0        Q

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic_numeric = titanic.select_dtypes(include=['int', 'float'])
display(titanic_numeric.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
# your code here
titanic_categorical = titanic.select_dtypes(include=['object'])
display(titanic_categorical.dtypes)
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.boxplot(titanic['Age'])
plt.ylabel('Age')
plt.title('Box Plot of Age')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

# Plot with 10 bins
sns.histplot(data=titanic, x='Age', bins=10, ax=axes[0])
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Histogram with 10 bins')

# Plot with 20 bins
sns.histplot(data=titanic, x='Age', bins=20, ax=axes[1])
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Histogram with 20 bins')

# Plot with 50 bins
sns.histplot(data=titanic, x='Age', bins=50, ax=axes[2])
axes[2].set_xlabel('Age')
axes[2].set_ylabel('Frequency')
axes[2].set_title('Histogram with 50 bins')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The size of the bins affects the ability to identify clusters/areas of higher incidence, and therefore also the variability across
the dataset. Too little bins and it might be difficult to visualize any change/difference in the dataset. Too many bins and,
conversely, it will be hard to notice any meaningful differences.
"""
# Out:
# '\nThe size of the bins affects the ability to identify clusters/areas of higher incidence, and therefore also the variability across\nthe dataset. Too little bins and it might be difficult to visualize any change/difference in the dataset. Too many bins and,\nconversely, it will be hard to notice any meaningful differences.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.boxplot(y=titanic['Age'])
plt.ylabel('Age')
plt.title('Box Plot of Age')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender_counts = titanic['Gender'].value_counts().sort_index()
colors = ['#ff9999', '#66b3ff']
plt.bar(gender_counts.index, gender_counts.values, color=colors)
plt.ylabel('Count')
plt.title('Titanic passengers by gender')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='Accent')

# Set labels and title
plt.ylabel('Count', fontsize=12)
plt.title('Titanic passengers by gender', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.set(style="white")
pclass_counts = titanic['Pclass'].value_counts()
ax = sns.barplot(x=pclass_counts.index, y=pclass_counts.values, color='steelblue')

class_labels = ['First Class', 'Second Class', 'Third Class']
ax.set_xticklabels(class_labels)


plt.ylabel('Count', fontsize=12)
plt.title('Titanic passengers by type of class', fontsize=14)


plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(y=titanic['Age'])
plt.ylabel('Age')
plt.title('Summary statistics of Age')

# Get summary statistics
age_summary = titanic['Age'].describe()
count = age_summary['count']
std_dev = age_summary['std']
min_age = age_summary['min']
q1 = age_summary['25%']
median_age = age_summary['50%']
q3 = age_summary['75%']
max_age = age_summary['max']

# Add horizontal lines to represent the summary statistics
plt.axhline(y=min_age, color='r', linestyle='--', label='Min')
plt.axhline(y=q1, color='g', linestyle='--', label='Q1')
plt.axhline(y=median_age, color='b', linestyle='--', label='Median')
plt.axhline(y=q3, color='g', linestyle='--', label='Q3')
plt.axhline(y=max_age, color='r', linestyle='--', label='Max')

# Add text annotations for count and standard deviation
plt.text(0.61, (min_age + max_age) / 3, f"Count: {count}", color='black', fontsize=10, ha='left')
plt.text(0.61, (min_age + max_age) / 2.5, f"Standard Deviation: {std_dev:.2f}", color='black', fontsize=10, ha='left')

# Set the y-axis limits with some space before zero and after the maximum age
plt.ylim(bottom=min_age - 1, top=max_age + 1)

plt.legend()
plt.show()

# %%
"""
We used a box plot for the all summary statistics and added some text label for the count and standard
deviation
"""
# Out:
# '\nWe used a box plot for the all summary statistics and added some text label for the count and standard\ndeviation\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
It tells us that the age of the passengers on the Titanic, at least based on the dataset available,
was particularly young. 75% of the passenger were less than 40 years old.
"""
# Out:
# '\nIt tells us that the age of the passengers on the Titanic, at least based on the dataset available,\nwas particularly young. 75% of the passenger were less than 40 years old.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(y=titanic['Age'])
plt.ylabel('Age')
plt.title('Distribution of Age')

plt.text(0.61, (min_age + max_age) / 3, f"Count: {count}", color='black', fontsize=10, ha='left')
plt.text(0.61, (min_age + max_age) / 2.5, f"Standard Deviation: {std_dev:.2f}", color='black', fontsize=10, ha='left')


plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Using a violin plot we can visualize the distribution of the data and deduce that the most common
value is around 30 years old.
"""
# Out:
# '\nUsing a violin plot we can visualize the distribution of the data and deduce that the most common\nvalue is around 30 years old.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

fare = titanic['Fare']
age = titanic['Age']

# Create the scatter plot
plt.scatter(fare, age)
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot of Fare vs Age')

plt.show()

# %%
# Method 2 - seaborn
sns.scatterplot(x=fare, y=age)
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter Plot of Fare vs Age')

plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

corr_matrix = titanic.corr()

# Create the correlation matrix plot using Seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix: Titanic Dataset')

plt.show()
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_11536\3410207685.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = titanic.corr()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The features that are most correlated are the passenger class with the passenger fare and with the 
age. 
"""
# Out:
# '\nThe features that are most correlated are the passenger class with the passenger fare and with the \nage. \n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x=titanic['Pclass'], y=titanic['Age'])
plt.xlabel('Passenger class')
plt.ylabel('Age')
plt.title('Summary statistics of age by passenger class')

plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

# Create a FacetGrid with 'Gender' as the column variable
grid = sns.FacetGrid(data=titanic, col='Gender')

# Plot the distribution of 'Age' in each subplot
grid.map(sns.histplot, 'Age')

# Set the axis labels and title
grid.set_axis_labels('Age', 'Count')
grid.fig.suptitle('Distribution of Age by Gender')

# Adjust the subplot spacing
plt.tight_layout()

plt.show()
