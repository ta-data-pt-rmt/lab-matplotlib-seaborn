# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'g--',linewidth=0.75)
plt.plot(x,z,'bs',markersize=3)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

ax1.plot(x, y,'g--',linewidth=0.75)
ax1.set_title('y = x * 2')

ax2.plot(x, z,'bs',markersize=3)
ax2.set_title('z = x**2')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8, 6))

ax1.plot(x, y,'g--',linewidth=0.75)
ax1.set_title('y = x * 2',fontsize=10, fontweight='bold')
ax1.set_xlabel('X-axis', fontsize=10, fontweight='medium')
ax1.set_ylabel('Y-axis', fontsize=10, fontweight='medium')

ax2.plot(x, z,'bs',markersize=3)
ax2.set_title('z = x**2',fontweight='bold')
ax2.set_xlabel('X-axis', fontsize=10, fontweight='medium')
ax2.set_ylabel('Y-axis', fontsize=10, fontweight='medium')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,5,0.2)
y1=x**2
y2=np.exp(x)
plt.plot(x,y1,'ro',markersize=3)
plt.plot(x,y2,'gs',markersize=3)
plt.show()


plt.plot(x,y1,'ro',markersize=3)
plt.plot(x,y2,'gs',markersize=3)
plt.yscale('log')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x = np.arange(0,5,0.2)
y1=x**2
y2=np.exp(x)

plt.plot(x,y1,'ro',markersize=3, label=r'$y = x^2$')
plt.plot(x,y2,'gs',markersize=3,label=r'$y = e^x$')
plt.legend()
plt.show()


plt.plot(x,y1,'ro',markersize=3, label=r'$y = x^2$')
plt.plot(x,y2,'gs',markersize=3,label=r'$y = e^x$')
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
median_step_vs_month = fitbit.groupby('Months_encoded').median().reset_index()
median_step_vs_month
plt.figure(figsize=(12,4))
plt.plot(median_step_vs_month['Months_encoded'],median_step_vs_month['Steps'],'r')
plt.xticks(range(1, 13))

plt.xlabel('Month')
plt.ylabel('Median Steps')
plt.title('Median Steps by months')
plt.tight_layout()
plt.savefig('../your-code/figures/Median Steps by months.jpg')
plt.show()


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

median_step_vs_day = fitbit.groupby('Work_or_Weekend').median().reset_index()
median_step_vs_day
plt.figure(figsize=(4,6))
plt.bar(median_step_vs_day['Work_or_Weekend'],median_step_vs_day['Steps'])
x_values = {0:'Weekend', 1:'Work'}
plt.xticks(median_step_vs_day['Work_or_Weekend'], [x_values[val] for val in median_step_vs_day['Work_or_Weekend']])

plt.xlabel('Work and Weekend')
plt.ylabel('Median Steps')
plt.title('Median Steps by days')
plt.tight_layout()
plt.savefig('../your-code/figures/Median Steps by days.jpg')
plt.show()
# Out:
# /var/folders/4v/r9p762h55mn0ttvynz3ppd440000gn/T/ipykernel_11337/690952981.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_step_vs_month = fitbit.groupby('Months_encoded').median().reset_index()
# /var/folders/4v/r9p762h55mn0ttvynz3ppd440000gn/T/ipykernel_11337/690952981.py:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_step_vs_day = fitbit.groupby('Work_or_Weekend').median().reset_index()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

minutes_columns = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for column in minutes_columns:
    plt.scatter(fitbit[column],fitbit['Steps'], c='green')
    plt.xlabel(column)
    plt.ylabel('Steps')
    plt.title(column + ' '+ 'vs Steps')
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerical_variables = titanic.select_dtypes(include ='number')
numerical_variables
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
categorical_variables = titanic.select_dtypes(exclude ='number')
categorical_variables
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'], bins=50, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, (age1, age2,age3) = plt.subplots(nrows=1, ncols=3)

age1.hist(titanic['Age'], bins =10, color ='green')
age1.set_title('bin=10')

age2.hist(titanic['Age'], bins =20, color ='turquoise')
age2.set_title('bin=20')

age3.hist(titanic['Age'], bins =50, color = 'skyblue')
age3.set_title('bin=50')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
Large bin size creates more bars in the histogram. This increases quantity of bars presents a more detailed view of the data.
It enables the visualization to capture smaller, localized variations in the distribution, resulting in a more detailed data.
"""
# Out:
# '\nyour comments here\nLarge bin size creates more bars in the histogram. This increases quantity of bars presents a more detailed view of the data.\nIt enables the visualization to capture smaller, localized variations in the distribution, resulting in a more detailed data.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(titanic['Age'],bins=50)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Frequency')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender = pd.DataFrame(titanic['Gender'].value_counts())
gender = gender.rename(columns={'Gender':'count'})
plt.figure(figsize=(4,5))
plt.bar(gender.index, gender['count'], color = 'turquoise')
plt.xlabel('Gender')
plt.ylabel('Number')
plt.title('Total Gender Number')
plt.show()

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize = (4,5))
plt.title('Total Gender Number')
sns.countplot(data=titanic, x='Gender', palette ='pastel')
# Out:
# <Axes: title={'center': 'Total Gender Number'}, xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
plt.figure(figsize = (6,5))
plt.title('Distribution of Pclass')
sns.countplot(data=titanic, x='Pclass', palette ='pastel')
# Out:
# <Axes: title={'center': 'Distribution of Pclass'}, xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
display(titanic.describe())
plt.figure(figsize = (3,5))
sns.boxplot(data=titanic['Age'], palette ='pastel')
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.879186     0.498854
# std     378.020061    0.486592     0.837836    13.448335     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    22.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.500000     0.000000
# 75%     982.000000    1.000000     3.000000    37.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.281086
# std       0.865560    51.741500
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200
# <Axes: >

# %%
"""
your comments here
We can combine the summary statistics (min,max,25%,50% and 75%) in boxplot.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
The minimum Age is 0.
The maximum Age is 80. It looks like we have some outliers. 
Q3=around 38, Q1=around 20, IQR=18, outliers> 38+(18*1,5)=65z
The median (Q2 or 50%) is around 30, which is quite close to mean value.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.figure(figsize=(8,3))
sns.violinplot(data=titanic['Age'],orient='h', palette='pastel')
# Out:
# <Axes: >

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
We see the variation in thickness which signifies how common a value in Age column.
We see a central dot which indicates the median value.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Age'], titanic['Fare'], c='yellow')
plt.tight_layout()
plt.xlabel('Age')
plt.xlabel('Fare')
plt.title('Relationship between Age and Fare')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.regplot(data=titanic, x='Age', y='Fare', color='green')
plt.title('Relationship between Age and Fare')
# Out:
# Text(0.5, 1.0, 'Relationship between Age and Fare')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

correlation_matrix = titanic.select_dtypes(include='number').corr()
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f')
plt.title('Pearson Correlation Heatmap')
plt.show()

# correlation_matrix = titanic.select_dtypes(include='number').corr()
# plt.matshow(correlation_matrix)
# plt.colorbar()
# plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
The most correlated futures are between 'Parch' and 'SibSp' (correlation = 0,37 which is one the most close to 1.00)
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
plt.figure(figsize=(8, 6))
sns.boxplot(data=titanic, x='Pclass', y='Age', palette='pastel')
plt.title('Summary Statistics of Age by Passenger Class')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
dist_age_gender = sns.FacetGrid(titanic, col="Gender", height=4, aspect=1)
dist_age_gender.map(sns.histplot, 'Age', kde=True, bins=50)
dist_age_gender.set_axis_labels("Age", "Count")
dist_age_gender.set_titles("{col_name} - Age Distribution")
plt.show()
