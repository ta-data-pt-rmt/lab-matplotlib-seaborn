# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y,'b-',label='y=2*x')
plt.plot(x,z,'r-',label='z=x^2')
plt.title('Plots of y and z')
plt.xlabel('x')
plt.ylabel('y or z')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
#plt.subplots(nrows=1,ncols=2)
chart_options,(chart1,chart2) = plt.subplots(nrows=1,ncols=2)
chart1.bar(x,y,label='y=2x')
chart2.bar(x,z,label='z=x^2')
chart_options.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9156\4002576541.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   chart_options.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
plt.figure(figsize=(10,5))
#plt.subplots(nrows=1,ncols=2)
chart_options,(chart1,chart2) = plt.subplots(nrows=1,ncols=2)
chart1.bar(x,y,label='y=2x')
chart2.bar(x,z,label='z=x^2')
chart1.set_title('Plot of y=2x')
chart2.set_title('Plot of z=2^2')
chart1.set_xlabel('x')
chart2.set_xlabel('x')
chart1.set_ylabel('y')
chart2.set_ylabel('z')
chart_options.show()

#plt.subplots_adjust(wspace=0.6)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9156\2977659119.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   chart_options.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
plt.plot(x,y,'b-',label='y=x^2')
plt.plot(y,x,'y-',label='y=e^x')
plt.show()

# %%
x = np.linspace(0.1, 10, 100)

y1 = x ** 2
y2 = np.exp(x)

fig, ax = plt.subplots()

ax.plot(x, y1, label='y = x^2')
ax.plot(x, y2, label='y = exp(x)')

ax.set_xscale('log')  
ax.set_yscale('log')  

ax.legend()

ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
#cell above

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
import matplotlib.pyplot as plt
fitbit_short = fitbit[['Steps','Months_encoded','Work_or_Weekend']]
fitbit_short

data = fitbit_short.to_dict(orient='list')
data

df = pd.DataFrame(data)

median_steps_month = df.groupby('Months_encoded')['Steps'].median()
median_steps_month

plt.figure(figsize=(12,4))
plt.plot(median_steps_month)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
#grouped = fitbit_short.groupby('Work_or_Weekend')['Steps'].mean()
#if grouped[1]>grouped[0]:
 #   print("Fitbitter is more active on workdays.")
#else:
 #   print("Fitbitter is more active on weekends.")

workdays = df[df['Work_or_Weekend']== 1]['Steps']
weekends = df[df["Work_or_Weekend"]== 0]['Steps']

plt.figure(figsize=(10, 6))
sns.histplot(workdays, kde=False, color='green', label='Workdays')
sns.histplot(weekends, kde=False, color='pink', label='Weekends')
plt.xlabel('Steps')
plt.ylabel('Frequency')
plt.title('Step on Workdays vs Weekends')
plt.legend()
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fit_bit = fitbit[['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']]
fit_bit

feature_pairs = [
    ('Minutes Lightly Active', 'Steps'),
    ('Minutes Sedentary', 'Steps')
     ('Minutes Sedentary', 'Steps')
]
 
#nothing I have tried was working after this step..:(
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Steps'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 12
#      10 for i, (x_feature, y_feature) in enumerate(feature_pairs, 1):
# ...

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_columns = titanic.select_dtypes(include=['int64','float64'])
numerical_columns
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
categorical_columns= titanic.select_dtypes(include=['object'])
categorical_columns
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

plt.plot(titanic['Age'][:100],titanic['Fare'][:100],'*')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.figure(figsize=(12, 6))
plt.hist(titanic['Age'], bins=36, alpha=1,color='g')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Number of people')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
#plt.subplots(nrows=1,ncols=3)
chart_options,(chart1,chart2,chart3) = plt.subplots(nrows=1,ncols=3)

chart1.hist(titanic['Age'], bins=10, color='b')
chart1.set_title('Histogram with 10 Bins')
chart1.set_xlabel('Age')
chart1.set_ylabel('Frequency')

chart2.hist(titanic['Age'], bins=20, color='g')
chart2.set_title('Histogram with 20 Bins')
chart2.set_xlabel('Age')
chart2.set_ylabel('Frequency')

chart3.hist(titanic['Age'], bins=50, color='r')
chart3.set_title('Histogram with 50 Bins')
chart3.set_xlabel('Age')
chart3.set_ylabel('Frequency')

plt.tight_layout()
chart_options.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9156\825881217.py:20: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   chart_options.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The higher number the bin has, the more detailed data visualization we get
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(titanic['Age'], bins=30, kde=False, color='b')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=titanic)  
plt.title('Passengers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_counts = titanic['Gender'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index,autopct='%1.1f%%')
plt.title('Passengers by Gender')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code hereplt.figure(figsize=(8, 6))
sns.countplot(x='Pclass', data=titanic)  
plt.title('Number of passengers by Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x='Age', data=titanic, color='pink')
plt.title('Box Plot for Age')
plt.xlabel('Age')
plt.show()

# %%
"""
A box plot represents Age here the best, as we can see the spread of ages, median and outliers at the same time.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
50% of the passengers fall between 20-40 years, the median of the total age is around 29.Only a small amount of pessenger are 60 or above.
"""
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
plt.figure(figsize=(8, 6))
sns.boxenplot(x='Age', data=titanic, color='pink')

plt.title('Boxen Plot for Age')
plt.xlabel('Age')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Data spread is visualized better, shows multiply levels of the data.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(titanic['Age'][:100], titanic['Fare'][:100], alpha=1, c='b',s=50)
plt.title('Scatter Plot of Fare vs Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
sns.jointplot(x='Age', y='Fare', data=titanic, kind='hex', color='blue',gridsize=30)

plt.suptitle('Hexbin Plot of Fare vs. Age', y=1.02)  
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr_matrix = numerical_columns.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Age', data=titanic_df)

plt.title('Box Plot of Age by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Age')


plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic_df, col='Gender', height=6, aspect=1.5, sharex=True, sharey=True)

g.map(sns.histplot, 'Age', bins=20, kde=False, color='yellow')

g.set_titles(col_template="{col_name} Gender")
g.set_axis_labels("Age", "Count")

plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
