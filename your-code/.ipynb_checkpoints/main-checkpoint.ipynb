# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
x = np.arange(0,100)
y = x*2
z = x**2


plt.plot(x,y,label ='y', c='red')
plt.plot(x,z,label ='z', c='green')

plt.xlabel('x')
plt.ylabel('y')
plt.title("Data")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig,ax = plt.subplots(nrows=1, ncols=2)

# ploting y = 2x
ax[0].plot(x,y, c ="green")
ax[0].set_title('y = 2x')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')

# ploting z = X^2
ax[1].plot(x, z, c = "blue")
ax[1].set_title('z = X^2')
ax[1].set_xlabel('x')
ax[1].set_ylabel('y')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# ploting y = 2x
ax[0].plot(x,y, c ="green")
ax[0].set_title('y = 2x', fontsize =18, fontweight='bold')
ax[0].set_xlabel('x', fontweight='bold')
ax[0].set_ylabel('y', fontweight='bold')

# ploting z = X^2
ax[1].plot(x, z, c = "blue")
ax[1].set_title('z = X^2', fontsize =18, fontweight='bold')
ax[1].set_xlabel('x', fontweight='bold')
ax[1].set_ylabel('y', fontweight='bold')

# plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.linspace(0,5,100)

y1 = x**2
y2 = np.exp(x)

fig, ax = plt.subplots(figsize=(6,4))

ax.plot(x, y1, label='y = x^2', color='blue')
ax.plot(x, y2, label='y = e^x', color='red')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Normal and Logarithmic Scale')
ax.set_xscale('log')
ax.set_yscale('log')


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
x = np.linspace(0,5,100)

y1 = x**2
y2 = np.exp(x)

fig, ax = plt.subplots(figsize=(6,4))

ax.plot(x, y1, label='y = x^2', color='blue')
ax.plot(x, y2, label='y = e^x', color='red')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Normal and Logarithmic Scale')
ax.legend()
ax.set_xscale('log')
ax.set_yscale('log')


plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('/Users/jochemmeesters/Documents/Ironhack_DA/week4/week4day2/lab-matplotlib-seaborn/your-code/Fitbit2.csv')
fitbit.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
median_by_month = fitbit['Months_encoded'].median()
print("Median steps by month is:", median_by_month)

# MEDIAN STEPS BY WORK_OR_WEEKEND
median_by_work_or_weekend = fitbit['Work_or_Weekend'].median()
print("Median by work or weekend is:", median_by_work_or_weekend)
# Out:
# Median steps by month is: 7.0
# Median by work or weekend is: 1.0

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
fig, axes = plt.subplots(1,3, figsize=(12,4))

for i, feature in enumerate(features):
    ax = axes[i]
    ax.scatter(fitbit[feature], fitbit['Steps'])
    ax.set_xlabel(feature)
    ax.set_ylabel('Steps')
    ax.set_title(f'{feature} vs Steps')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
dataset = titanic.dtypes
dataset
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numeric = titanic.select_dtypes(include = 'number')
numeric
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
catergorical = titanic.select_dtypes(include = 'object')
catergorical
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12, 6))
data = titanic[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
sns.pairplot(data, hue = 'Survived')

plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
ages = titanic['Age'].dropna() 
plt.hist(ages, bins= 10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
ages = titanic['Age'].dropna()

plt.figure(figsize=(8,6))
custom_bins = [10, 20, 50]
plt.hist(ages, bins= custom_bins)
# plt.figure(figsize=(4,3))plt.xlabel('Age')
plt.ylabel('Number of survivors')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""Smaller bins provide more details and help identifying subtle patterns. 
Larger bins or fewer and wider intervals can smooth out the distribution and highlight a pattern of data 
Choosing the larger bins size can impact visulization because each bins are aggregated together and create 
the appearance of clustered data which leading to loss of details"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic, x= "Age")

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

gender_counts = titanic['Gender'].value_counts()
genders = gender_counts.index
counts = gender_counts.values

plt.figure(figsize=(8,6))
plt.bar(genders, counts, width = 0.5)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distrubution of Gender')
plt.show()

# %%
# Method 2 - seaborn

plt.figure(figsize=(8,6))
sns.countplot(data =titanic, x = 'Gender')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=titanic, x='Pclass')

plt.xlabel('Pclass')
plt.ylabel('Count')
plt.title('Distribution of Passenger Class (Pclass)')

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=titanic, y = 'Age', width = 0.3)

plt.ylabel('Age')
plt.title('Summary Statistics of Age')
plt.show()

# %%
"""I choose to use box plot becuase it gives summary of statistics of the dataset and visualize distribution 
of the variables. It represents min, max, mean, 25th percentile and 75% percentile."""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
""" The plot represents the interquartile range between Q1(25%) and Q3(75%). It contains 50% of data
which is the mean of the dataset.Line inside the box represents the median. It provides a measure of 
central tendency. This case we have a systemrical distribution. Any data points beyond the whiskers are plotted as individual points and are considered 
potential outliers.Age distribution is between 22-38 and median is around 28. Above 60's are outliers"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# import seaborn as sns
# sns.violinplot("Combined MPG", data=data)

plt.figure(figsize=(8, 6))
sns.violinplot(data=titanic, y= "Age", inner= 'quart', color="lightblue")

plt.xlabel('Age')
plt.title('Summary Statistics and Distribution of Age')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""This violine plot shows both the distribtuion of age and the sumarry statistics wiht the quartile lines
inside the plot. The width of the plot of each age level represents density of data points. Wider section means 
higher density and narrower section represents lower density, The plot shows that the data is more concentrated
around 22-38 yrs."""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

plt.figure(figsize=(8, 6))
plt.scatter(titanic['Age'], titanic['Fare'])

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Fare vs Age')
plt.show()

# %%
# Method 2 - seaborn

plt.figure(figsize=(8, 6))
sns.regplot(data=titanic, x='Age', y='Fare')

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Fare vs Age')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
correlation_matrix = titanic.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True)#            
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""In a correlation matrix, values close to 1 indicate a strong positive correlation and values close to -1
indicate a strong negative corrlations. The most correlated features are Pclass vs Fare 
and SibSp vs Parch"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.figure(figsize =(8,6))

sns.boxplot(data=titanic, x='Pclass', y='Age', width =0.5)
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Summary Statistics of Age by Pclass')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender", height = 5)
g.set_axis_labels("Age", "Count")
g.set_titles("Gender:{col_name}")
g.fig.suptitle("Distribution of age by gender", size = 16)
g.map(sns.histplot, "Age", bins=20)
g.tight_layout()
plt.show()
