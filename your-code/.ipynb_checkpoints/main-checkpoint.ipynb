# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 - Subplot

plt.figure(figsize=(12, 6))

# Subplot 1: (x, y)
plt.subplot(1, 2, 1) #row, col, index
plt.plot(x, y, 'y-', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('(x, y) Plot')

# Subplot 2: (x, z)
plt.subplot(1, 2, 2)
plt.plot(x, z, 'b-', linewidth=2)
plt.xlabel('x')
plt.ylabel('z')
plt.title('(x, z) Plot')


plt.tight_layout()


plt.show()

# %%
# Method 2: Using plt.subplots with 1 row and 2 columns

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot (x, y)
axs[0].plot(x, y, label='y = 2x', color='yellow', linestyle='--', linewidth=2)

# Plot (x, z)
axs[1].plot(x, z, label='z = x^2', color='blue', linestyle='-', linewidth=2)

axs[0].set_title('(x, y) Plot')
axs[1].set_title('(x, z) Plot')
axs[0].set_xlabel('x')
axs[1].set_xlabel('x')
axs[0].set_ylabel('y')
axs[1].set_ylabel('z')

plt.show()

# %% [markdown]
# Méthode 1 :plt.subplot(rows, cols, index)
#
# Cette méthode utilise la plt.subplot()fonction pour créer des sous-intrigues une par une.
# Vous spécifiez le nombre de lignes ( rows), de colonnes ( cols) et le indexnombre de sous-tracés actuels dans la grille.
# Il offre plus de contrôle sur le placement et la disposition des sous-parcelles lorsque vous souhaitez créer une mise en page personnalisée.
# Vous spécifiez manuellement la position actuelle du sous-tracé pour chaque tracé, ce qui offre une certaine flexibilité dans l'organisation des sous-tracés.
#
#
# Méthode 2 :plt.subplots(nrows, ncols, index)
#
# Cette méthode utilise la plt.subplots()fonction pour créer une grille de sous-parcelles.
# Vous spécifiez le nombre de lignes ( nrows) et de colonnes ( ncols) dans la grille, ainsi que le indexparamètre permettant de spécifier la position actuelle du sous-tracé.
# Il fournit un moyen simple de créer des sous-tracés sous forme de grille.
# Vous pouvez accéder directement à chaque sous-tracé à l'aide d'un tableau 2D, tel que axes[row, col].

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, axes = plt.subplots(nrows=1, ncols=2)

# Plot the first function
axes[0].plot(x, y, color='blue', lw=2, linestyle='--')
axes[0].set_title('Linear Function', fontsize=16, fontweight='bold')
axes[0].set_xlabel('X', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Y', fontsize=12, fontweight='bold')

# Plot the second function
axes[1].plot(x, z, color='red', lw=2, linestyle='-.')
axes[1].set_title('Quadratic Function', fontsize=16, fontweight='bold')
axes[1].set_xlabel('X', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Y', fontsize=12, fontweight='bold')

# Add a title to the entire figure
fig.suptitle('Comparison of Functions', fontsize=18, fontweight='bold')

# Adjust the layout to prevent overlapping elements
#plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Plot the first function
axes[0].plot(x, y, color='blue', lw=2, linestyle='--')
axes[0].set_title('Linear Function', fontsize=16, fontweight='bold')
axes[0].set_xlabel('X', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Y', fontsize=12, fontweight='bold')

# Plot the second function
axes[1].plot(x, z, color='red', lw=2, linestyle='-.')
axes[1].set_title('Quadratic Function', fontsize=16, fontweight='bold')
axes[1].set_xlabel('X', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Y', fontsize=12, fontweight='bold')

# Add a title to the entire figure
fig.suptitle('Comparison of Functions', fontsize=18, fontweight='bold')

# Adjust the layout to prevent overlapping elements
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

# Calculate y values for y = x^2 and y = e^x
x = np.arange(0,100)

y1 = x**2

y2 = np.exp(x)

#Subplots method
fig, ax = plt.subplots()

ax.plot(x, y1, label='y = x^2', linestyle='-', color='b')

ax.plot(x, y2, label='y = e^x', linestyle='--', color='r')

# Set the x-axis to a logarithmic scale
ax.set_xscale('log')

# Set the y-axis to a logarithmic scale
ax.set_yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

fig, ax = plt.subplots()

ax.plot(x, y1, label='y = x^2', linestyle='-', color='b')

ax.plot(x, y2, label='y = e^x', linestyle='--', color='r')

# Set the x-axis to a logarithmic scale
ax.set_xscale('log')

# Set the y-axis to a logarithmic scale
ax.set_yscale('log')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Comparison of Functions in Logarithmic Scale')
ax.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

import pandas as pd

fitbit = pd.read_csv('fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
monthly_steps = fitbit.groupby('Months')['Steps'].median()

# MEDIAN STEPS BY WORK_OR_WEEKEND
work_vs_weekend = fitbit.groupby('Work_or_Weekend')['Steps'].median()

# Create a gridspec specifying subplot positions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot the first subplot
monthly_steps.plot(kind='bar', ax=ax1, color='skyblue')
ax1.set_title('Median Steps by Month')
ax1.set_ylabel('Median Steps')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)

# Plot the second subplot
work_vs_weekend.plot(kind='bar', ax=ax2, color='lightcoral')
ax2.set_title('Workdays vs. Weekends')
ax2.set_ylabel('Median Steps')
ax2.set_xlabel('Day Type')  

# Customize the x-axis labels for clarity
day_type_labels = ['Weekend', 'Workday']
ax2.set_xticks(range(2))
ax2.set_xticklabels(day_type_labels, rotation=45)  # Adjust rotation

# Add text to the bars to show the exact values
for ax in (ax1, ax2):
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Save the figure
plt.savefig('/Users/amandine/Downloads/fitbit_visualizations.png')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, feature in enumerate(features):
    ax = axes[i]
    ax.scatter(fitbit['Steps'], fitbit[feature], alpha=0.5)
    ax.set_xlabel('Steps')
    ax.set_ylabel(feature)
    ax.set_title(f'Scatter Plot: Steps vs {feature}')

plt.tight_layout()

plt.show()

#Scatter compare le nombre de minutes actives avec le nombre de pas

# %%
import matplotlib.ticker as ticker  # Import the ticker module

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(17, 5))

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)  # You can change the spacing by adjusting the "wspace" value

# Define the features you want to plot
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

# Loop through the features and create scatter plots with different color gradations
for i, feature in enumerate(features):
    ax = axes[i]
    sc = ax.scatter(fitbit['Steps'], fitbit[feature], c=fitbit[feature], cmap='viridis', alpha=0.5)
    ax.set_xlabel('Steps')
    ax.set_ylabel(feature)
    ax.set_title(f'Scatter Plot: Steps vs {feature}')

    # Set the lower limits of the x and y axes to 0
    ax.set_xlim(0, fitbit['Steps'].max())
    ax.set_ylim(0, fitbit[feature].max())

    # Set a minimum limit for the color scale (values under 0 will not be displayed)
    sc.set_clim(0, sc.get_array().max())

    # Add a colorbar to the plot
    cbar = plt.colorbar(sc, ax=ax)
    cbar.set_label(f'Color Gradation ({feature})')

    # Increase the spacing between color scale values
    cbar.locator = ticker.MaxNLocator(nbins=5)
    cbar.update_ticks()

# Show the plots
plt.show()

# %% [markdown]
# Notes:
# - Dependant variable always go in vertical axis (y) / independant variable goes on the horizontal axis (x).
#
#
# - Goal : visualiser la relation entre le nombre de pas (variable indépendante) et trois caractéristiques différentes : « Minutes légèrement actives », « Minutes très actives » et « Minutes sédentaires » (variables dépendantes). . Les nuages de points aident à explorer comment chacune de ces caractéristiques (variables dépendantes) change le nombre de pas (variable indépendante).
#
# - variable dépendante : variables que vous essayez de comprendre ou de prédire en fonction de la variable indépendante.
# - variable indépendante : variable utilisée pour catégoriser ou mesurer la relation avec d'autres variables.

# %%
# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(17, 5))

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4)  # You can change the spacing by adjusting the "wspace" value

# Loop through the features and create scatter plots with different color gradations
for i, feature in enumerate(features):
    ax = axes[i]
    if feature == 'Minutes Lightly Active':
        sc = ax.scatter(fitbit['Steps'], fitbit[feature], c=color_var1, cmap='viridis', alpha=0.5)
    elif feature == 'Minutes Very Active':
        sc = ax.scatter(fitbit['Steps'], fitbit[feature], c=color_var2, cmap='viridis', alpha=0.5)
    elif feature == 'Minutes Sedentary':
        sc = ax.scatter(fitbit['Steps'], fitbit[feature], c=color_var3, cmap='viridis', alpha=0.5)
    ax.set_xlabel('Steps')
    ax.set_ylabel(feature)
    ax.set_title(f'Scatter Plot: Steps vs {feature}')
    
    # Add a colorbar to the plot
    cbar = plt.colorbar(sc, ax=ax)
    cbar.set_label(f'Color Gradation ({feature})')

# Show the plots
plt.show()

# %% [markdown]
# - Steps vs Minutes lightly active:
# positive relationship between number of steps and minutes spent to be slightly active
# the more minutes you are slightly active, the more steps you do.
# Linear relationship but points very spread out, so quiete weak lienar relationship (?).
#
#
# - Steps vs Minutes Sedentary: negative correlation (the more minutes I spend being sedentary, the less steps I do).

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

numerical_variables = titanic.select_dtypes(include=['number'])
#also works : titanic.select_dtypes(include=['int64', 'float64'])

print("Numerical Variables:")
print(numerical_variables.columns)
# Out:
# Numerical Variables:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here

categorical_variables = titanic.select_dtypes(include=['object'])

print("Categorical Variables:")
print(categorical_variables.columns)
# Out:
# Categorical Variables:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')

plt.figure(figsize=(12, 6))

# Countplot of passengers by Pclass
plt.subplot(1, 2, 1) #keeping grid for smaller display
#plt.subplot(1, 2, 1) means the first subplot in a 1x2 grid.
#plt.subplot(1, 2, 2) would be the second subplot in the same 1x2 grid.

sns.countplot(data = titanic, x='Embarked')

plt.title('Passengers by Port of Embarkation')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.figure(figsize=(8, 6))
plt.hist(titanic['Age'], bins=20, color='lightblue', edgecolor='lightseagreen')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

bin_sizes = [10, 20, 50]

fig, axes = plt.subplots(1, len(bin_sizes), figsize=(18, 6))

for i, bin_size in enumerate(bin_sizes):
    ax = axes[i]
    ax.hist(titanic['Age'], bins=bin_size, color='skyblue', edgecolor='black')
    ax.set_title(f'Age Distribution (Bins = {bin_size})')
    ax.set_xlabel('Age')
    ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# The bin size affects the granularity of the data distribution.
# Bins determine the size of intervals to divide the data and influence how the data are displayed on the histogram.
#
# - Smaller bin size = more bins, and each bin will cover a narrower range of values. This results in more detailed information about the distribution (more granular to display more variations).
#
# - Fewer bins = A larger bin size groups more data points into each bin, reducing the number of bins (each bin covers a broader range of values).
# Useful to provide a general overview (for identifying broad trends and general patterns).

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.set_style("whitegrid")

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 2)
sns.histplot(data= titanic, x='Age', kde=True, color='#ffcc99')
mean_age = titanic['Age'].mean()
plt.axvline(mean_age, color='red', linestyle='dashed', linewidth=2, label=f'Mean Age: {mean_age:.1f}')
plt.legend()
plt.title('Distribution of Passenger Ages')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender_counts = titanic['Gender'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()

# %%
gender_counts = titanic['Gender'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, colors=['blue', 'pink'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender', y=1.08)
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

plt.show()

# %%
# Method 2 - seaborn
# your code here

#plt.style.use('seaborn') -> depreciated, do not use, try instead:

sns.set_style('whitegrid')

plt.figure(figsize=(12, 6))
# Countplot of passengers by gender
plt.subplot(1, 2, 1)
sns.countplot(data = titanic, x='Gender')
plt.title('Passengers by gender')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.set(style='whitegrid', palette='pastel')

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.countplot(data=titanic, x='Pclass')
plt.title('Passengers by classes')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

plt.figure(figsize=(8, 6))

sns.boxplot(data=titanic, y='Age', palette='pastel')
plt.title('Summary Statistics of Age')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.violinplot(data=titanic, y='Age', palette='pastel')

plt.title('Summary Statistics of Age')

plt.show()

# %% [markdown]
# Box plots show essential summary statistics of the data, such as the median, quartiles, and potential outliers. This information provides an immediate sense of the central tendency and variability of the data.

# %%
titanic['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(11, 4))

# Create a horizontal bar chart to display the summary statistics
summary = titanic['Age'].describe()
summary.plot(kind='barh', color='coral', ax=ax)

# Add labels for each summary statistic
for i, v in enumerate(summary):
    ax.text(v + 1, i, str(round(v, 2)), color='black', va='center', fontsize=12)

# Set labels and title
ax.set_xlabel("Value")
ax.set_title("Summary Statistics of Age")

# Display the plot
plt.show()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %% [markdown]
# The median age is 28.5 years.
# The mean age is 29.88.
# Std at 13,45, which suggest that ages vary around the mean age.
# More spread between Q2 and Q3, than Q1 and Q2. It suggests the data for age is more skewed to the right.

# %%
# Define the age groups
age_bins = [0, 18, 30, 50, 100]  # Customize the age groups as needed
age_labels = ['0-18', '19-30', '31-50', '51+']  # Labels for each age group

# Use pd.cut() to create a new column with age groups
titanic['AgeGroup'] = pd.cut(titanic['Age'], bins=age_bins, labels=age_labels)

# Plot the distribution of passengers in each age group
plt.figure(figsize=(10, 6))
titanic['AgeGroup'].value_counts().sort_index().plot(kind='bar', color='wheat')
plt.title('Distribution of Passengers by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Passengers')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Box plot for age
sns.boxplot(data=titanic, y='Age', ax=axes[0])
axes[0].set_title('Box Plot: Age')
axes[0].set_ylabel('Age')

# Histogram for age
sns.histplot(data=titanic, x='Age', bins=20, ax=axes[1], kde=True)
axes[1].set_title('Histogram: Age')
axes[1].set_xlabel('Age')

plt.tight_layout()

plt.show()

# %%
# Create a figure with subplots
fig, ax = plt.subplots(figsize=(12, 5))

# Create a histogram for Age
sns.histplot(data=titanic, x='Age', bins=20, ax=ax, kde=True)
ax.set_title('Histogram: Age')
ax.set_xlabel('Age')

# Stock summary statistics into variable to loop through it
age_summary = titanic['Age'].describe()

# Define line colors for each summary info
line_colors = {
    'mean': 'red',
    '25%': 'blue',
    '50%': 'green',
    '75%': 'purple',
    'min': 'orange',
    'max': 'pink'
}

# Add mean, median, IQR, min, and max to the histogram
for param, value in age_summary.items():
    if param in line_colors:
        ax.axvline(value, color=line_colors[param], linestyle='dashed', linewidth=2, label=f'{param}: {value:.2f}')

ax.legend()

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %% [markdown]
# - Box Plot:
#
# Provides a summary of the data's distribution, including the median. Useful to emphasizes the spread, central tendency, and the presence of outliers.
# Gives a concise overview of the data's statistical properties.
# Doesn't show the exact data distribution or density.
#
# - Histogram (Histplot):
#
# Visualizes the entire data distribution by dividing it into intervals (bins).
# Shows the frequency or count of data points in each bin.
# Gives insights into the data's shape, skewness...
# Provides a more detailed view of the data's distribution.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.figure(figsize=(8, 6))
plt.scatter(titanic['Age'], titanic['Fare'], alpha=0.5, color='blue')
plt.title('Scatter Plot: Fare vs Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)

plt.show()

# %%
# Method 2 - seaborn - Regression plot
# your code here

plt.figure(figsize=(8, 6))
sns.regplot(data=titanic, x='Age', y='Fare', scatter_kws={'alpha':0.5, 'color':'blue'}, line_kws={'color':'red', 'alpha':0.7})
plt.title('Regression Plot: Fare vs Age')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit and transform the Age and Fare columns
titanic[['Age_normalized', 'Fare_normalized']] = scaler.fit_transform(titanic[['Age', 'Fare']])

# Now, the 'Age' and 'Fare' columns are scaled to the range [0, 1]

# %%
sns.scatterplot(data=titanic, x='Fare_normalized', y='Age_normalized', color='blue')
plt.title('Scatter Plot: Fare vs Age (Normalized)')
plt.xlabel('Fare (Normalized)')
plt.ylabel('Age (Normalized)')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
import warnings
warnings.filterwarnings('ignore')

titanic.drop(['Age_normalized',  'Fare_normalized'], axis=1, inplace=True)

# your code here
print(titanic.corr()) 
  
# plotting correlation heatmap 
dataplot = sns.heatmap(titanic.corr(), cmap="YlGnBu", annot=True) 
  
# displaying heatmap 
plt.show()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### What are the most correlated features?

# %% [markdown]
# - Survived and Pclass: - 0.34
# - Survived and Fare = 0.26
# - Pclass and Fare: = - 0.56
# - Age and Pclass = - 0.43

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.figure(figsize=(10, 6))  
sns.boxplot(x="Pclass", y="Age", data=titanic)

plt.xlabel("Pclass")
plt.ylabel("Age")
plt.title("Summary Statistics of Age by Pclass")

# Show the plot
plt.show()

# %%
grid = sns.FacetGrid(titanic, col='Pclass', height=6) 
grid.map(sns.kdeplot, 'Age', shade=True)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
grid = sns.FacetGrid(titanic, col='Gender', height=6) 
grid.map(sns.kdeplot, 'Age', shade=True)
sns.despine(left=True, bottom=True)
plt.show()
