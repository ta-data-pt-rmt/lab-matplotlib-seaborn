# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y)
plt.show()
plt.plot(x,z)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y)
ax2.plot(x, z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,8))
ax1.plot(x, y)
ax1.set_ylabel('x axis',fontsize=12)
ax1.set_xlabel('y axis',fontsize=12)
ax2.plot(x, z)
ax2.set_ylabel('x axis',fontsize=12)
ax2.set_xlabel('z axis',fontsize=12)
ax1.set_title('x & y plot',fontsize=28,fontweight="bold")
ax2.set_title('x & z plot',fontsize=28,fontweight="bold")
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y = x**2
e = 2.71828 # https://www.mathcentre.ac.uk/resources/uploaded/mc-bus-expconstant-2009-1.pdf
z = e**x

plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, ax = plt.subplots()
ax.plot(x, y, label='Test Log')
ax.plot(x, z, label='Testing Other Log')
ax.set_xscale('log')
ax.set_yscale('log')
leg = ax.legend();
ax.legend(loc='upper left', frameon=False)
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fitbit_steps_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()
display(fitbit_steps_month.head())


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fitbit_steps_week = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()
display(fitbit_steps_week.head())
# Out:
#    Months_encoded    Steps
# 0               1  10366.0
# 1               2   9235.0
# 2               3  11122.0
# 3               4  13846.5
# 4               5  11998.0
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
# MEDIAN STEPS BY MONTH_ENCODED
plt.figure(figsize = (12,4))
plt.bar(fitbit_steps_month['Months_encoded'],fitbit_steps_month['Steps'])
plt.xticks(fontsize=12)
plt.show()

plt.savefig("Months_steps.jpg")

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
plt.figure(figsize = (12,4))
plt.bar(fitbit_steps_week['Work_or_Weekend'],fitbit_steps_week['Steps'])
#plt.xticks([-0.25,0,0.25,0.5,0.75,1,1.25],["Monday","Tuesday","Wednesday","Thursday","Friday",'Weekend',""])
plt.xticks([-0.25,0,0.25,0.5,0.75,1,1.25],["","Workday","","","",'Weekend',""])
plt.show()

plt.savefig("Week_Work_steps.jpg")

# %%
plt.figure(figsize = (12,4))
plt.bar(fitbit_steps_week['Work_or_Weekend'],fitbit_steps_week['Steps'])
#plt.xticks([-0.25,0,0.25,0.5,0.75,1,1.25],["Monday","Tuesday","Wednesday","Thursday","Friday",'Weekend',""])
#plt.xticks([-0.25,0,0.25,0.5,0.75,1,1.25],["","Workday","","","",'Weekend',""])
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

features =['Minutes Very Active', 'Minutes Lightly Active','Minutes Sedentary']

for i in features:
    plt.scatter(fitbit[i],fitbit['Steps'])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes('float64','int64')
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes('object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
plt.figure(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, [bins10, bins20, bins30] = plt.subplots(1,3, figsize=(20,8))

bins10.hist(titanic['Age'],10)
bins20.hist(titanic['Age'],20)
bins30.hist(titanic['Age'],50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
More bins we have, more distributed values we generate along the whole histogram. 
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.displot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender = titanic['Gender'].unique()
freq = titanic['Gender'].value_counts()

plt.bar(gender,freq)
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x=gender,y=freq)
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
pclass = titanic['Pclass'].unique()
freq_class = titanic['Pclass'].value_counts()
plt.xticks([0.5,1.0,1.5,2.0,2.5,3.0,3.5],["","PClass #1","","PClass #2","",'PClass #3',""])
plt.bar(pclass,freq_class)
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.boxplot(x = 'Age', data = titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
Boxplot is the best summary report for understanding values distributions across the Qs and also to have a draft of the potential outliers.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Most of the distribution is between 22- 37 range (Q1,Median,Q3)
Everything over 60 years old is considering a potential outlier at least by the chart. 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.displot(titanic['Age']) # I think I am not understanding the question :)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
In the distribution histograms we did before we can find that these values represent very low amount of cases.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Age'],titanic['Fare'])

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(data = titanic, x = 'Age', y = 'Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

display(titanic.corr())
sns.heatmap(titanic.corr(),annot=True, xticklabels = titanic.corr().columns,yticklabels = titanic.corr().columns)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
""" From high corr to low 
1) SibS & Parch
2) Survived & Fare
3) Parch & Fare 
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

titanic_gen = sns.FacetGrid(titanic, col = "Gender")
titanic_gen.map(plt.hist, "Age")
plt.show()
