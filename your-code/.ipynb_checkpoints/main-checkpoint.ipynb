# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt 

# %matplotlib inline

import seaborn as sns

import pandas as pd

# %%
#Defining Libraries: Import the important libraries which are required (For data creation and manipulation: Numpy and Pandas, For data visualization: pyplot from matplotlib).

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)# arange generate integer values that will store in Numpy array
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'r--',x,z,'g--') 
#plt.plot(x,z,'g^')

plt.xlabel('x label')
plt.ylabel('y label')
plt.show()  # not know why (x,y) &(x,z) not showing proper graphtogether, but seperately showing perfect graph?

# %%
 #Plot

plt.plot(x,y,color='r')

# Define Title and change size
plt.title("Straight Line Function Chart", fontsize=10)
# To change size
#Note: matplotlib.pyplot.title(label, fontsize=None)
# Out:
# Text(0.5, 1.0, 'Straight Line Function Chart')

# %%
plt.plot(x,y,'b--') 
plt.show()

# %%
plt.plot(x,z,'b--') 
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig,[ax1, ax2] = plt.subplots(nrows = 1, ncols = 2)
ax1.plot(x,y)
ax2.plot(x,z)

#ax1.legend(title='straight line',title_fontsize=5)
#ax2.legend(title='SUBJECT',title_fontsize=10)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig,[ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))
ax1.plot(x,y)
ax2.plot(x,z)

ax1.set_xlabel('x label')
ax1.set_ylabel('y label')
ax1.set_title("ploting")   #plt.title("straight line ",fontsize=10) can only used in a single axis



ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
#ax2.set_title("ploting")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.title("curve line ",fontsize=20, fontweight='bold') #title(label, fontsize=None)/#plt.title("Sine Function", fontsize= 15, fontweight='bold')

plt.show()

# %%
#plt.title(:)
 
fig, ax = plt.subplots()
plt.title("straight line ",fontsize=10) #can only used in a single axis
ax.plot(x,y)
plt.show()

# %%
#set_title()-----for mulpiple axis &  set_size() method:
fig, ax = plt.subplots(1, 2)

# Set Title
ax[0].set_title("Plot 1")
ax[1].set_title("Plot 2")
# Change font size

# Change font size
ax[0].title.set_size(10)
ax[1].title.set_size(20)

# Plot graph
ax[0].plot(x, y)
ax[1].plot(x, z)

# Display Graph
fig.tight_layout() #tight_layout automatically adjusts subplot params so that the subplot(s) fits in to the figure area. 
plt.show()

# %%
# Set title size
#Matplotlib rcParams title font size
#par = {'axes.titlesize':30}
#plt.rcParams.update(par)

#plt.plot(x, y)

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = int(input("Enter a number: ")
y = 1
for i in range(1,101):
    y = y+ pow(x,i)/fact(i)
# Out:
#   File "C:\Users\suparna\AppData\Local\Temp/ipykernel_33420/3571150381.py", line 2
#     y = 1
#     ^
# SyntaxError: invalid syntax

# %%
# your code here
#logarithmic scale.
x = np.arange(0,100)
𝑦=𝑥**2 
fig,[ax1, ax2] = plt.subplots(nrows = 1, ncols = 2)
ax1.set_xscale("log")
ax2.set_yscale("log")
#ax1.plot(x,y)
#ax2.plot(x,z)
ax1.plot(x,y,'r--',x,z,'g--')

# %%
#normal scale
x = np.arange(0,100)
𝑦=𝑥**2 
fig,[ax1, ax2] = plt.subplots(nrows = 1, ncols = 2)
ax1.plot(x,y)
ax2.plot()
# Out:
# []

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x = np.arange(0,100)
𝑦=x**2
plt.legend(['single ']) # Function add a legend  
plt.plot(x,y)
plt.show()

# %%
# X-axis values
x = [1, 2, 3, 4, 5]
  
# Y-axis values 
y = [1, 4, 9, 16, 25]
  
# Function to plot  
plt.plot(x, y)
  
# Function add a legend  
plt.legend(['single '])

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x)
plt.plot(y)
# Function add a legend  
plt.legend(["blue", "green"], loc ="lower right")
# function to show the plot
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#my note:The sca() method pyplot module of matplotlib library is used to set the current axes.

# %%
# MEDIAN STEPS BY MONTH_ENCODED    # ask how to plot in box plot
# your code here
fig, ax = plt.subplots(2, 1)
#fig,[ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))
fig = plt.figure(figsize =(12, 4))
#plt.figure(figsize = (12,4))

plt.sca(ax[0])
#plt.hist(fitbit["Months_encoded"])
plt.boxplot(fitbit["Months_encoded"])

#plt.scatter(fitbit["Steps"],fitbit["Months_encoded"])



#plt.xticks(fontsize=24,rotation=45)


# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
plt.sca(ax[1])
plt.boxplot(fitbit["Work_or_Weekend"])
#plt.hist(fitbit["Work_or_Weekend"])
#plt.xticks(fontsize=24,rotation=45)

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, axes = plt.subplots(3, 1) 

  
for i in range(3):
    plt.sca(axes[i])

axes[0].scatter(fitbit["Steps"],fitbit["Minutes Very Active"])
axes[1].scatter(fitbit["Steps"],fitbit["Minutes Sedentary"])
axes[2].scatter(fitbit["Steps"],fitbit["Minutes Fairly Active"])
      
fig.suptitle("""matplotlib.pyplot.sca()
function Example\n\n""", fontweight ="bold") 


plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Plot stacked bar chart
#https://pythonguides.com/matplotlib-title-font-size/
ax = titanic.plot(stacked=True, kind='bar')
plt.show()

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
only_numerics=titanic.select_dtypes(include=numerics)
only_numerics
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=object)
#titanic.select_dtypes(include=[np.object])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

#using matplotlib
#fig, ax = plt.subplots()
#fig,[ax1,ax2,ax3] = plt.subplots(1,3,figsize=(9,1.5))
plt.figure(figsize = (12,6))
plt.style.use('classic') #using matplotlib
#plt.style.use('default')
#plt.style.use('seaborn')
plt.bar(titanic['Embarked'],titanic['Age']) #Embarked in x-axis,Age in y-axis
plt.xticks(fontsize=24,rotation=45)
plt.show()

# %%
#using seaborn
plt.figure(figsize = (12,6))
#sns.set_style("whitegrid") #style must be one of white, dark, whitegrid, darkgrid, ticks
sns.set_style("white")
sns.barplot(titanic['Embarked'],titanic['Age']) #Embarked in x-axis,Age in y-axis
# Out:
# C:\software-da\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='Age'>

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": "--"})
sns.lineplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <AxesSubplot:>

# %%
#Note for style:
#plt.style.use('default')---------> default style
#plt.style.use('style')------------> for diff style
# exm,   plt.style.use('fivethirtyeight')
for style in plt.style.available:
    print(style)
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
#your code here
sns.histplot(titanic, x='Age')
plt.ticklabel_format(style='plain', axis='x')

# %%
sns.histplot(titanic.Age,bins=10)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig,[ax1,ax2,ax3] = plt.subplots(1,3,figsize=(9,1.5))
ax1.set_title("bins equal to 10") 
ax2.set_title("bins equal to 20") 
ax3.set_title("bins equal to 50") 

ax1.hist(titanic["Age"],bins=10)
ax2.hist(titanic["Age"],bins=20)
ax3.hist(titanic["Age"],bins=50)

#sns.histplot(titanic["Age"],bins=10)
#sns.histplot(titanic["Age"],bins=20)
#sns.histplot(titanic["Age"],bins=50)


# Form a facetgrid using columns
g = sns.FacetGrid(titanic, col = "Age")

# Form a facetgrid using columns with a hue
#g= sns.FacetGrid(titanic, col = "Age", hue = "kind")

# map the above form facetgrid with some attributes 
#g.map(sns.histplot(titanic.Age,bins=20))
#g.map(sns.histplot(titanic["Age"],bins=20))
#g.map(sns.scatterplot, "Cabin", "Age", alpha = .8)
 
# adding legend
g.add_legend()

#www.delftstack.comax1.set_title("ploting")/www.geeksforgeeks.org/multi-plot-grid-in-seaborn/

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
Too large bin, and you will not get enough differentiation. Too small bin, and the data cannot be grouped.A good bin width will usually show a recognizable normal probability distribution curve
Here,bins=20 gives good normal distribution.
Explanation:
"""
# Out:
# '\nyour comments here\nToo large bin, and you will not get enough differentiation. Too small bin, and the data cannot be grouped.A good bin width will usually show a recognizable normal probability distribution curve\nHere,bins=20 gives good normal distribution.\nExplanation:\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.boxplot(titanic.Age)
# Out:
# C:\software-da\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
 titanic.groupby(by='Gender').size()
# Out:
# Gender
# female    466
# male      843
# dtype: int64

# %%
# Method 1 - matplotlib
# your code here
gender_df = titanic.groupby(by='Gender').size()
gender_df.plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
titanic['Gender'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn

# your code here
sns.catplot(data=titanic, x="Gender", kind="count", palette="ch:.25")

# %%
sns.catplot(
    data=titanic, y="Gender", hue="Gender", kind="count",
    palette="pastel", edgecolor=".6",
)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
#Pclass-----.int64
sns.distplot(titanic["Pclass"]);
# Out:
# C:\software-da\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.879186     0.498854
# std     378.020061    0.486592     0.837836    13.448335     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    22.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.500000     0.000000
# 75%     982.000000    1.000000     3.000000    37.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.281086
# std       0.865560    51.741500
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

fig, ax = plt.subplots()
ax.boxplot(titanic["Age"])
plt.figtext(0.1,0.5, titanic["Age"].describe().to_string())
plt.figtext(0.75,0.5, titanic["Age"].describe().loc[['mean','std']].to_string())
plt.show()

# %%
"""
your comments here
boxplot
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
normally distributed
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig, ax = plt.subplots()
ax.hist(titanic["Age"])
plt.figtext(0.1,0.5, titanic["Age"].describe().to_string())
# Out:
# Text(0.1, 0.5, 'count    1309.000000\nmean       29.879186\nstd        13.448335\nmin         0.170000\n25%        22.000000\n50%        28.500000\n75%        37.000000\nmax        80.000000')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
Use histogram
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic["Fare"],titanic["Age"])

# %%
# Method 2 - seaborn
# your code here
 
sns.scatterplot(x=titanic["Fare"], y=titanic["Age"] )
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
print(only_numerics.corr())
sns.heatmap(only_numerics.corr(), cmap="YlGnBu", annot=True)
plt.show()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
#sol2
only_numerics.corr()
plt.matshow(only_numerics.corr())
plt.xticks(range(0,7),only_numerics.columns)
plt.yticks(range(0,7),only_numerics.columns)
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Parch & SibSp
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %%
summary_stat = titanic.groupby('Pclass').agg({'Age':'count'}).reset_index()
summary_stat
# Out:
#    Pclass  Age
# 0       1  323
# 1       2  277
# 2       3  709

# %%
summary_stat["Age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(summary_stat["Age"])
# Out:
# C:\software-da\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
summary_stat1 = titanic.groupby('Gender').agg({'Age':'count'}).reset_index()
summary_stat1
# Out:
#    Gender  Age
# 0  female  466
# 1    male  843

# %%
# your code here
# Form a facetgrid using columns
g = sns.FacetGrid(summary_stat1, col = "Age",hue = "Gender")  #g->graph

# map the above form facetgrid with some attributes 
g.map(sns.histplot(summary_stat1,bins=20))

g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31908/3432233522.py in <module>
#       4
#       5 # map the above form facetgrid with some attributes
# ----> 6 g.map(sns.histplot(summary_stat1,bins=20))
#       7
#       8 g.add_legend()
#
# C:\software-da\anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     708
#     709             # Draw the plot
# --> 710             self._facet_plot(func, ax, plot_args, kwargs)
#     711
#     712         # Finalize the annotations and layout
#
# C:\software-da\anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# ...

# %%
sns.distplot(summary_stat1["Age"])
# Out:
# C:\software-da\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
summary_stat1["Age"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#sol2
plt.figure(figsize = (4,4))
plt.bar(titanic["Gender"],titanic["Age"])
plt.xticks(fontsize=24,rotation=45)
plt.show()
