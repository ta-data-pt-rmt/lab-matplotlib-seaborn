# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, color= 'b', lw= 1)
plt.plot(x, z, color= 'g', lw= 1)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, (xy, xz) = plt.subplots(1, 2)
xy.plot(x, y, color= 'b', lw= 1)
xz.plot(x, z, color= 'g', lw= 1)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
# your code here
fig, (xy, xz) = plt.subplots(1, 2, figsize=(10,5))
xy.plot(x, y, color= 'b', lw= 1)
xz.plot(y, z, color= 'g', lw= 1)

xy.set_title('xy')
xz.set_title('xz')

xy.set_xlabel('x')
xz.set_xlabel('x')

xy.set_ylabel('y')
xz.set_ylabel('y')

fig.tight_layout()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

x = np.linspace(0, 4, 1000)
y1 = lambda x: x**2
y2 = lambda x: np.exp(x)


plt.plot(x,y1(x), color= 'b', lw= 1)
plt.plot(x,y2(x), color= 'g', lw= 1)

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.plot(x,y1(x), color= 'b', lw= 1, label= 'y1 = x**2')
plt.plot(x,y2(x), color= 'g', lw= 1, label= 'y2 = np.exp(x)')

plt.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps_by_month = fitbit.groupby(by= ['Months_encoded'])['Steps'].median()

fig = plt.figure(figsize= (10, 2))
plt.bar(steps_by_month.index, steps_by_month.values, color= 'blue')
plt.xticks(steps_by_month.index, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.savefig(r'C:\Users\Sergio\Desktop\Data course\W4-D2-lab-Matplotlib & Seaborn\lab-matplotlib-seaborn\your-code\fig1.png', format='png')

active_steps = fitbit.groupby(by= ['Work_or_Weekend'])['Steps'].median()

fig = plt.figure(figsize= (2, 4))
plt.bar(active_steps.index, active_steps.values, color= 'blue')
plt.xticks([0, 1], ['Weekend', 'Workdays'])
plt.savefig(r'C:\Users\Sergio\Desktop\Data course\W4-D2-lab-Matplotlib & Seaborn\lab-matplotlib-seaborn\your-code\fig2.png', format='png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
collumns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for c in collumns:
    plt.figure()
    plt.title('Steps vs ' + c)
    plt.xlabel('Steps')
    plt.ylabel(c)
    plt.scatter(fitbit['Steps'], fitbit[c], color= np.random.rand(3))

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
titanic.select_dtypes(exclude='number')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize= (12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
ax = sns.histplot(data=titanic,x='Age',bins=30,color='r',alpha=.25,
                  label='Age')
sns.histplot(data=titanic,x='Fare',ax=ax,bins=30,color='b',alpha=.25,
             label='Fare')         
ax.legend()
plt.show()

# %%
# your code here

#sns.displot(titanic['Age'])
#sns.distplot(titanic['Age'])
sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, y = plt.subplots(3, 1, figsize=(5, 6))

sns.histplot(titanic['Age'], color="g", ax=y[0], bins= 10)


sns.histplot(titanic['Age'], color="b", ax=y[1], bins= 20)


sns.histplot(titanic['Age'], color="y", ax=y[2], bins= 50)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""


The smaller the bins, the more detailed analysis can be made, since the information is more detailed / visual. 



"""
# Out:
# '\n\n\nThe smaller the bins, the more detailed analysis can be made, since the information is more detailed / visual. \n\n\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
ax = sns.histplot(data=titanic,x='Age',bins=30,color='r',alpha=.25, label='Age')
sns.histplot(data=titanic,x='Fare',ax=ax,bins=30,color='b',alpha=.25,label='Fare')         
ax.legend()
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.hist(titanic['Gender'], color='y', bins=2)
# Out:
# (array([843., 466.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
# Method 2 - seaborn
# your code here

sns.histplot(titanic['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic['Pclass'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

plt.boxplot(titanic.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14f1d6cbc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14f1d6db400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14f1d6cb8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14f1d6dbb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14f1d6dbeb0>],
#  'means': []}

# %%
"""


THis is the most accurate plot for any Age representation



"""
# Out:
# '\n\n\nTHis is the most accurate plot for any Age representation\n\n\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""



Average Age is around 30, while most titanic travellers are btween 20 and 40



"""
# Out:
# '\n\n\n\nAverage Age is around 30, while most titanic travellers are btween 20 and 40\n\n\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.violinplot(x = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""

Same as the box but more visual representation of the data


"""
# Out:
# '\n\nSame as the box but more visual representation of the data\n\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Fare'],titanic['Age'])

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(x = titanic['Fare'],y = titanic['Age'])
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.heatmap(titanic.corr())
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""


SibSp and Parch 
Fare and Survived



"""
# Out:
# '\n\n\nSibSp and Parch \nFare and Survived\n\n\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

plt.boxplot([titanic.loc[titanic['Pclass'] == 1, 'Age'], titanic.loc[titanic['Pclass'] == 2, 'Age'], titanic.loc[titanic['Pclass'] == 3, 'Age']])
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
face = sns.FacetGrid(titanic[['Age','Gender']],col='Gender')
face.map(sns.histplot,'Age')
plt.show()
