# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,"ro-")
plt.plot(x,z,"b+-")
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
(plot_options,[xy,xz])=plt.subplots(nrows=1,ncols=2)

xy.plot(x,y)
xz.plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

(plot_options,[xy,xz])=plt.subplots(nrows=1,ncols=2, figsize=(30,10))
xy.plot(x,y)
xz.plot(x,z)
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %% [markdown]
# # your code here
# y_xsquare=x**2
# y_exp=np.exp(x)
# (plot_options,[chat1,chart2])=plt.subplots(nrows=1,ncols=2,figsize=(30,5))
# chart1.plot(x,y_xsquare,label='y = x^2',color="orange")
# chart2.plot(x,y_exp,label='y = exp(x)',color="green")
# plt.title('Normal Scale')
# plt.grid(True)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

plt.figure(figsize=(25, 8))

# Plot on the normal scale
plt.subplot(1, 2, 1)
plt.plot(x, y_xsquare, label='y = x^2', color='orange')
plt.plot(x, y_exp, label='y = e^x', color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Normal Scale')
plt.legend()

# Plot on the logarithmic scale
plt.subplot(1, 2, 2)
plt.plot(x, y_xsquare, label='y = x^2', color='orange')
plt.plot(x, y_exp, label='y = e^x', color='green')
plt.yscale('log')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Logarithmic Scale')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv("Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
import seaborn as sns
step_by_month=fitbit.groupby("Months_encoded").agg({"Steps":"mean"}).reset_index()
print(step_by_month)
# Create the histogram using seaborn
plt.figure(figsize=(8, 6))
plt.bar(step_by_month["Months_encoded"],step_by_month["Steps"])
plt.xticks(fontsize=12) # not enoguh space for x label, rotaion = 45degree
plt.yticks(fontsize=12)

# sns.histplot(data=step_by_month, y="Steps",x="Months_encoded", bins=5, color='orange', element='step')
# sns.boxplot(data=step_by_month, y="Steps",x="Months_encoded")

plt.ylabel('Average steps')
plt.xlabel('Months')
plt.title('Average steps by month')
# plt.grid(True)
# plt.legend()
plt.show()


# MEDIAN STEPS BY WORK_OR_WEEKEND
step_week=fitbit.groupby("Work_or_Weekend").agg({"Steps":"mean"}).reset_index()
step_week['Work_or_Weekend'] = step_week['Work_or_Weekend'].replace({0: 'Weekdays', 1: 'Weekend'})
print(step_week)

plt.figure(figsize=(4, 8))
# sns.histplot(data=step_week, y="Steps",x="Work_or_Weekend", bins=5, color='purple', element='step')
# sns.boxplot(data=step_week, y="Steps",x="Work_or_Weekend")
plt.bar(step_week["Work_or_Weekend"],step_week["Steps"])
plt.xticks(fontsize=12) # not enoguh space for x label, rotaion = 45degree
plt.yticks(fontsize=12)
plt.ylabel('Average steps')
plt.xlabel('Week or weekend')
plt.title('Average steps observation')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#     Months_encoded         Steps
# 0                1   9892.064516
# 1                2   8922.866667
# 2                3  10312.935484
# 3                4  13079.033333
# 4                5  10620.096774
# 5                6  12536.166667
# 6                7   9193.322581
# 7                8  11584.774194
# 8                9   9191.333333
# 9               10   8272.451613
# 10              11   9467.466667
# 11              12   8470.064516
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   Work_or_Weekend         Steps
# 0        Weekdays  10064.238095
# 1         Weekend  10144.572519

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv("titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
num_df=titanic.select_dtypes(exclude=['object'])
num_df
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
cat_df=titanic.select_dtypes(include=['object'])
cat_df
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
# Set the plot style to "classic"
plt.style.use('classic')

# Create a figure with the desired size
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
age_dist=titanic.groupby("Age").agg({"PassengerId":"count"}).reset_index()
print(age_dist)
plt.scatter(age_dist['Age'],age_dist["PassengerId"])
plt.xlabel("Age")
plt.ylabel("Number of passengers")
plt.title("Age distribution among passengers")
# Out:
#        Age  PassengerId
# 0     0.17            1
# 1     0.33            1
# 2     0.42            1
# 3     0.67            1
# 4     0.75            3
# ..     ...          ...
# 188  70.50            1
# 189  71.00            2
# 190  74.00            1
# 191  76.00            1
# 192  80.00            1
#
# [193 rows x 2 columns]
# Text(0.5, 1.0, 'Age distribution among passengers')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
(plot_options,[chart1,chart2])=plt.subplots(nrows=2,ncols=1)

chart1.hist(age_dist["Age"])

chart2.hist(age_dist["Age"],[10,20,50])
# Out:
# (array([ 18., 128.]),
#  array([10., 20., 50.]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
FIrst chart with the default bins give more granuality to data distribution, the second chart tends to generalized the distribution of age aver 20
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(data=age_dist,x="Age",kde=True, edgecolor="none")

plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# to add more information, im trying to plot gender as well
gender_dist=titanic.groupby(["Gender"]).agg({"PassengerId":"count"}).reset_index()
print(gender_dist)

plt.figure(figsize=(5,8))
# Create a bar chart
plt.bar(gender_dist["Gender"],gender_dist['PassengerId'])
plt.title("Passengers by gender")

# Add labels and a legend

plt.show()
# Out:
#    Gender  PassengerId
# 0  female          466
# 1    male          843

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(5,8))
# Create a bar chart
sns.barplot(data=gender_dist, x= "Gender",y='PassengerId')
plt.title("Passengers by gender")
# Out:
# Text(0.5, 1.0, 'Passengers by gender')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
# to add more information, im trying to plot gender as well
class_dist=titanic.groupby(["Pclass"]).agg({"PassengerId":"count"}).reset_index()
print(class_dist)
plt.figure(figsize=(8,8))
# Create a bar chart
sns.barplot(data=class_dist, x= "Pclass",y='PassengerId')
plt.title("Passengers by class")
# Out:
#    Pclass  PassengerId
# 0       1          323
# 1       2          277
# 2       3          709
# Text(0.5, 1.0, 'Passengers by class')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.figure(figsize=(8, 6))
sns.boxplot(y=age_dist['Age'],color='darkgreen')

# Add labels and a title

plt.title('Summary Statistics of Age Feature')
# Out:
# Text(0.5, 1.0, 'Summary Statistics of Age Feature')

# %%
"""
Median age is around 30-35. 50% of popolation aged from 23 to 44. A few outliners are over 75 age 
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Passengers are quite young
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.figure(figsize=(10, 6))
sns.violinplot(x=age_dist['Age'], color='skyblue', inner='box')

# Add labels and a title
plt.xlabel('Age')
plt.title('Summary Statistics and Distribution of Age')

# Display the plot
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
in addition to boxplot, it show the distribution which hihgly concentrated in the middle , consistent with the size of boxplot chart
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.figure(figsize=(10, 6))
plt.scatter(titanic['Age'],titanic['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic,x="Age",y="Fare")
plt.xlabel("Age")
plt.ylabel("Fare")

# your code here
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
titanic_corr = titanic.corr()

# Create a correlation matrix plot
plt.figure(figsize=(8, 6))
sns.heatmap(titanic_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add a title
plt.title('Correlation Matrix')

# Display the plot
plt.show()
# Out:
# /var/folders/b5/_g73482d637g7mvbbf2qcxk80000gn/T/ipykernel_17361/442712427.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic_corr = titanic.corr()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
PClass with Fare is most correlated which make sense since higher class higher fare
pclass with age also a bit correlated assuming it is because of the level income by age
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
# Create a box plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Pclass', y='Age', data=titanic)

# Add labels and a title
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.title('Summary Statistics of Age by Passenger Class')

# Display the plot
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

plt.figure(figsize=(10, 6))
sns.histplot(data=titanic, x='Age', hue='Gender', kde=True, element='step', edgecolor ="none")

# Add labels and a title
plt.xlabel('Age')
plt.ylabel('Number of passengers')
plt.title('Distribution of Age Based on Gender')

# Display the plot
plt.show()
