# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1: Creating two separate figures for each plot
# First figure for (x, y)
plt.figure(figsize=(6, 4))
plt.plot(x, y, label='y = 2x', linestyle='--', linewidth=2, color='blue')
plt.title('Linear Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True) # Enable grid
plt.legend() # print a label on the plot
plt.show()

# Second figure for (x, z)
plt.figure(figsize=(6, 4))
plt.plot(x, z, label='z = x^2', linestyle='-.', linewidth=2, color='red')
plt.title('Quadratic Plot')
plt.xlabel('x')
plt.ylabel('z')
plt.grid(True)# Enable grid
plt.legend() # print a label on the plot
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2: Using a single plt.plot() call for each subplot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

# Plotting x and y
axes[0].plot(x, y, 'b-', linewidth=2, label='y = 2x')  # Blue solid line
axes[0].set_title('Linear Plot')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].grid(True)  # Enable grid
axes[0].legend()  # print a label on the plot

# Plotting x and z
axes[1].plot(x, z, 'm-.', linewidth=2, label='z = x^2')  # Magenta dash-dot line
axes[1].set_title('Quadratic Plot')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
axes[1].grid(True)  # Enable grid
axes[1].legend() # print a label on the plot


plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(40,20))

axes[0].plot(x, y, 'go-', linewidth=2, label='y = 2x') 
axes[0].set_title('Linear Plot', fontsize= 30)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].grid(True)   
axes[0].legend()  

# Plotting x and z
axes[1].plot(x, z, 'r-.', linewidth=4, label='z = x^2') 
axes[1].set_title('Quadratic Plot', fontsize= 30)
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
axes[1].grid(True)  
axes[1].legend() 


plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
# Data setup
x = np.linspace(0, 3, 400)  # Generate 400 points from 0 to 3
y1 = x**2
y2 = np.exp(x)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Normal scale plot
ax1.plot(x, y1, label='$y = x^2$', linestyle='-', linewidth=2, color='c')
ax1.plot(x, y2, label='$y = e^x$', linestyle='--', linewidth=2, color='g')
ax1.set_title('Normal Scale')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()
ax1.grid(True)

# Logarithmic scale plot
ax2.plot(x, y1, label='y = x^2', linestyle='-', linewidth=2, color='m')
ax2.plot(x, y2, label='y = e^x', linestyle='--', linewidth=2, color='b')
ax2.set_title('Logarithmic Scale')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_yscale('log')  # Apply logarithmic scale to y-axis
ax2.legend()
ax2.grid(True)

# Display the figure
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
#done above

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv("Fitbit2.csv")

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
monthly_steps = fitbit.groupby('Months_encoded')['Steps'].median()

# MEDIAN STEPS BY WORK_OR_WEEKEND
weekend_steps = fitbit.groupby('Work_or_Weekend')['Steps'].median()

# your code here

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

# median steps by month plot
plt.sca(axes[0])
monthly_steps.plot(kind='bar', ax= axes[0])
axes[0].set_title('Median steps by month')
axes[0].set_xlabel('Month Encoded')
axes[0].set_ylabel('Median Steps')
plt.xticks(rotation=45) # rotate x-axis labels for easier readability

# Activity comparison: Weekday vs Weekend
plt.sca(axes[1])
weekend_steps.plot(kind='bar', ax=axes[1], color='orange')
axes[1].set_title('Median Steps: Workdays vs Weekends')
axes[1].set_xlabel('Type of day')
axes[1].set_ylabel('Median Steps')
axes[1].set_xticklabels(['Workday', 'Weekend'], rotation=0)

# adjust layout
plt.tight_layout()

# save figures

plt.savefig('figures/fitbit_analysis.png')

# show the plots
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# defining a list of tuples containing the columns to plot

plots = [
        ('Minutes Lightly Active','Steps'),
        ('Minutes Very Active','Steps'),
        ('Minutes Sedentary','Steps')
]

# creating a figure with 3 subplots (one for each scatter plot), arranged vertically

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# looping over the defined plots

for ax, (col_x, col_y) in zip(axes, plots):
    # create a scatter plot on the current axes
    ax.scatter(fitbit[col_x],fitbit[col_y],color='orange')
    ax.set_title(f"{col_x} vs {col_y}")
    ax.set_xlabel(col_x)
    ax.set_ylabel(col_y)
    

# adjusting the layout to prevent overlapping

plt.tight_layout()

# showing the plot

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerical_variables = titanic.select_dtypes(include = ['float64','int64'])
print("Numerical Variables:")
print(numerical_variables.columns)
# Out:
# Numerical Variables:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
categorical_variables = titanic.select_dtypes(include=['object'])
print("Categorical Variables:")
print(categorical_variables.columns)
# Out:
# Categorical Variables:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here


plt.rcParams['figure.figsize'] = [12, 6] # Sets the default size for all figures created after this setting

#print(plt.style.available)

plt.style.use('classic')

# Create a sample plot to visualize the changes
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.title("Example Plot with Classic Style")
plt.show()

# %%
plt.style.use('classic')

sns.set(rc={'figure.figsize':(12, 6)})

# Create a sample plot with Seaborn to visualize the changes
sns.lineplot(x=[1, 2, 3, 4, 5], y=[1, 4, 9, 16, 25])
plt.title("Example Plot with Classic Style")
plt.show()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
# using a histogram

num_bins = int(np.sqrt(len(titanic['Age'])))
plt.figure(figsize=(10,6))
plt.hist(titanic['Age'],bins=num_bins, color='purple',edgecolor='black', alpha= 0.6)
plt.title("Titanic: Age Distribution")
plt.xlabel('Age', fontsize=18)
plt.xticks(range(0,81,5),fontsize=18, rotation=0)
plt.ylabel('Frequency',fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True)

plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(15,10))

plt.sca(axes[0])
plt.hist(titanic['Age'],bins=10, color='orange',edgecolor='black',alpha= 0.6)
plt.title("Age Distribution with 10 bins")
plt.xlabel('Age')
plt.xticks(range(0,81,5))
plt.ylabel('Frequency')
plt.yticks(fontsize=18)
plt.grid(True)

plt.sca(axes[1])
plt.hist(titanic['Age'],bins=20, color='green',edgecolor='black',alpha= 0.6)
plt.title("Age Distribution with 20 bins")
plt.xlabel('Age', fontsize=18)
plt.xticks(range(0,81,5))
plt.ylabel('Frequency')
plt.yticks()
plt.grid(True)

plt.sca(axes[2])
plt.hist(titanic['Age'],bins=50, color='blue',edgecolor='black',alpha= 0.6)
plt.title("Age Distribution with 50 bins")
plt.xlabel('Age')
plt.xticks(range(0,81,5), rotation=0)
plt.ylabel('Frequency')
plt.yticks()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The frequency count in each bin of a histogram changes with the number of bins.
I suppose this is because the bin width (the range of values included in each bin) changes.
If you increase the number of bins (leading to narrower bins), 
each bin covers a smaller range of values so the frequency count decreases as we are covering a smaller range of the population.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
# setting the aesthetic style of the plot
sns.set(style="whitegrid")

# creating a histogram
plt.figure(figsize=(12,6))
sns.histplot(titanic['Age'],kde=True, line_kws={"lw": 3, "linestyle": "--"},color='purple') # kde True allows to see the distribution shape along with the histogram.

# adding labels and a title
plt.title("Age Distribution")
plt.xlabel('Age')
plt.ylabel('Frequency')

# show the plot

plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
# count the occurrences of each gender
gender_counts = titanic['Gender'].value_counts()
# create a bar plot
plt.style.use('default')
plt.figure(figsize=(10,6))
gender_counts.plot(kind='bar', color=['royalblue','orchid'],align='center', alpha=0.9)
plt.title("Titanic Gender Distribution",fontsize=16)
plt.xlabel('Gender',fontsize=16)
plt.xticks(fontsize=14, rotation=0)
plt.ylabel('Frequency',fontsize=16)
plt.grid(True)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Method 2 - seaborn
# your code here

sns.set(rc={'figure.figsize':(10,4)})
sns.countplot(x='Gender', data=titanic, hue='Gender', palette=['royalblue','orchid'],legend=False)
plt.xlabel('Gender',fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel('Count',fontsize=16)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x='Pclass',data=titanic,hue='Pclass', palette=['seagreen','steelblue','mediumpurple'],legend=False)
plt.title('Distribution of passengers per class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
# using a box plot
plt.figure(figsize=(18,6))
sns.boxplot(x=titanic['Age'],color='mediumorchid',showmeans=True, meanline=True,meanprops={'color': 'blue', 'linestyle': '--', 'linewidth': 2})
plt.title('Summary Statistics of Age')
plt.xlabel('Age')
plt.xticks(range(0,81,5))
plt.show()

# %%
"""
I chose a boxplot as it displays the summary statistics of a dataset, including the median, quartiles, and outliers. 
It's a great way to visualize the central tendency and variability of the data.
I also added a line displaying the mean value
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
From the box plot, we can tell that the median (Q2) is about 28 yo, also meaning that 50% of the passengers were under that age
Q1 is about 22 yo which means only 25% of the passengers were under that age
50% of the passengers were in the range between about 22 and about 37 yo (Q3)
75% of the total were under about 37
We can also tell there were babies on board (passengers with 0 yo)
Also, we can identify there is a rather significant number of outlier point above the age of about 58
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
# using a violin plot
plt.figure(figsize=(12,6))
sns.violinplot(x=titanic['Age'],color='orchid', saturation= 0.5, inner='quart')
plt.title("Summary Statistics and Disftibution of Age")
plt.xlabel("Age")
plt.xticks(ticks=np.arange(0,titanic['Age'].max()+5,5))
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The violing plot provides additional layers of information about the data's density and distribution shape.
In the plot above, not only can we see the median and quartiles, but we can more clearly identify how the ages are distributed around the median and other points. 
We can also see the skewness of the data with more clarity and it's spread (looking at the shape and tails of the 'violin')
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
# using a scatter plot:

plt.figure(figsize=(10,6))
plt.scatter(titanic['Age'],titanic['Fare'],color='orchid',alpha=0.5)
plt.title("Scatter Plot of fare vs age")
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age',y='Fare',data=titanic, color='orange',alpha=0.5)
plt.title('Scatter Plot of Fare vs Age')
plt.grid(True)
plt.show()

# %%
# adding a lineare regression line to compare:

plt.figure(figsize=(10,6))
sns.regplot(x='Age',y='Fare',data=titanic,scatter_kws={'color': 'green', 'marker': '.','alpha':0.5}, line_kws={'color': 'red','lw':'1'})
plt.title('Scatter Plot of Fare vs Age with Regression Line')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

corr_matrix= titanic.corr(numeric_only=True)

sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='viridis',
            cbar=True, xticklabels=corr_matrix.columns, yticklabels=corr_matrix.columns)

plt.title('Correlation Matrix')

plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The highest correlation is between Fare and PClass, which is totally expected: 
As Pclass increases (moving from 1st class to 3rd class), the Fare generally decreases. 
This means passengers in higher classes (lower Pclass value) tend to pay more for their tickets.
There is also a moderately significant negative correlation between PClass and Age which suggests that older passengers tend to be found in higher classes, 
and younger passengers tend to be more prevalend in lower classes.
The negative correlation between Pclass and Survived, although not too high, also suggests the expected: the people that survived were mostly from higher classes.

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
# plotting summary statistics of age vs class using box plot
plt.figure(figsize=(10,6))
sns.boxplot(x='Pclass',y='Age',data=titanic,hue='Pclass', dodge=False, legend=False,saturation= 0.5, palette=['orchid','royalblue','teal'])
plt.title('Age distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

# Create a FacetGrid with 'Gender' as the column variable

grid = sns.FacetGrid(titanic, col='Gender', height=4, aspect=1)

# Plot the distribution of 'Age' in each subplot

grid.map(sns.histplot, "Age", kde=True, color="m", bins=20) 

# Set the axis labels and title
grid.set_titles("Distribution for {col_name}")
grid.set_axis_labels('Age','Density')
plt.subplots_adjust(top=0.8)
grid.fig.suptitle('Age Distribution by Gender')

plt.show()
