# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X, Y')
plt.show()

# %%
plt.plot(x, z)
plt.xlabel('X')
plt.ylabel('Z')
plt.title('X, Z')
plt.show()

# %%
# graph with (x, y) and (x, z) combined 

plt.plot(x, y)
plt.plot(x, z)

plt.xlabel('x')
plt.ylabel('y and z')
plt.title('Plot of y = 2x and z = x^2')


plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)


ax[0].plot(x, y)
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].set_title('(x, y)')


ax[1].plot(x, z)
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
ax[1].set_title('(x, z)')


plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))


ax[0].plot(x, y)
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].set_title('(x, y)')


ax[1].plot(x, z)
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
ax[1].set_title('(x, z)')


plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y1 = x**2
y2 = np.exp(x)

fig, axs = plt.subplots(2, 1, figsize=(8, 8))

# plot with normal scale
axs[0].plot(x, y1)
axs[0].plot(x, y2)
axs[0].set_title('normal scale')

# plot with logarithmic scale
axs[1].plot(x, y1)
axs[1].plot(x, y2)
axs[1].set_xscale('symlog')
axs[1].set_yscale('symlog')
axs[1].set_title('logarithmic scale')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
y1 = x**2
y2 = np.exp(x)

fig, axs = plt.subplots(2, 1, figsize=(8, 8))

# plot with normal scale
axs[0].plot(x, y1, label='y = x^2')
axs[0].plot(x, y2, label='y = e^x')
axs[0].legend()
axs[0].set_title('normal scale')

# plot with logarithmic scale
axs[1].plot(x, y1, label='y = x^2')
axs[1].plot(x, y2, label='y = e^x')
axs[1].set_xscale('symlog')
axs[1].set_yscale('symlog')
axs[1].legend()
axs[1].set_title('logarithmic scale')

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv("Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# Define custom order of months
custom_order = ['May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March', 'April']

# Median steps by month
median_steps = fitbit.groupby("Months")["Steps"].median().loc[custom_order]


fig, ax = plt.subplots(figsize=(12, 4))
plt.sca(ax)
ax.bar(median_steps.index, median_steps.values)
ax.set_xticks(range(0, 12)) 
ax.set_xticklabels(['May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr'])
ax.set_ylabel("Steps")
ax.set_title("Median Steps by Month")
plt.show()


# Fitbitter activity on workday vs weekends
fit = {'Workdays': [fitbit["Work_or_Weekend"].value_counts()[1]], 
        'Weekends': [fitbit["Work_or_Weekend"].value_counts()[0]]}

fit_df = pd.DataFrame(fit)


fig, ax = plt.subplots(figsize=(12, 4))
plt.sca(ax)
ax.bar(fit_df.columns, fit_df.values[0])
ax.set_ylabel("Number of days")
ax.set_title("Annual Fitbitter Atctivity: Workdays vs Weekends")
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]

for feature in features:
    plt.scatter(fitbit["Steps"], fitbit[feature])
    plt.title(feature + " vs Steps")
    plt.xlabel("Steps")
    plt.ylabel(feature)
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical = titanic.select_dtypes(include=["int", "float"])
numerical.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
categorical = titanic.select_dtypes(include=["object"])
categorical.head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize =(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.style.use('classic')
plt.figure(figsize =(12,6))
plt.hist(titanic["Age"], bins=20)

plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age Distribution")
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.style.use('classic')

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

axs[0].hist(titanic["Age"], bins=10)
axs[0].set_title("Age Distribution (10 Bins)")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Frequency")

axs[1].hist(titanic["Age"], bins=20)
axs[1].set_title("Age Distribution (20 Bins)")
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Frequency")

axs[2].hist(titanic["Age"], bins=50)
axs[2].set_title("Age Distribution (50 Bins)")
axs[2].set_xlabel("Age")
axs[2].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size affects the level of detail of the histogram. If the bin size is too large, then the histogram bars will be too wide, and you may not be able to see the underlying distribution of the data. On the other hand, if the bin size is too small, then the histogram bars will be too narrow, and you may see too much noise or fluctuations in the data.
o, I suppose that depending on the range of our values, we should choose a suitable bin size. In this case, I prefer dividing the range into 10 equal bins."""
# Out:
# '\nThe bin size affects the level of detail of the histogram. If the bin size is too large, then the histogram bars will be too wide, and you may not be able to see the underlying distribution of the data. On the other hand, if the bin size is too small, then the histogram bars will be too narrow, and you may see too much noise or fluctuations in the data.\no, I suppose that depending on the range of our values, we should choose a suitable bin size. In this case, I prefer dividing the range into 10 equal bins.'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
import seaborn as sns

titanic_2 = sns.load_dataset('titanic')

sns.distplot(titanic_2['age'])

plt.show()
# Out:
# /Users/andrefontourafaria/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
male_count = (titanic['Gender'] == 'male').sum()
female_count = (titanic['Gender'] == 'female').sum()

plt.bar(['Male', 'Female'], [male_count, female_count])

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Titanic')

plt.show()

# %%
sns.countplot(x='sex', data=titanic_2)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x='pclass', data=titanic_2)
plt.show()

# I guess that it is easier and faster to plot using seaoborn =)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x='age', data=titanic_2)
plt.title('Summary statistics of Age')
plt.show()

# %%
"""

A box plot displays the median, quartiles, minimum and maximum values, and any outliers, making it easy to compare the distribution of the variable between groups.

"""
# Out:
# '\n\nA box plot displays the median, quartiles, minimum and maximum values, and any outliers, making it easy to compare the distribution of the variable between groups.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
median age is 28 yo.
max age is 80.0 yo.
min age is ~0 yo.
and also gives you a perspective of the quartiles.

"""
# Out:
# '\nmedian age is 28 yo.\nmax age is 80.0 yo.\nmin age is ~0 yo.\nand also gives you a perspective of the quartiles.\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.violinplot(x='age', data=titanic_2)

plt.title('Distribution')

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
It shows the shape and density of the distribution.

"""
# Out:
# '\nIt shows the shape and density of the distribution.\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.plot.scatter(x='Age', y='Fare')
plt.title('Titanic Dataset: Fare vs. Age')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %%
sns.lineplot(x='age',y='fare', data=titanic_2)

plt.title('Distribution')

plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
matrix = titanic_2.corr()

sns.heatmap(matrix, annot=True, cmap='coolwarm')

plt.title('Matrix for Titanic')

plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
- survived has strong correlations with "pclass", "fare" and "adult_male" (the most important one);
- pclass has a interesting correlation with age;
- also "alone has" the highest negative correlation with parch ans sibsp
"""
# Out:
# '\n- survived has strong correlations with "pclass", "fare" and "adult_male" (the most important one);\n- pclass has a interesting correlation with age;\n- also "alone has" the highest negative correlation with parch ans sibsp\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='pclass', y="age", data=titanic_2)
plt.title('Summary statistics of Age')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic_2, col='sex')
g.map(sns.histplot, 'age')

g.fig.suptitle('Summary statistics of Age based on Gender')
g.set_xlabels('Gender')
g.set_ylabels('Age')

plt.show()
