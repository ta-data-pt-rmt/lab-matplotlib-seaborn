# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import os

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.style.use('default')
plt.plot(x, y, 'b+')
plt.plot(x, z, 'ro')
plt.xlim(0, 25)
plt.ylim(0, 600)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
plt.style.use('classic')
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y, 'b+')
ax2.plot(x, z,'r', linewidth=5)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.plot(x, y, 'b+')
ax1.set_title('y = x*2', fontweight='bold', fontsize='x-large')
ax1.set_xlabel(xlabel='X')
ax2.plot(x, z,'r', linewidth=5)
ax2.set_title('y = x**2', fontweight='bold', fontsize='x-large')
ax2.set_xlabel(xlabel='X')
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
plt.style.use('default')
x = np.arange(0,100)
y = x**2
z = np.exp(x)

# %%
plt.plot(x, y)
plt.plot(x, z)
plt.xlim(90, 98)
plt.show()

# %%
plt.plot(x, y)
plt.plot(x, z)
plt.yscale('log')
plt.xscale('log')
plt.xlim(90, 98)
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.plot(x, y, label = 'y=x**2')
plt.plot(x, z, label = 'y=e**x')
plt.legend(loc="upper left")
plt.xlim(95, 99)
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit_df=pd.read_csv('C:/Users/magavald/Desktop/Ironhack/Week4/lab-matplotlib-seaborn/your-code/Fitbit2.csv')
fitbit_df.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
os.mkdir('figures')

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

months_df=fitbit_df.groupby(by=['Months_encoded']).median()[['Steps']].reset_index()
x=months_df['Months_encoded'].tolist()
y=months_df['Steps'].tolist()
ax1.bar(x,y)
ax1.set_xlabel(xlabel='Months of the year')
ax1.set_ylabel(ylabel='Median steps')
ax1.set_xticks(ticks=x)

week_df=fitbit_df.groupby(by=['Work_or_Weekend']).median()[['Steps']].reset_index()
x=week_df['Work_or_Weekend'].tolist()
y=week_df['Steps'].tolist()
ax2.bar(x,y)
ax2.set_xticks(ticks=x)
ax2.set_xticklabels(['Work','Weekend'])
ax2.set_ylabel(ylabel='Median steps')
ax2.set_ylim(9500, 10500)

plt.savefig('figures/fitbit.pdf') 
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
def scatter_plot(x):
    x = x.tolist()
    y = fitbit_df['Steps'].tolist()
    plt.scatter(x,y)

# %%
scatter_plot(fitbit_df['Minutes Lightly Active'])

# %%
scatter_plot(fitbit_df['Minutes Very Active'])

# %%
scatter_plot(fitbit_df['Minutes Sedentary'])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic_df=pd.read_csv('C:/Users/magavald/Desktop/Ironhack/Week4/lab-matplotlib-seaborn/your-code/titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
titanic_df.select_dtypes(include=numerics).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
titanic_df.select_dtypes(exclude=numerics).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.figure(figsize=(12,6))
plt.hist(titanic_df['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.figure(figsize=(12,6))
plt.hist(titanic_df['Age'], bins=10)
plt.show()

# %%
# your code here
plt.figure(figsize=(12,6))
plt.hist(titanic_df['Age'], bins=20)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.hist(titanic_df['Age'], bins=50)
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The more number of bins, the better detail we have on the distribution of the data. However, the more complex can be to analyze the graph. 
"""
# Out:
# '\nThe more number of bins, the better detail we have on the distribution of the data. However, the more complex can be to analyze the graph. \n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.displot(titanic_df['Age'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.hist(titanic_df['Gender'], bins=2)
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.histplot(titanic_df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
pclass_fig = sns.histplot(titanic_df['Pclass'])
pclass_fig.set(xticks=titanic_df['Pclass'].tolist())
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic_df['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# your code here
sns.boxplot(titanic_df['Age'])
plt.show()
# Out:
# C:\Users\magavald\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
"""
I'd use a boxplot as it allows you to see the quartiles, the median and outliers. 
"""
# Out:
# "\nI'd use a boxplot as it allows you to see the quartiles, the median and outliers. \n"

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The median age was around 28.5 years old and 50% of the people were between 22 years old and 37 years old.
"""
# Out:
# '\nThe median age was around 28.5 years old and 50% of the people were between 22 years old and 37 years old.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
f, (ax_box, ax_hist) = plt.subplots(2)
sns.boxplot(titanic_df["Age"], ax=ax_box)
sns.histplot(titanic_df['Age'], ax=ax_hist)
# Out:
# C:\Users\magavald\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
We can see that we had some babies (0-2 years old) and very few old people (>60 years old). Also we can see that there was a lot of people in their early 20's.
"""
# Out:
# "\nWe can see that we had some babies (0-2 years old) and very few old people (>60 years old). Also we can see that there was a lot of people in their early 20's.\n"

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
x=np.array(titanic_df['Age'])
y=np.array(titanic_df['Fare'])
m, b = np.polyfit(x, y,1)
plt.plot(x, y, 'o')
plt.plot(x, (m*x)+b)

# %%
# Method 2 - seaborn
x=titanic_df['Age'].tolist()
y=titanic_df['Fare'].tolist()
sns.regplot(x,y, color='b',line_kws={'color': 'black'}).margins(x=0,y=0)
# Out:
# C:\Users\magavald\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most postively correlated metrics are 'Fare' and 'Survived'. The more you paid, the more chances you had to survive.

'Pclass' is negatively correlated with 'Survived','Age' and 'Fare', which makes sense as the lower the class number (1 is lowest, although it's the best class), the higher the chances to survive and the higher the fare you paid. Also, older people tend to be in a lower class number.  
"""
# Out:
# "\nThe most postively correlated metrics are 'Fare' and 'Survived'. The more you paid, the more chances you had to survive.\n\n'Pclass' is negatively correlated with 'Survived','Age' and 'Fare', which makes sense as the lower the class number (1 is lowest, although it's the best class), the higher the chances to survive and the higher the fare you paid. Also, older people tend to be in a lower class number.  \n"

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x=titanic_df['Pclass'], y=titanic_df['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.displot(titanic_df, x='Age', hue='Gender')
