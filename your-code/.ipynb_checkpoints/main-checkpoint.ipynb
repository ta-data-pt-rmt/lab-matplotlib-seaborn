# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'r--')
plt.show()
plt.plot(x,z,'b.')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
#plt.subplots(nrows=1, ncols=2)
plot_options,[plot1,plot2] =plt.subplots(nrows=1, ncols=2 ,figsize= (20,10))
plot1.plot(x,y)
plot2.plot(x,z)

# %% [markdown]
# ### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
plot_options,[plot1,plot2] =plt.subplots(nrows=1, ncols=2 ,figsize= (15,5))

plt.suptitle('Example of subplot',fontsize=25, fontweight='bold')

plt.subplot(1,2,1)
plot1.plot(x,y,linewidth=4)
plt.title('Plot 1: 1st line',loc='left',fontsize=15,pad=15)
plt.ylabel('Vertical')
plt.xlabel('Horizontal')


plt.subplot(1,2,2)
plot2.plot(x,z,linewidth=8)
plt.title('Plot 2: 1st expo',loc='right',fontsize=10,pad=10)
plt.ylabel('Vertical1')
plt.xlabel('Horizontal1')

#https://pythonguides.com/matplotlib-subplot-tutorial/
# Out:
# Text(0.5, 0, 'Horizontal1')

# %% [markdown]
# ### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y = x^2
plt.plot(y,np.exp(y))
plt.xscale('log')

# %%
plt.plot(x,np.exp(y))
plt.yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.plot(x,np.exp(y))
plt.legend(['Single line'])

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.shape
# Out:
# (367, 24)

# %%
fitbit.dtypes
# Out:
# Date                           object
# Calorie burned                  int64
# Steps                           int64
# Distance                      float64
# Floors                          int64
# Minutes Sedentary             float64
# Minutes Lightly Active          int64
# Minutes Fairly Active           int64
# Minutes Very Active             int64
# Activity Calories               int64
# MinutesOfSleep                  int64
# MinutesOfBeingAwake             int64
# NumberOfAwakings                int64
# LengthOfRestInMinutes           int64
# Distance_miles                float64
# Days                           object
# Days_encoded                  float64
# Work_or_Weekend                 int64
# Hours Sleep                   float64
# Sleep efficiency              float64
# Yesterday_sleep               float64
# Yesterday_sleep_efficiency    float64
# Months                         object
# Months_encoded                  int64
# dtype: object

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

median_month = fitbit.groupby(['Months_encoded']).agg({'Steps':'median'})
median_work = (fitbit[fitbit['Work_or_Weekend']== 0]).groupby(['Months_encoded']).agg({'Steps':'median'})
median_weekend = (fitbit[fitbit['Work_or_Weekend']== 1]).groupby(['Months_encoded']).agg({'Steps':'median'})

plot_options,[plot1,plot2,plot3,plot4] =plt.subplots(nrows=1, ncols=4 ,figsize= (15,4))
plt.suptitle('Visualization to show the median steps by month',fontsize=10, fontweight='bold')

plt.subplot(1,4,1)
plot1.plot(median_month,"r",label='Median_month',linewidth=1)

plot1.plot(median_work,linewidth=1)
plot1.plot(median_weekend,linewidth=1)
plt.title('Median by Month,week,weekend',loc='left',fontsize=10,pad=5)
plt.ylabel('Steps')
plt.xlabel('Months')
plt.xticks(fitbit["Months_encoded"], fitbit["Months_encoded"], rotation ='vertical')

plt.subplot(1,4,2)
plot2.plot(median_month,linewidth=2)
plt.title('Median by Month',loc='left',fontsize=10,pad=5)
plt.xticks(fitbit["Months_encoded"], fitbit["Months_encoded"], rotation ='vertical')

plt.subplot(1,4,3)
plot3.plot(median_work,linewidth=2)
plt.title('Median by Work',loc='left',fontsize=10,pad=5)
plt.xticks(fitbit["Months_encoded"], fitbit["Months_encoded"], rotation ='vertical')

plt.subplot(1,4,4)
plot4.plot(median_weekend,linewidth=2)
plt.title('Median by Weekend',loc='left',fontsize=10,pad=5)
plt.xticks(fitbit["Months_encoded"], fitbit["Months_encoded"], rotation ='vertical')
plt.show()
# your code here

# MEDIAN STEPS BY WORK_OR_WEEKEND

#median_workorweekend = fitbit.groupby(['Months_encoded','Work_or_Weekend']).agg({'Steps':'median'})
#median_workorweekend

# your code here

# %%
median_month = fitbit.groupby(['Months_encoded']).agg({'Steps':'median'}).reset_index()
median_month


median_workwwkend = fitbit.groupby(['Work_or_Weekend']).agg({'Steps':'median'}).reset_index()
median_workwwkend





fig, ax = plt.subplots(1, 2,figsize= (12,4)) 
axes = axes.flatten() 

plt.suptitle('Fitbitter Visualization',fontsize=10, fontweight='bold')

plt.sca(ax[0])
plt.bar(median_month['Months_encoded'],median_month['Steps'])
plt.xticks(median_month["Months_encoded"], median_month["Months_encoded"], rotation ='vertical')
plt.title('Median steps by month')
plt.ylabel('Steps')
plt.xlabel('Months')


plt.sca(ax[1])
plt.bar(median_workwwkend['Work_or_Weekend'],median_workwwkend['Steps'])
#plt.xticks(median_workwwkend['Work_or_Weekend'],(median_workwwkend['Work_or_Weekend']), fontsize=10,rotation=45)
plt.xticks(median_workwwkend['Work_or_Weekend'],(['Week', 'Weekend']), fontsize=10,rotation=45)
plt.title('Median steps by Work and Weekend')
plt.ylabel('Steps')



plt.show()

# %%
median_month = fitbit.groupby(['Months_encoded']).agg({'Steps':'median'}).reset_index()
median_month


median_workwwkend = fitbit.groupby(['Work_or_Weekend']).agg({'Steps':'median'}).reset_index()
median_workwwkend


plot_options,[plot1,plot2] =plt.subplots(nrows=1, ncols=2 ,figsize= (12,4))
plt.suptitle('Fitbitter Visualization',fontsize=10, fontweight='bold')


plt.subplot(1,2,1)

plot1.bar(median_month['Months_encoded'],median_month['Steps'])
plt.xticks(median_month["Months_encoded"], median_month["Months_encoded"], rotation ='vertical')
plt.title('Median steps by month')
plt.ylabel('Steps')
plt.xlabel('Months')

plt.subplot(1,2,2)
plot2.bar(median_workwwkend['Work_or_Weekend'],median_workwwkend['Steps'])
#plt.xticks(median_workwwkend['Work_or_Weekend'],(median_workwwkend['Work_or_Weekend']), fontsize=10,rotation=45)
plt.xticks(median_workwwkend['Work_or_Weekend'],(['Week', 'Weekend']), fontsize=10,rotation=45)
plt.title('Median steps by Work and Weekend')
plt.ylabel('Steps')

#plt.savefig("../Documents/Ironhack bootcamp/Week4/Day2/Lab_day2_week4/lab-matplotlib-seaborn/your-code/figures/fig.png")

plt.savefig("./figures/fig.png")
plt.show()

# %%
median_month = fitbit.groupby(['Months_encoded']).agg({'Steps':'median'}).reset_index()
median_month
plt.bar(median_month['Months_encoded'],median_month['Steps'])
plt.xticks(median_month["Months_encoded"], median_month["Months_encoded"], rotation ='vertical')
plt.title('Median steps by month')
plt.ylabel('Steps')
plt.xlabel('Months')
plt.show()

# %%
median_workwwkend = fitbit.groupby(['Work_or_Weekend']).agg({'Steps':'median'}).reset_index()
median_workwwkend
plt.bar(median_workwwkend['Work_or_Weekend'],median_workwwkend['Steps'])
#plt.xticks(median_workwwkend['Work_or_Weekend'],(median_workwwkend['Work_or_Weekend']), fontsize=10,rotation=45)
plt.xticks(median_workwwkend['Work_or_Weekend'],(['Week', 'Weekend']), fontsize=10,rotation=45)
plt.title('Median steps by Work and Weekend')
plt.ylabel('Steps')
plt.xlabel('Months')
plt.show()

# %%
fitbit.dtypes
# Out:
# Date                           object
# Calorie burned                  int64
# Steps                           int64
# Distance                      float64
# Floors                          int64
# Minutes Sedentary             float64
# Minutes Lightly Active          int64
# Minutes Fairly Active           int64
# Minutes Very Active             int64
# Activity Calories               int64
# MinutesOfSleep                  int64
# MinutesOfBeingAwake             int64
# NumberOfAwakings                int64
# LengthOfRestInMinutes           int64
# Distance_miles                float64
# Days                           object
# Days_encoded                  float64
# Work_or_Weekend                 int64
# Hours Sleep                   float64
# Sleep efficiency              float64
# Yesterday_sleep               float64
# Yesterday_sleep_efficiency    float64
# Months                         object
# Months_encoded                  int64
# dtype: object

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
x1 = fitbit['Minutes Lightly Active']
x2 = fitbit['Minutes Very Active']
x3 = fitbit['Minutes Sedentary']
y = fitbit['Steps']
#y2 = fitbit['Steps']
#y3 = fitbit['Steps']

fig, axes = plt.subplots(1, 3,figsize= (12,4)) 
axes = axes.flatten() 

for i in range(3):
    plt.sca(axes[i])
    plt.scatter(x,y)

# %%
plt.scatter(x1,y)

# %%
plt.scatter(x2,y)

# %%
plt.scatter(x3,y)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
# Out:
# (1309, 12)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.shape
# Out:
# (1309, 12)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S

# %%
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass  \
# 225           226       0.0       3
# 297           298       0.0       1
# 406           407       0.0       3
# 1059         1060       NaN       1
# 849           850       1.0       1
#
#                                                    Name  Gender        Age  \
# 225                        Berglund, Mr. Karl Ivar Sven    male  22.000000
# 297                        Allison, Miss. Helen Loraine  female   2.000000
# 406                    Widegren, Mr. Carl/Charles Peter    male  51.000000
# 1059  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female  40.181552
# 849        Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  44.078850
#
#       SibSp  Parch   Ticket      Fare    Cabin Embarked
# 225       0      0  PP 4348    9.3500       U0        S
# 297       1      2   113781  151.5500  C22 C26        S
# 406       0      0   347064    7.7500       U0        S
# 1059      0      0    17770   27.7208       U0        C
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
num_var = titanic.select_dtypes(include=['float64','int64'])
num_var
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
num_cat = titanic.select_dtypes(include=['object'])
num_cat
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
from matplotlib import style
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-notebook')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
titanic['bins'] = pd.cut(x=titanic['Age'], bins=[10,20,50,100] )#, labels=[10,20,50] )
titanic[['Age','bins']]
# Out:
#             Age      bins
# 0     22.000000  (20, 50]
# 1     38.000000  (20, 50]
# 2     26.000000  (20, 50]
# 3     35.000000  (20, 50]
# 4     35.000000  (20, 50]
# ...         ...       ...
# 1304  29.513190  (20, 50]
# 1305  39.000000  (20, 50]
# 1306  38.500000  (20, 50]
# 1307  29.513190  (20, 50]
# 1308  25.315435  (20, 50]
#
# [1309 rows x 2 columns]

# %%
titanic.groupby(['bins']).agg({'Age':'mean'})
# Out:
#                  Age
# bins
# (10, 20]   17.046995
# (20, 50]   31.742019
# (50, 100]  58.520549

# %%
def calcbins(age):
    #will calculate and group ages in bins
    if age < 20:
        return 10
    elif (age >=20) & (age <50):
        return 20
    elif age >= 50:
        return 50

# %%
calcbins(51)
# Out:
# 50

# %%
titanic['bin'] = titanic['Age'].apply(calcbins)
titanic[['Age','bin']].sample(8)
# Out:
#             Age  bin
# 131   20.000000   20
# 995   16.000000   10
# 229   12.671518   10
# 211   35.000000   20
# 1209  27.000000   20
# 1241  45.000000   20
# 215   31.000000   20
# 1182  30.000000   20

# %%
plt.hist(titanic['bin'])
plt.show()

# %%
plot_options,[plot1,plot2,plot3] =plt.subplots(nrows=1, ncols=3 ,figsize= (12,4))
plt.suptitle('Distribution by bins 10, 20, 50',fontsize=10, fontweight='bold')


plt.subplot(1,3,1)
plot1.hist(titanic['Age'][titanic['bin'] ==10])


plt.subplot(1,3,2)
plot2.hist(titanic['Age'][titanic['bin'] ==20])

plt.subplot(1,3,3)
plot3.hist(titanic['Age'][titanic['bin'] ==50])

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
It groups the values wuth the bins, letting analizing where is the distribution by ages in the range I selected (0-20) bin 10
[20-50) bin 20 and [50 -..) bin 50. So we can analize that the mayor population of the titanic was between ages from 20-50 years
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

import seaborn as sns
sns.boxplot(y = 'Age', x = 'bin', data = titanic)
# Out:
# <AxesSubplot:xlabel='bin', ylabel='Age'>

# %%
sns.boxplot(y = 'Age', data = titanic)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.catplot(data=titanic, kind="swarm", y="Age")
# Out:
# C:\dataanalyst\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic['Gender'].value_counts()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
titanic['Gender'].value_counts().plot.bar()
plt.show()

# %%
gender= titanic["Gender"].value_counts().rename_axis('gender').reset_index(name='quantity')
plt.bar(gender['gender'],gender['quantity'])
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.displot(data=titanic, x="Gender")
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code hereA
titanic['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
titanic['Pclass'].value_counts().plot.bar()
plt.show()
sns.displot(data=titanic, x="Pclass")
plt.xticks(titanic['Pclass'], fontsize= 10,rotation=0)

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.style.use('classic')
plt.hist(titanic['Age'])
plt.show()

# %%
"""
I would use the histogram, because it let you see in a quick view the distribution of ages
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The mayority of the population in the Titanic was betwwen the ages of 20-40
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Fare'],titanic['Age'])
plt.show()

# %%
plt.matshow(titanic[['Fare','Age']].corr())
plt.colorbar()
plt.show()

# %%
titanic[['Fare','Age']].corr()
# Out:
#           Fare       Age
# Fare  1.000000  0.171355
# Age   0.171355  1.000000

# %%
# Method 2 - seaborn
# your code here

sns.lmplot(data=titanic, y='Fare', x='Age')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic[['Fare','Age']].corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
# bin             0.019391 -0.047126 -0.334831  0.795731 -0.179331 -0.121717
#
#                  Fare       bin
# PassengerId  0.031128  0.019391
# Survived     0.257307 -0.047126
# Pclass      -0.558683 -0.334831
# Age          0.171355  0.795731
# SibSp        0.160349 -0.179331
# Parch        0.221635 -0.121717
# Fare         1.000000  0.154571
# ...

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
I dont see correlation, in order to start having correlation, it should have at least.60 or higher. And the highst is wwith 
corr neg is between Pclass and Fare with -.55
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
#plt.boxplot(titanic['Pclass'],titanic['Age'])
#plt.xticks(titanic['Pclass'], fontsize= 10,rotation=0)
sns.boxplot(y = 'Age', x = 'Pclass', data = titanic)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
import seaborn
# Form a facetgrid using columns with a hue
graph = seaborn.FacetGrid(titanic, col ="Gender"  )
# map the above form facetgrid with some attributes
graph.map(plt.hist, "Age", edgecolor ="w").add_legend()
# show the object
plt.show()
