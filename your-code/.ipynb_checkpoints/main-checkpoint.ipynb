# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y,'m--')
plt.title('First Plot')
# Out:
# Text(0.5, 1.0, 'First Plot')

# %%
plt.plot(x,z,'g:')
plt.title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
f, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(x,y,'m--')
ax2.plot(x,z,'g:')
ax1.set_title('First Plot')
ax2.set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(12,4))

with sns.axes_style("whitegrid"):

    ax1.plot(x,y,'m--')
    ax2.plot(x,z,'g:')
    ax1.set_title('First Plot',fontsize=(15))
    ax2.set_title('Second Plot',fontsize=(15))

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(x, x**2,'g')
ax1.plot(x, np.exp(x),'b')
ax1.set_title("Normal Plot")

ax2.plot(x, x**2,'g')
ax2.plot(x, np.exp(x),'b')
ax2.set_yscale("log")
ax2.set_title("Lograrithmic Plot")
# Out:
# Text(0.5, 1.0, 'Lograrithmic Plot')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
ax1.plot(x, x**2,'g')
ax1.plot(x, np.exp(x),'b')
ax1.set_title('Normal Plot')
ax1.legend(['Line 1','Line 2'])

ax2.plot(x, x**2,'g')
ax2.plot(x, np.exp(x),'b')
ax2.set_yscale('log')
ax2.set_title('Lograrithmic Plot')
ax2.legend(['Line 1','Line 2'])

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('Fitbit2.csv')

fitbit.sample(5)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 32   2015-06-09            3072  11338      8.42      28              806.0
# 215  2015-12-09            3062  10026      7.45      17              803.0
# 21   2015-05-29            2558    565      4.20       8              789.0
# 83   2015-07-30            3246  14105     10.48      20              718.0
# 334  2016-04-05             383  20154     15.05       3              445.0
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 32                      228                     43                   31
# 215                     204                     29                   38
# 21                      208                      0                    0
# 83                      225                     60                   44
# 334                     471                     28                   45
#
#      Activity Calories  ...  Distance_miles       Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

steps_by_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()


# MEDIAN STEPS BY WORK_OR_WEEKEND

steps_by_work = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()


# PLOT MEDIAN STEPS BY MONTH_ENCODED

months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

f, ax = plt.subplots(1, 2)

plt.figure(figsize = (10,4))
plt.bar(steps_by_month['Months_encoded'], steps_by_month['Steps'], color = ['purple'])
plt.title('Median Steps by Month')

plt.xticks(steps_by_month['Months_encoded'], labels = months, rotation = 45)
plt.sca(ax[0])

plt.show()

# I tried to save it but it doesn't work:
# plt.savefig('figures/steps_by_month.png')
# plt.savefig('users/maria/desktop/ironhack/lab-matplotlib-seaborn/figures/steps_by_month.png')


# PLOT MEDIAN STEPS BY WORK_OR_WEEKEND

work_weekend = ['Work','Weekend']

f, ax = plt.subplots(1, 2)

plt.figure(figsize = (6,4))
plt.bar(steps_by_work['Work_or_Weekend'], steps_by_work['Steps'], color = ['violet'])
plt.title('Median Steps by Work or Weekend')

plt.xticks(steps_by_work['Work_or_Weekend'], labels = work_weekend, rotation=45)
plt.sca(ax[1])

plt.show()

# I tried to save it but it doesn't work:
# plt.savefig('figures/steps_by_work.png')
# plt.savefig('users/maria/desktop/ironhack/lab-matplotlib-seaborn/figures/steps_by_work.png')

# Also, how do we get rid of the plot without data?

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
activity = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
plot_titles = ['Minutes Lightly Active vs Steps','Minutes Very Active vs Steps','Minutes Sedentary vs Steps']

for i in activity:
    plt.scatter(fitbit[i], fitbit['Steps'], color = ['seagreen'])
    plt.show()

# I would like to add the titles but I don't know how in the loop. I tried with: plt.title(plot_titles[i])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

numerical = titanic.select_dtypes(include='number')
numerical.sample(5)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 858           859       1.0       3  24.000000      0      3  19.2583
# 84             85       1.0       2  17.000000      0      0  10.5000
# 607           608       1.0       1  27.000000      0      0  30.5000
# 1158         1159       NaN       3  29.546883      0      0   7.5500
# 1020         1021       NaN       3  24.000000      0      0   8.0500

# %%
# CATEGORICAL VARIABLES

categorical = titanic.select_dtypes(exclude='number')
categorical.sample(5)
# Out:
#                                            Name  Gender  Ticket Cabin Embarked
# 925                    Mock, Mr. Philipp Edmund    male   13236   C78        C
# 236                           Hold, Mr. Stephen    male   26707    U0        S
# 251  Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  347054    G6        S
# 631                 Lundahl, Mr. Johan Svensson    male  347743    U0        S
# 554                          Ohman, Miss. Velin  female  347085    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic['Age'], color = "sandybrown")
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
f, ax = plt.subplots(1,3, figsize=(18,5))

plt.sca(ax[0])
plt.hist(titanic['Age'], bins=10, color = "lightcoral")
plt.title('bin=10')

plt.sca(ax[1])
plt.hist(titanic['Age'], bins=20, color = "lightcoral")
plt.title('bin=20')

plt.sca(ax[2])
plt.hist(titanic['Age'], bins=50, color = "lightcoral")
plt.title('bin=50')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Thanks to the use of different bins, we can see in a more detailed way the Age distribution, which will lead to a
better analysis of the data.

"""
# Out:
# '\nThanks to the use of different bins, we can see in a more detailed way the Age distribution, which will lead to a\nbetter analysis of the data.\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

titanic['Gender'].value_counts().plot(kind='bar',color='darkturquoise')
plt.title('Gender of Passengers')
plt.show()

# %%
# Method 2 - seaborn
sns.countplot(titanic.Gender).set(title='Gender of Passengers')
# Out:
# [Text(0.5, 1.0, 'Gender of Passengers')]

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic.sample(2)
# Out:
#       PassengerId  Survived  Pclass                       Name Gender   Age  \
# 971           972       NaN       3       Boulos, Master. Akar   male   6.0
# 1119         1120       NaN       3  Everett, Mr. Thomas James   male  40.5
#
#       SibSp  Parch     Ticket     Fare Cabin Embarked
# 971       1      1       2678  15.2458    U0        C
# 1119      0      0  C.A. 6212  15.1000    U0        S

# %%
titanic['Pclass'].value_counts().plot(kind = 'bar', color='goldenrod')
plt.show()


# Here I wanted to use Zorder to change the order of the columns to first, second, and third class but idk how

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7feaa0c070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7feaa0c610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7fea9fcd60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7feaa0cbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7feaa0ce80>],
#  'means': []}

# %%
sns.boxplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
I used a boxplot to see the distribution of age, as it has a lot of useful information.
With this plot we can see the quartiles, outliers, etc.

"""
# Out:
# '\nI used a boxplot to see the distribution of age, as it has a lot of useful information.\nWith this plot we can see the quartiles, outliers, etc.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
display(titanic['Age'].mean(),titanic['Age'].median())
# Out:
# 29.879185698255316
# 28.5

# %%
"""
The plot shows that the ages are mostly from early twenties to late thirties. The mean is almost 30 and there are
a few outliers aged +60. We can also see that the median is not exactly in the middle of the box, which indicates
that the ages are skewed.

"""
# Out:
# '\nThe plot shows that the ages are mostly from early twenties to late thirties. The mean is almost 30 and there are\na few outliers aged +60. We can also see that the median is not exactly in the middle of the box, which indicates\nthat the ages are skewed.\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.distplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
I used a distplot in seaborn to plot the distribution of variables, I like how clear it shows the data.
Thus, we can see the density of people from different ages and how the curve shows that what stated above
(the ages are skewed) is right, as we can see it directly from this histogram.

"""
# Out:
# '\nI used a distplot in seaborn to plot the distribution of variables, I like how clear it shows the data.\nThus, we can see the density of people from different ages and how the curve shows that what stated above\n(the ages are skewed) is right, as we can see it directly from this histogram.\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.sample(2)
# Out:
#       PassengerId  Survived  Pclass                                     Name  \
# 847           848       0.0       3                       Markoff, Mr. Marin
# 1245         1246       NaN       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#       Gender    Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 847     male  35.00      0      0     349213   7.8958    U0        C
# 1245  female   0.17      1      2  C.A. 2315  20.5750    U0        S

# %%
# Method 1 - matplotlib

plt.scatter(titanic['Age'],titanic['Fare'])

# %%
# Method 2 - seaborn

sns.scatterplot(x=titanic['Age'],y=titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""

Sibsp (# of siblings/spouses aboard) and Parch (# of parents/children aboard) has the highest correlation.
It makes sense as usually families travelled together. 

Also, there is some correlation between survival and tickets fare, meaning that the wealthiest had a sort of 
priority in their emergency boats and thus more of them survived

Finally, tickets fare have obviously a negative correlation with the passengers' class (if you pay more you have
a better class, the cheapest tickets are for the standard class)

"""
# Out:
# "\n\nSibsp (# of siblings/spouses aboard) and Parch (# of parents/children aboard) has the highest correlation.\nIt makes sense as usually families travelled together. \n\nAlso, there is some correlation between survival and tickets fare, meaning that the wealthiest had a sort of \npriority in their emergency boats and thus more of them survived\n\nFinally, tickets fare have obviously a negative correlation with the passengers' class (if you pay more you have\na better class, the cheapest tickets are for the standard class)\n\n"

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
gender = sns.FacetGrid(titanic, col = "Gender",height=5)                     
gender.map(sns.histplot, "Age", color='pink')
