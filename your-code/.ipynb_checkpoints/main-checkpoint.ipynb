# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

# Plot y
axs[0].plot(x, y, linewidth=2, linestyle='-', color='blue')
axs[0].set_title('y = sin(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

# Plot z
axs[1].plot(x, z, linewidth=2, linestyle='--', color='red')
axs[1].set_title('z = cos(x)')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(8, 6))

# Plot y
axs[0].plot(x, y, linewidth=2, linestyle='-', color='blue')
axs[0].set_title('y = sin(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

# Plot z
axs[1].plot(x, z, linewidth=2, linestyle='--', color='red')
axs[1].set_title('z = cos(x)')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

# Plot y in the first subplot
axs[0].plot(x, y, color='blue')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_title('y = sin(x)')

# Plot z in the second subplot
axs[1].plot(x, z, color='red')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].set_title('z = cos(x)')

# Display the plot
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 20))

# Plot y in the first subplot
axs[0].plot(x, y, color='blue')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_title('y = sin(x)')

# Plot z in the second subplot
axs[1].plot(x, z, color='red')
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].set_title('z = cos(x)')

# Display the plot
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y1 = x**2
y2 = np.exp(x)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, y1, label='y=x^2')
ax.plot(x, y2, label='y=e^x')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Normal Scale')
ax.legend()


fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, y1, label='y=x^2')
ax.plot(x, y2, label='y=e^x')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Logarithmic Scale')
ax.set_xscale('symlog')
ax.set_yscale('symlog')
ax.legend()


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('C:\\Users\\miquelemelo\\Desktop\\Ironhack\\Week 4\\day 2\\lab-matplotlib-seaborn\\your-code\Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# Converting Months to a categorical variable
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
fitbit['Months'] = pd.Categorical(fitbit['Months'], categories=months, ordered=True)

# Grouping the data by month and calculate the median number of steps
steps_by_month = fitbit.groupby('Months')['Steps'].median()

# Group the data by Weekday/Weekend and calculate the median number of steps
steps_by_day = fitbit.groupby('Work_or_Weekend')['Steps'].median()

# Create the figure and subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

# Plot the median steps by month
plt.sca(axs[0])
steps_by_month.plot(kind='bar')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Median Steps')
plt.title('Median Steps by Month')

# Plot the median steps by weekday/weekend
plt.sca(axs[1])
steps_by_day.plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel('Day Type')
plt.ylabel('Median Steps')
plt.title('Median Steps by Workday/Weekend')

# Save the figures
fig.savefig('figures/fitbit_steps.png')

# Display the plot
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for feat in features:
    plt.scatter(fitbit[feat], fitbit['Steps'])
    plt.xlabel(feat)
    plt.ylabel('Steps')
    plt.title(f'Steps vs {feat}')
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("C:\\Users\\miquelemelo\\Desktop\\Ironhack\\Week 4\\day 2\\lab-matplotlib-seaborn\\your-code\\titanic.csv")
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# columns
numerical_cols = titanic.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical columns:", numerical_cols)
# Out:
# Numerical columns: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# CATEGORICAL VARIABLES
categorical_cols = titanic.select_dtypes(include=['object']).columns.tolist()
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: ['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# Set the plot style to classic
plt.style.use('classic')

# Set the figure size to (12,6)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))
plt.hist(titanic['Age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.style.use('classic')
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))


axes[0].hist(titanic['Age'], bins=10)
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Histogram of Age (Bins = 10)')

axes[1].hist(titanic['Age'], bins=20)
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Histogram of Age (Bins = 20)')

axes[2].hist(titanic['Age'], bins=50)
axes[2].set_xlabel('Age')
axes[2].set_ylabel('Frequency')
axes[2].set_title('Histogram of Age (Bins = 50)')


plt.tight_layout()


plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size affects the level of granularity of the histogram plot.

A smaller bin size creates more bins, and thus more detailed and granular plot. This allows you to identify more specific patterns and trends in the data, but can also create noise and hide overall patterns.

On the other hand, a larger bin size creates fewer bins and a less detailed plot, which allows you to identify overall patterns and trends more easily. However, it may also hide important variations in the data.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))


sns.distplot(titanic["Age"].dropna(), kde=True, bins=30, color="blue")

plt.title("Distribution of Age", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Density", fontsize=14)


plt.show()
# Out:
# C:\Users\miquelemelo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

gender_counts = titanic["Gender"].value_counts()

plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(6,6))


plt.bar(gender_counts.index, gender_counts.values, color=["blue", "pink"])


plt.title("Gender Counts", fontsize=16)
plt.xlabel("Gender", fontsize=14)
plt.ylabel("Count", fontsize=14)


plt.show()

# %%
# Method 2 - seaborn

sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
sns.countplot(x="Gender", data=titanic, palette=["blue", "pink"])
plt.title("Gender Counts", fontsize=16)
plt.xlabel("Gender", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
sns.countplot(x="Pclass", data=titanic, palette="Blues")
plt.title("Passenger Class Counts", fontsize=16)
plt.xlabel("Passenger Class", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
sns.boxplot(x="Age", data=titanic, color="lightblue")
plt.title("Summary Statistics of Age", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The last plot, which is a box plot of the "Age" feature, provides a summary of the distribution of ages in the Titanic dataset. 
From the plot, we can see that:
The median age is around 28 years old.
The majority of passengers were between the ages of approximately 20 and 40, as indicated by the height and width of the box.
There were some outliers on the higher end of the age range, with the oldest passenger being around 80 years old.
The distribution of ages is slightly skewed to the right, as indicated by the longer whisker on the upper end of the box.
Overall, the box plot suggests that the majority of passengers on the Titanic were relatively young adults, 
with a few older individuals also present.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(12,6))
sns.violinplot(data=titanic, x='Age', ax=ax, color='lightblue')
plt.title('Distribution of Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The last plot, which is a violin plot, provides additional information about the distribution of the feature Age. 
It not only shows the summary statistics (i.e., median, quartiles, and outliers) but also displays the shape of the distribution.

In this particular case, the violin plot shows that the distribution of ages is roughly bimodal,
with two peaks in the density of the distribution around 20-30 years and 40-50 years, respectively. 
Additionally, the plot shows that there are several outliers with ages above 65 years.

Overall, the violin plot gives a more complete picture of the distribution of the Age feature than the summary statistics alone,
as it provides information on both the central tendency and the spread of the distribution, 
as well as any skewness and the presence of multiple modes.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.figure(figsize=(8,6))
plt.scatter(x=titanic['Age'], y=titanic['Fare'])
plt.title('Scatter plot of Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
plt.figure(figsize=(8,6))
sns.scatterplot(data=titanic, x='Age', y='Fare')
plt.title('Scatter plot of Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
import seaborn as sns

corr = titanic.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Looking at the heatmap, the most correlated features in the Titanic dataset are:

Pclass and Fare: -0.55 (negative correlation)
SibSp and Parch: 0.41 (positive correlation)
It's also worth noting that Age and Fare have a moderate negative correlation of -0.1.
"""
# Out:
# "\nLooking at the heatmap, the most correlated features in the Titanic dataset are:\n\nPclass and Fare: -0.55 (negative correlation)\nSibSp and Parch: 0.41 (positive correlation)\nIt's also worth noting that Age and Fare have a moderate negative correlation of -0.1.\n"

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(12, 6))


g = sns.FacetGrid(titanic, col='Gender', height=6)


g.map(sns.histplot, 'Age', bins=20)


g.set_axis_labels('Age', 'Count')
g.fig.suptitle('Distribution of Age by Gender', fontsize=16, y=1.05)


plt.show()
