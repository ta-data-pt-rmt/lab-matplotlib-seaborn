# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib.pyplot as plt 
import seaborn as sns

import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(y,x)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
plot_options , (chart_1, chart_2) = plt.subplots(nrows =1, ncols = 2)

chart_1.plot(x, y)
chart_2.plot(y, x)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
plot_options , (chart_1, chart_2) = plt.subplots(nrows =1, ncols = 2, figsize = (20,10))

chart_1.plot(x, y)
chart_2.plot(y, x)

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal")
axes[0].set_label('I Am Legend #1')

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic")
axes[1].set_label('I Am Legend #2')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal")
axes[0].legend(['I Am Legend #1', 'I Am Legend #2'])

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic")
axes[1].legend(['I Am Legend #1', 'I Am Legend #2'])

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit2 = pd.read_csv('Fitbit2.csv')

# %%
fitbit2.head(5)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

steps_per_month = fitbit2.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()
fig, ax = plt.subplots(2, 1)

plt.figure(figsize = (12,4))
plt.bar(steps_per_month['Months_encoded'],steps_per_month['Steps'])
plt.xticks(fontsize=10)
plt.sca(ax[0])
plt.show()
plt.savefig('figures/steps_per_month.png')

# MEDIAN STEPS BY WORK_OR_WEEKEND
            
steps_by_work = fitbit2.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()
fig, ax2 = plt.subplots(2, 1)

plt.figure(figsize = (12,4))
plt.bar(steps_by_work['Work_or_Weekend'],steps_by_work['Steps'])
plt.xticks(fontsize=10)
plt.sca(ax2[1])
plt.show()
plt.savefig("figures/steps_by_work.png")

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
minutes = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for column in minutes:
    plt.scatter(fitbit2[column], fitbit2['Steps'])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

numerical = titanic.select_dtypes(exclude=['object']).columns
numerical
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES

categorical = titanic.select_dtypes(exclude=['float64','int64']).columns
categorical
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.plot( y = 'Age', kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(3,1)
axes[0].hist(titanic.Age, bins = 10)
axes[1].hist(titanic.Age, bins = 20)
axes[2].hist(titanic.Age, bins = 50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
With figure #3 we can actually see all the different ages due to the proper width of the bars.

"""
# Out:
# '\nWith figure #3 we can actually see all the different ages due to the proper width of the bars.\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic['Gender'].value_counts().plot(kind = 'bar')
plt.show()

# %%
# Method 2 - seaborn
sns.countplot(titanic.Gender)
# Out:
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic['Pclass'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.boxplot(titanic['Age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Just wanted to use this Viz with Survivals by gender and age (Looks Cool)

men = (titanic.Gender == 'male')
women = (titanic.Gender == 'female')

with sns.axes_style(style = None):
    sns.violinplot("Survived", "Age", hue = "Gender", data = titanic,
                   split = True, inner = "quartile",
                   palette = ["lightblue", "pink"]);
# Out:
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
men = (titanic.Gender == 'male')
women = (titanic.Gender == 'female')

with sns.axes_style(style = None):
    sns.violinplot("Survived", "Pclass", hue = "Gender", data = titanic,
                   split = True, inner = "quartile",
                   palette = ["lightblue", "pink"]);
# Out:
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The quartiles can be identified clearly, and the outliers along with the average.

Age is between ~20 and ~38 YO

Extra 1 ~~

The survival rate is higher for females and children between 0 and ~15 YO, as expected (Women and Children first)

Extra 2 ~~

The survival rate is quite Lower for females and males in third class, the other 2 classes had more survivals.

"""
# Out:
# '\nThe quartiles can be identified clearly, and the outliers along with the average.\n\nAge is between ~20 and ~38 YO\n\nExtra 1 ~~\n\nThe survival rate is higher for females and children between 0 and ~15 YO, as expected (Women and Children first)\n\nExtra 2 ~~\n\nThe survival rate is quite Lower for females and males in third class, the other 2 classes had more survivals.\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
print(titanic['Age'].mean())
print(titanic['Age'].median())
# Out:
# 29.879185698255316
# 28.5

# %%
sns.distplot(titanic['Age'], hist=True, kde=True, bins=int(180/5), color = 'darkblue', hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 4})

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Since the mean of age is 29.8 YO and the Median is 28.5 YO we can say that based on the Visualization theres a 
right skewed distribution (Median is to the left of the Mean).
"""
# Out:
# '\nSince the mean of age is 29.8 YO and the Median is 28.5 YO we can say that based on the Visualization theres a \nright skewed distribution (Median is to the left of the Mean).\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

plt.scatter(titanic['Age'],titanic['Fare'])

# %%
# Method 2 - seaborn

sns.scatterplot(data = titanic, x = 'Age', y = 'Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Positive: SibSp & Parch, Survived & Fare, but not that strong postive corr.

Negative: Pclass & Fare, Pclass & Age, Pclass & Survived, really strong negative corr.

"""
# Out:
# '\nPositive: SibSp & Parch, Survived & Fare, but not that strong postive corr.\n\nNegative: Pclass & Fare, Pclass & Age, Pclass & Survived, really strong negative corr.\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
gender = sns.FacetGrid(titanic, col = "Gender")
                               
gender.map(sns.histplot, "Age")

# %%
genders = ['male', 'female']

for gender in genders:    
    subset = titanic[titanic['Gender'] == gender]  
    
    sns.distplot(subset['Age'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = gender)    

plt.legend(prop={'size': 16}, title = 'Gender')
plt.title('Density of Age by Gender')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\FiercePC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
