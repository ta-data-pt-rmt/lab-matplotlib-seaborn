# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

axes[0].plot(x, y, color='blue', linestyle='--', linewidth=2)
axes[0].set_title('Plot of (x, y)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')


axes[1].plot(x, z, color='red', linestyle='-', linewidth=2)
axes[1].set_title('Plot of (x, z)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(x, y, color='blue', linestyle='-.', linewidth=2)
plt.title('Plot of (x, y)')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(1, 2, 2)
plt.plot(x, z, color='red', linestyle=':', linewidth=2)
plt.title('Plot of (x, z)')
plt.xlabel('x')
plt.ylabel('z')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
#Method 1
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

axes[0].plot(x, y, color='blue', linestyle='--', linewidth=2)
axes[0].set_title('Plot of (x, y)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('x', fontsize=12, fontweight='bold')
axes[0].set_ylabel('y', fontsize=12, fontweight='bold')

axes[1].plot(x, z, color='red', linestyle='-', linewidth=2)
axes[1].set_title('Plot of (x, z)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('x', fontsize=12, fontweight='bold')
axes[1].set_ylabel('z', fontsize=12, fontweight='bold')
# Out:
# Text(0, 0.5, 'z')

# %%
#Method 2
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(x, y, color='blue', linestyle='-.', linewidth=2)
plt.title('Plot of (x, y)', fontsize=14, fontweight='bold')
plt.xlabel('x', fontsize=12, fontweight='bold')
plt.ylabel('y', fontsize=12, fontweight='bold')

plt.subplot(1, 2, 2)
plt.plot(x, z, color='red', linestyle=':', linewidth=2)
plt.title('Plot of (x, z)', fontsize=14, fontweight='bold')
plt.xlabel('x', fontsize=12, fontweight='bold')
plt.ylabel('z', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.linspace(0, 2, 100)  

y1 = x ** 2

y2 = np.exp(x)

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label=r'$y = x^2$')

plt.plot(x, y2, label=r'$y = e^x$')

plt.yscale('log')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = x^2$ and $y = e^x$ (log scale)')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
x = np.linspace(0, 2, 100)  

y1 = x ** 2

y2 = np.exp(x)

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label=r'$y = x^2$')

plt.plot(x, y2, label=r'$y = e^x$')

plt.yscale('log')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $y = x^2$ and $y = e^x$ (log scale)')
plt.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit2 = pd.read_csv('Fitbit2.csv')
fitbit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit2.shape
# Out:
# (367, 24)

# %%
fitbit2.dtypes
# Out:
# Date                           object
# Calorie burned                  int64
# Steps                           int64
# Distance                      float64
# Floors                          int64
# Minutes Sedentary             float64
# Minutes Lightly Active          int64
# Minutes Fairly Active           int64
# Minutes Very Active             int64
# Activity Calories               int64
# MinutesOfSleep                  int64
# MinutesOfBeingAwake             int64
# NumberOfAwakings                int64
# LengthOfRestInMinutes           int64
# Distance_miles                float64
# Days                           object
# Days_encoded                  float64
# Work_or_Weekend                 int64
# Hours Sleep                   float64
# Sleep efficiency              float64
# Yesterday_sleep               float64
# Yesterday_sleep_efficiency    float64
# Months                         object
# Months_encoded                  int64
# dtype: object

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
steps_by_month = fitbit2.groupby('Months')['Steps'].median().reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
steps_by_month.plot(kind='bar', color='skyblue')
plt.title('Median Steps by Month')
plt.xlabel('Month')
plt.ylabel('Median Steps')
plt.xticks(rotation=45)
plt.grid(axis='y')

# MEDIAN STEPS BY WORK_OR_WEEKEND
plt.subplot(1, 2, 2)
activity_by_day = fitbit2.groupby('Work_or_Weekend')['Steps'].median()
activity_by_day.index = ['Weekend', 'Workdays']
activity_by_day.plot(kind='bar', color='lightgreen')
plt.title('Median Steps: Weekend vs Workdays')
plt.xlabel('Day Type')
plt.ylabel('Median Steps')
plt.xticks(rotation=0)
plt.grid(axis='y')

plt.savefig('figures/fitbit_visualizations.png')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

plt.figure(figsize=(15, 5))

for i, feature in enumerate(features, start=1):
    plt.subplot(1, 3, i)
    
    plt.scatter(fitbit2[feature], fitbit2['Steps'], alpha=0.5)
    
    plt.title(f'{feature} vs Steps')
    plt.xlabel(feature)
    plt.ylabel('Steps')
    
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
titanic.shape
# Out:
# (1309, 12)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_variables = titanic.select_dtypes(include=['int64', 'float64'])
print("Numerical Variables:")
print(numerical_variables.head())
# Out:
# Numerical Variables:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
categorical_variables = titanic.select_dtypes(include=['object'])
print("\nCategorical Variables:")
print(categorical_variables.head())
# Out:
# Categorical Variables:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.style.use('classic')

plt.figure(figsize=(12, 6))

plt.hist(titanic['Age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution on Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.style.use('classic')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, bins in enumerate([10, 20, 50]):
    ax = axes[i]
    ax.hist(titanic['Age'].dropna(), bins=bins, color='skyblue', edgecolor='black')
    ax.set_title(f'Age Distribution with {bins} Bins')
    ax.set_xlabel('Age')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
the bin size affects the level of detail and resolution of the histogram. 
Choosing an optimal bin size is important for accurately representing the distribution of the data without 
oversimplifying or overcomplicating it
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(titanic['Age'].dropna(), color='skyblue', kde=True)
plt.title('Distribution of Age on Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
gender_counts = titanic['Gender'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])
plt.title('Gender Distribution (Matplotlib)')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
# Method 2 - seaborn
sns.set_style("whitegrid")

plt.figure(figsize=(6, 4))
sns.countplot(data=titanic, x='Gender', palette=['blue', 'pink'])
plt.title('Gender Distribution (Seaborn)')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
pclass_counts = titanic['Pclass'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(pclass_counts.index, pclass_counts.values, color=['skyblue', 'lightgreen', 'salmon'])
plt.title('Passenger Class Distribution (Matplotlib)')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.xticks(pclass_counts.index, labels=['First Class', 'Second Class', 'Third Class'])

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8, 6))
sns.boxplot(data=titanic, y='Age', color='skyblue')
plt.title('Summary Statistics of Age')
plt.ylabel('Age')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
a box plot would be appropriate. 
A box plot displays the median, quartiles, and outliers of a dataset, providing a comprehensive summary of its distribution
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Median Age: The line inside the box represents the median age of the passengers, which appears to be around 28 years.
The box itself represents the middle 50% of the data, with the lower and upper boundaries corresponding to Q1 and Q3. 
This range spans from approximately 21 to 38 years.
The length of the box indicates the spread of the central 50% of the data, showing that the ages of most passengers are concentrated within this range.
Any individual data points lying outside the whiskers of the box plot are considered outliers. 
In this plot, there are a few outliers with ages above approximately 60 years.
Overall, the box plot suggests that the majority of passengers were relatively young, with a median age around 28 years. 
However, there were also some older passengers, as indicated by the outliers.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8, 6))
sns.violinplot(data=titanic, y='Age', color='skyblue')
plt.title('Distribution and Summary Statistics of Age')
plt.ylabel('Age')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Density Estimation: The width of the violin plot at any given point represents the estimated probability density of the data at that age. 
Wider sections indicate higher density, while narrower sections indicate lower density. This provides a more detailed view of the distribution compared to a box plot.
Distribution Shape: The shape of the violin plot provides information about the distribution of ages. 
For example, a wider section in the middle of the plot suggests a higher concentration of ages in that range, while narrow sections or peaks indicate areas with fewer data points.
Summary Statistics: the central line within each violin plot represents the median age. The width of the plot around the median indicates the spread of the data, providing a visual representation of the interquartile range.
Outliers: outliers can still be identified in a violin plot. 
Overall, the violin plot offers a more comprehensive view of the distribution of ages, combining summary statistics with density estimation and distribution shape. 
It provides a useful tool for visualizing the variability and patterns in the data.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.figure(figsize=(8, 6))
plt.scatter(titanic['Age'], titanic['Fare'], color='skyblue', alpha=0.5)
plt.title('Relationship between Fare and Age')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %%
# Method 2 - seaborn
sns.set_style("whitegrid")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=titanic, x='Age', y='Fare', color='skyblue', alpha=0.5)
plt.title('Relationship between Fare and Age')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
numeric_columns = titanic[['Fare', 'Age']]

correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix between Fare and Age')
plt.show()

# %%
numeric_columns = titanic.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Plot the correlation matrix using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
most_correlated_features = correlation_matrix.unstack().sort_values(ascending=False)

most_correlated_features = most_correlated_features[most_correlated_features != 1]

print(most_correlated_features.head(10))
# Out:
# SibSp     Parch       0.373587
# Parch     SibSp       0.373587
# Fare      Survived    0.257307
# Survived  Fare        0.257307
# Fare      Parch       0.221635
# Parch     Fare        0.221635
# Fare      Age         0.171355
# Age       Fare        0.171355
# Fare      SibSp       0.160349
# SibSp     Fare        0.160349
# dtype: float64

# %%
"""
The most correlated features are those pairs with correlation coefficients closest to 1 (for positive correlation) 
or -1 (for negative correlation). 
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))

sns.boxplot(x='Pclass', y='Age', data=titanic)

plt.title('Age Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

g = sns.FacetGrid(titanic, row='Gender', height=4, aspect=2)

g.map(plt.hist, 'Age', bins=20, alpha=0.7)

g.set_titles(row_template='{row_name}', size=16)

g.set_axis_labels('Age', 'Frequency')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

male_age = titanic[titanic['Gender'] == 'male']['Age']
female_age = titanic[titanic['Gender'] == 'female']['Age']

sns.histplot(male_age, bins=20, color='skyblue', alpha=0.7, label='Male')
sns.histplot(female_age, bins=20, color='salmon', alpha=0.7, label='Female')

plt.title('Distribution of Age by Gender')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.legend()

plt.show()
# Out:
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\elora\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
