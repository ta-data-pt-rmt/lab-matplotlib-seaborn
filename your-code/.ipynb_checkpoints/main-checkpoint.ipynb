# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,'g^') #color verde
plt.plot(x,z,'ro') #color rojo
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
plt.subplots(nrows=1, ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A4BDD5DE08>,
# ...
#        dtype=object))

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (100,50))
chart_1.bar(x, y)
chart_2.bar(x, z)
# Out:
# <BarContainer object of 100 artists>

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

#normal scale:
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))

chart_1.bar(x, x^2)
chart_2.bar(x, np.exp(x))


#logartimic scale:
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))

chart_1.bar(x, x^2)
chart_2.bar(x, np.exp(x))

plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# your code here

#normal scale:
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))

chart_1.bar(x, x^2)
chart_2.bar(x, np.exp(x))
plt.xlabel('x value')
plt.ylabel('x^2')
plt.legend()

#logartimic scale:
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (20,10))

chart_1.bar(x, x^2)
chart_2.bar(x, np.exp(x))

plt.xscale('log')
plt.yscale('log')
plt.xlabel('x value')
plt.ylabel('x^2')
plt.legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
#fitbit.groupby(['Steps']).agg({'Months':'mean'})
months_ascending = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September':9,
    'October':10,
    'November':11,
    'December':12
}


fitbit['Order'] = fitbit['Months'].map(months_ascending)
fitbit = fitbit.sort_values(by='Order')
plt.figure(figsize = (40,10)) #tamaño del hueco donde ponemos el nombre abajo de cada barrita
plt.xticks(fontsize=24,rotation=45) #giramos 45 grados las palabras para que entren bien

plt.bar(fitbit['Months'], fitbit['Steps'])


plt.show()
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
days_ascending = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7,
}


fitbit['Order_days'] = fitbit['Days'].map(days_ascending)
fitbit = fitbit.sort_values(by='Order_days')
plt.figure(figsize = (40,10)) #tamaño del hueco donde ponemos el nombre abajo de cada barrita
plt.xticks(fontsize=24,rotation=45) #giramos 45 grados las palabras para que entren bien

# Definir una paleta de colores personalizada
colors = np.where(fitbit['Days'].isin(['Saturday', 'Sunday']), 'r','b')

# Crear un gráfico de barras con colores personalizados

plt.bar(fitbit['Days'], fitbit['Steps'],color=colors)


plt.show()
# MEDIAN STEPS BY WORK_OR_WEEKEND
plt.show()
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
work_weekend = {
    'Monday': 'Work',
    'Tuesday': 'Work',
    'Wednesday': 'Work',
    'Thursday': 'Work',
    'Friday': 'Work',
    'Saturday': 'Weekend',
    'Sunday': 'Weekend',
}


fitbit['work_weekend'] = fitbit['Days'].map(work_weekend)
#fitbit = fitbit.sort_values(by='work_weekend')
plt.figure(figsize = (40,10)) #tamaño del hueco donde ponemos el nombre abajo de cada barrita
plt.xticks(fontsize=24,rotation=45) #giramos 45 grados las palabras para que entren bien

# Definir una paleta de colores personalizada
colors = np.where(fitbit['work_weekend'].isin(['Weekend']), 'r','b')

# Crear un gráfico de barras con colores personalizados

plt.bar(fitbit['work_weekend'], fitbit['Steps'],color=colors)


plt.show()
print('Not too many differences between work days or weekend. However, there are differences between months and also between Sundays and Fridays and the rest of the week')
# Out:
# Not too many differences between work days or weekend. However, there are differences between months and also between Sundays and Fridays and the rest of the week

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

#first way
a = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for element in a:
    plt.scatter(fitbit[element],fitbit['Steps'])

plt.colorbar()

# %%
#including legend
a = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for element in a:
    plt.scatter(fitbit[element],fitbit['Steps'],label=element)

plt.legend()
plt.colorbar()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
print('Numerical variables:')
print(titanic.select_dtypes('float64').columns)
# Out:
# Numerical variables:
# Index(['Survived', 'Age', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
print('Categorical variables:')
print(titanic.select_dtypes('int64').columns)

print('More categorical variables:')
print(titanic.select_dtypes('object').columns)
# Out:
# Categorical variables:
# Index(['PassengerId', 'Pclass', 'SibSp', 'Parch'], dtype='object')
# More categorical variables:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.bar(titanic['Age'],titanic['PassengerId'])
# Out:
# <BarContainer object of 1309 artists>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

plot_options , (chart_1,chart_2,chart_3, chart_4) = plt.subplots(nrows = 1, ncols = 4, figsize = (20,10))

chart_1.bar(titanic[titanic['Age']<=10]['Age'],titanic[titanic['Age']<=10]['PassengerId'])
chart_2.bar(titanic[(titanic['Age']>10)&(titanic['Age']<=20)]['Age'],titanic[(titanic['Age']>10)&(titanic['Age']<=20)]['PassengerId'])
chart_3.bar(titanic[(titanic['Age']>20)&(titanic['Age']<=50)]['Age'],titanic[(titanic['Age']>20)&(titanic['Age']<=50)]['PassengerId'])
chart_4.bar(titanic[titanic['Age']>50]['Age'],titanic[titanic['Age']>50]['PassengerId'])
# Out:
# <BarContainer object of 99 artists>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here: we can analyze with more details each bin 
"""
# Out:
# '\nyour comments here: we can analyze with more details each bin \n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here: debo usar un histograma para ver la distribucion de los datos.


sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))

sns.distplot(titanic['Age'], bins=10, color='skyblue', kde=True)
plt.title('Age Distribution of the passengers of Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic_gender = titanic.groupby('Gender').agg({'PassengerId':'count'}).reset_index()
plt.pie(titanic_gender['PassengerId'], labels=titanic_gender['Gender'],autopct='%1.1f%%', startangle=140)
plt.show()

#grafico de barras:

plt.bar(titanic_gender['Gender'], titanic_gender['PassengerId'],color=colors)
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
#we can use the colors but we cannot paint another pie with seaborn. 

# Contar la frecuencia de mujeres y hombres
female_count = sum(titanic['Gender']=='female')
male_count = sum(titanic['Gender']=='male')
colors = sns.color_palette('Set1')
count_data = [female_count, male_count]

# Crear un gráfico de pastel
plt.figure(figsize=(6, 6))
plt.pie(count_data, labels=['female', 'male'], autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])

plt.show()

#podemos pintar un gráfico de barras.

# Datos de ejemplo
categorias = ['Female','Male']


# Crear un gráfico de barras con Seaborn
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.barplot(x=categorias, y=count_data , palette="Set1")
plt.xlabel('Gender')
plt.ylabel('Total passengers')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic['Pclass'].unique() #hay tres clases:1,2,3
titanic['Pclass']=titanic['Pclass'].astype('object')
# your code here
titanic_Pclass = titanic.groupby('Pclass').agg({'PassengerId':'count'}).reset_index()
plt.pie(titanic_Pclass['PassengerId'], labels=titanic_Pclass['Pclass'],autopct='%1.1f%%', startangle=140)
plt.show()

#grafico de barras:

plt.bar(titanic_Pclass['Pclass'], titanic_Pclass['PassengerId'],color=colors)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
stats_sum = titanic['Age'].describe() 
plt.figure(figsize=(6, 4))
plt.boxplot(titanic['Age'], vert=False)  # Create a horizontal box plot
q1 = titanic['Age'].quantile(0.25)
q2 = titanic['Age'].quantile(0.5)
q3 = titanic['Age'].quantile(0.75)

print('First quartile:',q1)
print('Second quartile:',q2)
print('Third quartile:',q3)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()
stats_sum
# Out:
# First quartile: 22.0
# Second quartile: 28.5
# Third quartile: 37.0
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
"""
your comments here: with a boxplot we can see visually the mean, quartiles, outliers... 
"""
# Out:
# '\nyour comments here: with a boxplot we can see visually the mean, quartiles, outliers... \n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments herewe can see that the mean age is near to 30. Typical ages are between 20-40. 

"""
# Out:
# '\nyour comments herewe can see that the mean age is near to 30. Typical ages are between 20-40. \n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))

sns.distplot(titanic['Age'], bins=10, color='skyblue', kde=True)
plt.title('Age Distribution of the passengers of Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

stats_sum = titanic['Age'].describe() 
plt.figure(figsize=(6, 4))
plt.boxplot(titanic['Age'], vert=False)  # Create a horizontal box plot
q1 = titanic['Age'].quantile(0.25)
q2 = titanic['Age'].quantile(0.5)
q3 = titanic['Age'].quantile(0.75)

print('First quartile:',q1)
print('Second quartile:',q2)
print('Third quartile:',q3)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()
stats_sum
# Out:
# First quartile: 22.0
# Second quartile: 28.5
# Third quartile: 37.0
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here: a distribution with a mean near to 30, most values between 20-40 and some outliers as 80, 1... standard deviation of 13.4
"""
# Out:
# '\nyour comments here: a distribution with a mean near to 30, most values between 20-40 and some outliers as 80, 1... standard deviation of 13.4\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# your code here
plt.plot(titanic['Fare'],titanic['Age'],'ro')

# %%
# Method 2 - seaborn
# your code here
sns.set(style="whitegrid")

plt.plot(titanic['Fare'],titanic['Age'], color='skyblue', label='Data')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

correlation_matrix = titanic.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here: there are not very big correlations, however, some correlation is detected between parc and SibSp, also between Survived and Fare and SibSp and Ange
"""
# Out:
# '\nyour comments here: there are not very big correlations, however, some correlation is detected between parc and SibSp, also between Survived and Fare and SibSp and Ange\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# Set Seaborn style
sns.set(style="whitegrid")

# Create a box plot of Age by Pclass
plt.figure(figsize=(8, 6))
sns.boxplot(titanic['Pclass'], titanic['Age'], data=titanic, palette="Set2")
plt.title('Summary Statistics of Age by Passenger Class')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

# Set Seaborn style
sns.set(style="whitegrid")

# Create a histogram based on Gender
plt.figure(figsize=(8, 6))
sns.distplot(titanic[titanic['Gender'] == 'male']['Age'], kde=True, label='Male', color='skyblue')
sns.distplot(titanic[titanic['Gender'] == 'female']['Age'], kde=True, label='Female', color='lightcoral')
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Number of passengers')
plt.legend()
plt.show()
