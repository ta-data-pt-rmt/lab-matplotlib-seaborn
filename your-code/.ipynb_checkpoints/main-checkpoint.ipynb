# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries

import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.plot(x,y,'r')
plt.ylabel("Y")
plt.xlabel("X")
plt.title('X-Y Chart')
plt.show() #plt show discharges the accumulated options for plt so far

#plt.savefig('outputfile.png')
#plt.plot([1,2,3,4,5],[7,6,5,4,3],'bo')
#plt.plot([1,2,3,4,5],[5,4,3,2,1],'r+-')
#https://matplotlib.org/3.3.3/api/markers_api.html

# %%
plt.plot(x,z,'b')
plt.ylabel("Z")
plt.xlabel("X")
plt.title('X-Z Chart')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2)

chart_1.plot(x,y,'r')
chart_2.plot(x,z,'b')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10,5))

chart_1.plot(x,y,'r')
chart_1.set_title('X-Y CHART')
chart_1.set_xlabel('X')
chart_1.set_ylabel('Y')

chart_2.plot(x,z,'b')
chart_2.set_title('X-Z CHART')
chart_2.set_xlabel('X')
chart_2.set_ylabel('Z')

plot_options.suptitle('Different types of Charts', fontsize=16)
plot_options.supxlabel('Numbers from 0 to 100')
plot_options.supylabel('Numbers based on X values')
plot_options.tight_layout()

plt.show()
plt.savefig('challenge1.png')

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

x = np.arange(0,100)
y = x*2
z = np.exp(x)


plot_options, axes = plt.subplots()

# Plotting both the curves simultaneously
plt.plot(x, y, color='r', label='X - Y')
plt.plot(x, z, color='g', label='X - Z')
axes.set_yscale('log')
axes.set_xscale('log')

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("X")
plt.ylabel("Y / Z")
plt.title("Dual Function in same graphic")
  
# To load the display window
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

x = np.arange(0,100)
y = x*2
z = np.exp(x)


plot_options, axes = plt.subplots()

# Plotting both the curves simultaneously
plt.plot(x, y, color='r', label='X - Y')
plt.plot(x, z, color='g', label='X - Z')
axes.set_yscale('log')
axes.set_xscale('log')

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("X")
plt.ylabel("Y / Z")
plt.title("Dual Function in same graphic")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit_df = pd.read_csv("Fitbit2.csv")
fitbit_df
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
month_df = (fitbit_df.groupby(['Months']).agg({'Steps':'mean','Months_encoded':'unique'}).reset_index())
month_df = (month_df.sort_values(by='Months_encoded')).drop(columns="Months_encoded")

# MEDIAN STEPS BY WORK_OR_WEEKEND
week_end_df = (fitbit_df.groupby(['Days']).agg({'Steps':'mean','Days_encoded':'unique' }).reset_index())
week_end_df = (week_end_df.sort_values(by='Days_encoded')).drop(columns="Days_encoded")

# MEDIAN STEPS BY WORK_OR_WEEKEND SUM
week_end2_df = (fitbit_df.groupby(['Work_or_Weekend']).agg({'Steps':'mean'}).reset_index())

#GENERAL CHART SETTINGS
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 1, ncols = 2, figsize = (12,4))
plot_options.suptitle('Fitbit Dataset Mean Analysis', fontsize=12)
plot_options.tight_layout(pad=2.5)

# CHART 1
chart_1.plot(month_df['Months'],month_df['Steps'])
chart_1.set_title('CHART 1-STEPS BY MONTH')
chart_1.set_xticklabels(month_df['Months'], fontsize=12, rotation=45)
chart_1.set_yticklabels((month_df['Steps'].round()), fontsize=10)
chart_1.set_yscale('linear')

# CHART 2
chart_2.bar(week_end_df['Days'],week_end_df['Steps'])
chart_2.set_title('CHART2-STEPS WEEK vs WEEKEND')
chart_2.set_xticklabels(week_end_df['Days'], fontsize=12, rotation=45)
chart_2.set_yticklabels((week_end_df['Steps'].round()), fontsize=10)
plt.bar(week_end_df['Days'], week_end_df['Steps'], color=['blue', 'blue', 'blue', 'blue', 'blue', 'red', 'red'])
chart_2.set_yscale('linear')

plt.show()
plt.savefig('challenge2a.png')
# Out:
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\1159876080.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_1.set_xticklabels(month_df['Months'], fontsize=12, rotation=45)
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\1159876080.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_1.set_yticklabels((month_df['Steps'].round()), fontsize=10)
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\1159876080.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_2.set_xticklabels(week_end_df['Days'], fontsize=12, rotation=45)
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\1159876080.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_2.set_yticklabels((week_end_df['Steps'].round()), fontsize=10)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

scatter = [fitbit_df['Minutes Lightly Active'], fitbit_df['Minutes Very Active'], fitbit_df['Minutes Sedentary']]
types = ['ro','b^','gs']

for i, item in zip(scatter, types):
        plt.plot((fitbit_df['Steps']), i, item, label="Steps-"+'i')
        plt.show()

plt.savefig('challenge2b.png')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic_df = pd.read_csv("titanic.csv")
titanic_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic_df.select_dtypes(include=['float64','int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

titanic_df.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

from matplotlib.pyplot import style
from matplotlib.pyplot import figure

plt.style.use('classic')
figure(figsize=(8, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

titanic_df.hist(column='Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

titanic_df.hist(column='Age', bins=[0, 10, 20, 50, 100])
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
# This bin distribution now make a funnel, most of the distribution is on the last bin

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

titanicsns_df = (titanic_df.groupby(['Age']).agg({'PassengerId':'count'}).reset_index())
titanicsns_df = titanicsns_df.rename(columns={"PassengerId": "Freq"})
titanicsns_df

import seaborn as sns
sns.displot(x = 'Age', y = 'Freq', data = titanicsns_df)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

gender = (titanic_df.groupby(['Gender']).agg({'Age':'count'}).reset_index())

plot_options , (chart_3) = plt.subplots(nrows = 1, ncols = 1, figsize = (5,3))

chart_3.bar(gender['Gender'],gender['Age'])
chart_3.set_title('CHART3-QTY x GENDER')
chart_3.set_xticklabels(gender['Gender'], fontsize=12, rotation=45)
chart_3.set_yticklabels((gender['Age'].round()), fontsize=10)
chart_3.set_yscale('linear')
# Out:
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\3530019773.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_3.set_xticklabels(gender['Gender'], fontsize=12, rotation=45)
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\3530019773.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_3.set_yticklabels((gender['Age'].round()), fontsize=10)

# %%
gender = gender.rename(columns={'Age': 'Qty'})
gender
# Out:
#    Gender  Qty
# 0  female  466
# 1    male  843

# %%
# Method 2 - seaborn
# your code here

sns.barplot(x = 'Gender', y = 'Qty', data = gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Qty'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# titanic_df.hist(column='Pclass')

pclass = (titanic_df.groupby(['Pclass']).agg({'PassengerId':'count'}).reset_index())
pclass['Class'] = pd.DataFrame(['1st Class', '2nd Class', '3rd Class'])

plot_options , (chart_4) = plt.subplots(nrows = 1, ncols = 1, figsize = (4,5))

chart_4.bar(pclass['Class'],pclass['PassengerId'])
chart_4.set_title('CHART4-QTY x PClass')
chart_4.set_xticklabels(pclass['Class'], fontsize=12, rotation=0)
chart_4.set_yticklabels((pclass['PassengerId'].round()), fontsize=10)
chart_4.set_yscale('linear')

plt.show()
# Out:
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\483036420.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_4.set_xticklabels(pclass['Class'], fontsize=12, rotation=0)
# C:\Users\fcavanagh\AppData\Local\Temp\ipykernel_9388\483036420.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart_4.set_yticklabels((pclass['PassengerId'].round()), fontsize=10)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

stats = titanic_df['Age'].describe().reset_index()
stats = stats.drop(labels=[0], axis=0)
display(stats)

plt.plot(stats['index'], stats['Age'])
plt.xlabel("Stats")
plt.ylabel("Value")
plt.title("'Age' stats, age sample = 1390un")
plt.show()
# Out:
#   index        Age
# 1  mean  29.879186
# 2   std  13.448335
# 3   min   0.170000
# 4   25%  22.000000
# 5   50%  28.500000
# 6   75%  37.000000
# 7   max  80.000000

# %%
# I used the line scatter, but removed the 'count' figure because make all other data loss perspective
# So, decided to put the sample size on the plot title

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
# there is an important dispersion in this feature bet min and max

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

plot_options , (chart_5, chart_6) = plt.subplots(nrows = 1, ncols = 2)
plot_options.tight_layout(pad=2.5)

chart_5.plot(stats['index'], stats['Age'], color='red')
chart_6.hist(titanic_df['Age'], color='lightblue')
plt.xlabel("Age")
plt.ylabel("Qty")
plt.show()

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
# Its easier to see the data centralization along the mean value (30)

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

fare_age_corr1 = titanic_df[['Fare','Age']]
fare_age_corr1

plt.matshow(fare_age_corr1.corr())
plt.xticks(range(0,2),fare_age_corr1.columns)
plt.yticks(range(0,2),fare_age_corr1.columns)
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.catplot(x = 'Fare', y = 'Age', data = titanic_df)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

sns.pairplot(titanic_df)

# %% [markdown]
# #### What are the most correlated features?

# %%
# I dont see any clear and strong corr at first sight

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

graph = sns.FacetGrid(titanic_df, row ='Pclass')
graph.map(plt.hist, 'Age', bins = 10, color ='lightblue')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

graph = sns.FacetGrid(titanic_df, row ='Gender')
# map the above form facetgrid with some attributes
graph.map(plt.hist, 'Age', bins = 10, color ='orange')
# show the object
plt.show()
