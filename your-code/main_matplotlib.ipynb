# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y,'r-')
plt.title('First method_plot1')
plt.show()
plt.plot(x,z,'b+')
plt.title('Second method_plot2')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 2, ncols = 1, figsize = (20,10))  # how can I display the title over the top diagram
plt.title("Method 2 with plt.subplots")
chart_1.plot(x,y,"b")
chart_2.plot(x,z,"g")
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
plot_options , (chart_1,chart_2) = plt.subplots(nrows = 2, ncols = 1, figsize = (20,15))

chart_1.plot(x,y,"b")
plt.title("Method 2_plot1 with plt.subplots")
plt.xticks(fontsize=12,rotation=45)
plt.ylabel("y_axis")
plt.xlabel("x_axis")
chart_2.plot(x,z,"g")
plt.title("Method 2_plot2 with plt.subplots")
plt.ylabel("y_axis")
plt.xlabel("x_axis")
plt.show()

# %% [markdown]
# # Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %% [markdown]
# x = np.arange(0,100)
# y = x*2
# z = x**2

# %%
xaxis =  np.arange(0, 4, 1000)
xaxis
# Out:
# array([0])

# %%
y1 = x**2
y2 = np.exp(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.yscale("log")
plt.xscale("log")
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
y1 = x**2
y2 = np.exp(x)
plt.plot(x,y1,label = "square")
plt.plot(x,y2,label = "exponential")
plt.yscale("log")
plt.xscale("log")
plt.ylabel("y_axis")
plt.xlabel("x_axis")
plt.legend()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv("Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# For visual help 
msteps_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()
display(msteps_month)
msteps_wow = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()
display(msteps_wow)
# Out:
#     Months_encoded    Steps
# 0                1  10366.0
# 1                2   9235.0
# 2                3  11122.0
# 3                4  13846.5
# 4                5  11998.0
# 5                6  12935.5
# 6                7  10644.0
# 7                8  12213.0
# 8                9   9343.0
# 9               10   7865.0
# 10              11   9453.5
# 11              12   8531.0
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
# MEDIAN STEPS BY MONTH_ENCODED 
# MEDIAN STEPS BY WORK_OR_WEEKEND

plot_options , (chart_1,chart_2) = plt.subplots(nrows = 2, ncols = 1, figsize = (12,4))

msteps_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()
msteps_wow = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()
chart_1.bar(msteps_month['Months_encoded'], msteps_month['Steps'])   
plt.xticks(fontsize=24,rotation=45)
chart_2.bar(msteps_wow['Work_or_Weekend'], msteps_wow['Steps'])
plt.xticks(range(0,2))
plt.savefig('figures.png')
# The fittbiter is more active during the weeek, achieving +400 more steps than during the weekend

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x_col = "Steps"
y_columns = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]


for y_col in y_columns:

    figure = plt.figure  # not quite sure, why to use this
    ax = plt.gca()   # not quite sure, why to use this, is it to show more than one?
    ax.scatter(fitbit[x_col], fitbit[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title("{} vs {}".format(x_col, y_col))
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
only_numerics = titanic.select_dtypes(include=numerics)
only_numerics.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES

categorical = titanic.select_dtypes(exclude=numerics)
categorical.columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
mpl.rcParams['figure.figsize'] = [12.0, 6.0]

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic["Age"].hist()
plt.suptitle("Age distribution")
plt.ylabel("Number of Passengers")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bins = [0,10,20,50]
titanic["Age"].hist(bins=bins)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The main difference I would say is that we get less granularity and therefore we are not able to spot the main groups and guess values like the mean, median, etc.
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x="Age",data = titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
# Method 1 - matplotlib
gender_distrib = titanic.groupby('Gender').agg({"PassengerId":"count"}).reset_index()
display(gender_distrib)
labels = ["female","male"]
plt.pie(gender_distrib["PassengerId"],labels=labels,autopct='%.0f%%')
plt.show()
# Out:
#    Gender  PassengerId
# 0  female          466
# 1    male          843

# %%
# Method 2 - seaborn
sns.barplot(x="Gender", y="PassengerId",hue="Gender", data=gender_distrib)
plt.ylabel("Passenger_quantity")
# Out:
# Text(0, 0.5, 'Passenger_quantity')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
PcClass_distrib = titanic.groupby('Pclass').agg({"PassengerId":"count"}).reset_index()
display(PcClass_distrib)
# Out:
#    Pclass  PassengerId
# 0       1          323
# 1       2          277
# 2       3          709

# %%
plt.figure(figsize = (20,10))
plt.bar(PcClass_distrib['Pclass'],PcClass_distrib['PassengerId'])
plt.xticks(fontsize=30)
plt.xticks(range(1,4))
plt.ylabel("Passenger_quantity")
plt.xlabel("PClass")
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
print(titanic["Age"].describe())
titanic.boxplot(column='Age', return_type='axes')
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64
# <AxesSubplot:>

# %%
"""
I would use a boxplot to visualize the age distribution among the passengers, including the min, max, mean, percentiles and standard deviation.

"""
# Out:
# '\nI would use a boxplot to visualize the age distribution among the passengers, including the min, max, mean, percentiles and standard deviation.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
75% of the passengers are younger than 37 years old.
The average is 29.87 years old

"""
# Out:
# '\nI\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.violinplot(x = 'Age', data = titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.figure(figsize = (20,15))
plt.scatter(titanic['Age'],titanic['Fare'],c = 'green')
plt.ylabel("Fare")
plt.xlabel("Age")
plt.show()

# %%
# Method 2 - seaborn
sns.regplot(x="Age", y="Fare", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

print(only_numerics.corr())
plt.matshow(only_numerics.corr())
plt.colorbar()
plt.xticks(range(0,7),only_numerics.columns)
plt.yticks(range(0,7),only_numerics.columns)
plt.show()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are Parch - SibSp & Survived - Fare (in both way)

It seems logical that the sibsp (Number of Siblings/Spouses Aboard) and the parch (Number of Parents/Children Aboard), as well as the fare and the number of survived have a strong relationship.

"""
# Out:
# '\nThe most correlated features are Parch - SibSp & Survived - Fare (in both way)\n\nIt seems logical that the sibsp (Number of Siblings/Spouses Aboard) and the parch (Number of Parents/Children Aboard), as well as the fare and the number of survived have a strong relationship.\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.boxplot([titanic.loc[titanic['Pclass'] == 1, 'Age'],titanic.loc[titanic['Pclass'] == 2, 'Age'],titanic.loc[titanic['Pclass'] == 3, 'Age']]
)
plt.show()

# %%
plt.boxplot(titanic.loc[titanic['Pclass'] == 1, 'Age'])
plt.show()
plt.boxplot(titanic.loc[titanic['Pclass'] == 2, 'Age'])
plt.show()
plt.boxplot(titanic.loc[titanic['Pclass'] == 3, 'Age'])

plt.show()

# %%
# For own use
bin_age = [*range(0, 101, 5)]
labels = np.array([*range(0, 100, 5)])
titanic['bin_years'] = pd.cut(titanic['Age'], bins=bin_age, labels=labels)
Pclass_age = titanic.groupby(['Pclass',"bin_years"]).agg({"PassengerId":"count"}).reset_index()
Pclass_age
sns.lineplot(x="bin_years", y="PassengerId",hue="Pclass",data=Pclass_age)
plt.ylabel("Passenger_quantity")
# Out:
# Text(0, 0.5, 'Passenger_quantity')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

g = sns.FacetGrid(titanic, col="Gender")
g.map_dataframe(sns.histplot, x="Age")
